# %% [markdown]
# Import important parameter

# %%
inputsize = 31**2
e = 0.05

# %% [markdown]
# Import Package

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import autograd.numpy as np
from autograd import grad
import pyamg
import dmg.gallery as gallery
import dmg.dgmg as dgmg
import dmg.gmg_linear as gmg_linear
import dmg.classical_amg as classical_amg
from mpl_toolkits.mplot3d import Axes3D
import xlsxwriter
from scipy.ndimage import convolve

# %% [markdown]
# Define function

# %%
def Restriction(inputsize):
    inputsize = int(inputsize)
    sqrtinputsize = int(np.sqrt(inputsize))     
    sqrtoutputsize = int(sqrtinputsize/2)
    outputsize = int(sqrtoutputsize**2)
    OUTPUT = np.zeros([outputsize, inputsize])
    for j in range(sqrtoutputsize):
        for i in range(sqrtoutputsize):
            OUTPUT[i+sqrtoutputsize*j][2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][1+2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2+2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][1+sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/4
            OUTPUT[i+sqrtoutputsize*j][2+sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2*sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][1+2 *
                                       sqrtinputsize + 2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2+2 *
                                       sqrtinputsize+2*i+j*2*sqrtinputsize] = 1/16
    return OUTPUT

def Poisson(inputsize):
    inputsize = int(inputsize)
    sqrtinputsize = int(np.sqrt(inputsize))     
    sqrtoutputsize = int(sqrtinputsize/2)
    outputsize = int(sqrtoutputsize**2)
    OUTPUT = np.zeros([outputsize, inputsize])
    A1 = 2*np.eye(sqrtinputsize)
    for i in range(sqrtinputsize-1):
        A1[i, i+1] = -1
        A1[i+1, i] = -1
    I = np.eye(sqrtinputsize)
    OUTPUT = (np.kron(I, A1)+np.kron(A1, I))
    return OUTPUT


def Multigrid_circle(inputsize, A_A, B, R_A, s, w, error):
    A = np.matrix(A_A)
    P = 16.*np.transpose(R_A)
    R = np.matrix(R_A)
    M = np.matrix(w**(-1)*np.diag(np.diag(A)))
    K = M - A
    C = np.linalg.inv(M)*K
    b = np.linalg.inv(M)*B
    U0 = np.matrix(np.zeros([inputsize, 1]))
    RESIDUAL = []
    Residual=1
    i=0
    while Residual > error:
        for j in range(s):
            U0 = C*U0+b
        r = B - A*U0
        Residual = np.linalg.norm(r,2)
        rc = R*r
        Ac = R*A*P
        Uc = np.linalg.solve(Ac, rc)
        U = U0 + P*Uc
        for k in range(s):
            U = C*U+b
        U0 = U
        RESIDUAL.append(Residual)
        i=i+1
        print("Residual = {}".format(Residual))
        print("Interation = {}".format(i))
        print("===================")
    return U0, RESIDUAL

def rho(inputsize,A,P,R,w,s):
    M = (w**(-1)) * np.diag(np.diag(A))
    K = M - A
    MK = np.matmul(np.linalg.inv(M),K)
    I = np.eye(inputsize)
    IPRAPRA = I - np.matmul(np.matmul(np.matmul(P,np.linalg.inv(np.matmul(np.matmul(R,A),P))),R),A)
    C = np.matmul(np.matmul(MK,IPRAPRA),MK)
    for i in range(5):
        C = np.matmul(C,C)
    radius = np.linalg.norm(C)**(1/32)
    return radius

def optimizer_GD(inputsize, A1, R, w, s, learning_rate, lam):
    rhoold = rho(inputsize,A1,16*np.transpose(R),R,w,s)
    device = torch.device('cpu')
    R = torch.tensor(R,dtype = torch.double, requires_grad=True,device=device)
    w = torch.tensor(w,dtype = torch.double, requires_grad=True, device=device)
    lam = torch.tensor(lam,dtype = torch.double, requires_grad=True, device=device)
    A = torch.tensor(A1,dtype = torch.double, device=device)
    P = 16*torch.t(R)
    M = (w**(-1)) * torch.diag(torch.diag(A))
    K = M - A
    MK = torch.mm(torch.inverse(M),K)
    I = torch.eye(inputsize,dtype = torch.double, device=device)
    I1 = torch.ones([inputsize,1],dtype = torch.double, device=device)
    I2 = torch.ones([outputsize,1],dtype = torch.double, device=device)
    IPRAPRA = I - torch.mm(torch.mm(torch.mm(P,torch.inverse(torch.mm(torch.mm(R,A),P))),R),A)
    C = torch.mm(torch.mm(MK,IPRAPRA),MK)
    for i in range(5):
        C = torch.mm(C,C)
    loss = torch.norm(C)**(1/32) + torch.mm(lam,torch.mm(R,I1) - I2)
    loss.backward()
    with torch.no_grad():
        R-=learning_rate*R.grad
        w-=learning_rate*w.grad 
        lam-=learning_rate*lam.grad
    R = R.detach().numpy()
    w = w.detach().numpy()
    lam = lam.detach().numpy()
    rhonew = rho(inputsize,A1,16*np.transpose(R),R,w,s)
    return R, w, lam, rhoold, rhonew

def direct_optimizer_GD(inputsize, A0, A1, R, w, s, learning_rate, lam):
    Rhoold = rho(inputsize,A1,16*np.transpose(R),R,w,s)
    Rhonew = [Rhoold]
    for i in range(100):
        Rnew, wnew, lamnew, rhoold, rhonew = optimizer_GD(inputsize, A1, R, w, s, learning_rate, lam)
        R = Rnew
        w = wnew
        lam = lamnew
        print("rho = {}".format(rhonew))
        print("===================")
        Rhonew.append(rhonew)
        i+=1
    print("======End======")
    return R, w, Rhoold, Rhonew

def homotopy_optimizer_GD(inputsize, A0, A1, R, w, s, learning_rate ,accept_radius ,step_length,lam):
    Rhoold = rho(inputsize,A1,16*np.transpose(R),R,w,s)
    Radius = [Rhoold]
    L = step_length
    print("======Section 1======")
    while L < 1:
        M = (1-L)*A0 + L*A1
        Rnew, wnew, lamnew, rhoold, rhonew = optimizer_GD(inputsize, M, R, w, s, learning_rate, lam)
        Radius.append(rhonew)
        if rhonew > accept_radius:
            step_length = 0.1*step_length
            learning_rate = 0.1*learning_rate
            print('Decrease the step_length, learning_rate and Restart!!')
            print("step_length = {}".format(step_length))      
            print("learning_rate = {}".format(learning_rate))
            print("rhonew = {}".format(rhonew))
            print("===================")
            R = Restriction(inputsize)
            lam = np.zeros([1,outputsize])
            w = 2/3
            L = step_length
        else:
            R = Rnew
            w = wnew
            L += step_length
            lam = lamnew
            print("L = {}".format(L))
            print("rho = {}".format(rhonew))
            print("===================")
    print("======Section 2======")
    i = 0
    while rhoold>rhonew and i <1000:
        Rnew, wnew, lamnew, rhoold, rhonew = optimizer_GD(inputsize, A1, R, w, s, learning_rate, lam)
        Radius.append(rhonew)
        R = Rnew
        w = wnew
        lam = lamnew
        print("the {} steps".format(i))
        print("rho = {}".format(rhonew))
        print("===================")
        i+=1            
    Rhonew = rhonew
    print("======End======")
    return R, w, Rhoold, Rhonew, Radius

# %% [markdown]
# Define parameter

# %%
s = 1
w = 2/3
error=10e-11
def u_real(x, y): return np.sin(np.pi*3*x)*np.sin(np.pi*5*y)
def rightf(x, y): return  (-(5/6))*np.pi*np.cos(5*np.pi*y)*np.sin(3*np.pi*x)*(-((np.pi*np.cos(np.pi*y)*(1.1 + np.sin(np.pi*x)))/(1.1 + np.sin(np.pi*y))**2)-(10*np.pi*np.cos(10*np.pi*y)*(1.1 + np.sin(10*np.pi*x)))/(1.1 + np.sin(10*np.pi*y))**2)-(1/2)*np.pi*np.cos(3*np.pi*x)*np.sin(5*np.pi*y)*((np.pi*np.cos(np.pi*x))/(1.1 + np.sin(np.pi*y)) + (10*np.pi*np.cos(10*np.pi*x))/(1.1 + np.sin(10*np.pi*y))) +  (17/3)*np.pi**2*np.sin(3*np.pi*x)*np.sin(5*np.pi*y)*((1.1 + np.sin(np.pi*x))/(1.1 + np.sin(np.pi*y)) + (1.1 + np.sin(10*np.pi*x))/(1.1 + np.sin(10*np.pi*y)))
def a(x,y): return (1/6)*((1.1 + np.sin(np.pi*x))/(1.1 + np.sin(np.pi*y)) + (1.1 +np.sin(np.pi*x*10))/(1.1 + np.sin(np.pi*y*10)))

sqrtinputsize = int(np.sqrt(inputsize))
sqrtmidputsize = int(sqrtinputsize/2)
midputsize = int(sqrtmidputsize**2)
sqrtoutputsize = int(sqrtmidputsize/2)
outputsize = int(sqrtoutputsize**2)

h = 1/(sqrtinputsize-1)
H = 1/(sqrtoutputsize-1)
A0 = Poisson(inputsize)
num_levels=2
n=sqrtinputsize
kx = np.zeros([n,n+1])
ky = np.zeros([n+1,n])
for i in range(n):
    for j in range(n+1):
        kx[i][j] = a((j-0.5)*h,i*h)
for i in range(n+1):
    for j in range(n):
        ky[i][j] = a(j*h,(i-0.5)*h)    
A1 = gallery.nonlinearPoisson((n,n), kx, ky)
n = inputsize
[X, Y] = np.meshgrid(np.linspace(0, 1, sqrtinputsize),np.linspace(0, 1, sqrtinputsize))
RightF = rightf(X,Y)*h**2
RightF = RightF.reshape(inputsize, 1)
Ureal = u_real(X,Y).reshape(inputsize, 1)
Media = a(X,Y)
R1 = Restriction(inputsize)
R2 = Restriction(midputsize)
R  = np.matmul(R2, R1)
P = 16*np.transpose(R)

# %% [markdown]
# GMM on fine grid

# %%
GMM_U, GMM_Res = Multigrid_circle(inputsize, A1.to_full(), RightF, R, s, w, error)
# Out:
# Residual = 3.966544131291676
# Interation = 1
# ===================
# Residual = 1.0045130663985138
# Interation = 2
# ===================
# Residual = 0.6278880507358233
# Interation = 3
# ===================
# Residual = 0.4141020931315499
# Interation = 4
# ===================
# Residual = 0.28104422200832674
# Interation = 5
# ===================
# Residual = 0.19575244578083206
# Interation = 6
# ===================
# Residual = 0.14006304123896865
# Interation = 7
# ===================
# Residual = 0.10296611060368348
# Interation = 8
# ===================
# Residual = 0.07763558785164687
# Interation = 9
# ===================
# Residual = 0.05983528168639733
# Interation = 10
# ===================
# Residual = 0.046944775901305205
# Interation = 11
# ===================
# Residual = 0.03734124754259223
# Interation = 12
# ===================
# Residual = 0.030009205728586636
# Interation = 13
# ===================
# Residual = 0.02429976553329672
# Interation = 14
# ===================
# Residual = 0.019785795392616896
# Interation = 15
# ===================
# Residual = 0.01617621040769728
# Interation = 16
# ===================
# Residual = 0.013265504973018694
# Interation = 17
# ===================
# Residual = 0.010903800274295437
# Interation = 18
# ===================
# Residual = 0.008978719208229185
# Interation = 19
# ===================
# Residual = 0.007404100872381314
# Interation = 20
# ===================
# Residual = 0.006112727019697935
# Interation = 21
# ===================
# Residual = 0.005051457965488342
# Interation = 22
# ===================
# Residual = 0.004177860434298276
# Interation = 23
# ===================
# Residual = 0.0034577919586569364
# Interation = 24
# ===================
# Residual = 0.0028636211647786528
# Interation = 25
# ===================
# Residual = 0.0023728857962366312
# Interation = 26
# ===================
# Residual = 0.00196726178486431
# Interation = 27
# ===================
# Residual = 0.0016317595092012582
# Interation = 28
# ===================
# Residual = 0.0013540898592780625
# Interation = 29
# ===================
# Residual = 0.0011241596400351419
# Interation = 30
# ===================
# Residual = 0.0009336670079628139
# Interation = 31
# ===================
# Residual = 0.0007757752344605973
# Interation = 32
# ===================
# Residual = 0.0006448484111262028
# Interation = 33
# ===================
# Residual = 0.0005362365339756855
# Interation = 34
# ===================
# Residual = 0.00044610020853190057
# Interation = 35
# ===================
# Residual = 0.0003712673151717615
# Interation = 36
# ===================
# Residual = 0.00030911556747998943
# Interation = 37
# ===================
# Residual = 0.0002574761231721082
# Interation = 38
# ===================
# Residual = 0.00021455436245556273
# Interation = 39
# ===================
# Residual = 0.00017886469977288676
# Interation = 40
# ===================
# Residual = 0.00014917689016598725
# Interation = 41
# ===================
# Residual = 0.00012447176657837797
# Interation = 42
# ===================
# Residual = 0.00010390472569259042
# Interation = 43
# ===================
# Residual = 8.67755874938505e-05
# Interation = 44
# ===================
# Residual = 7.250370278173651e-05
# Interation = 45
# ===================
# Residual = 6.0607385291784227e-05
# Interation = 46
# ===================
# Residual = 5.068691002478971e-05
# Interation = 47
# ===================
# Residual = 4.24104541611617e-05
# Interation = 48
# ===================
# Residual = 3.550246723281438e-05
# Interation = 49
# ===================
# Residual = 2.9734047698510076e-05
# Interation = 50
# ===================
# Residual = 2.4914977316931396e-05
# Interation = 51
# ===================
# Residual = 2.0887125796907594e-05
# Interation = 52
# ===================
# Residual = 1.75189884158744e-05
# Interation = 53
# ===================
# Residual = 1.4701160692971757e-05
# Interation = 54
# ===================
# Residual = 1.2342588302780512e-05
# Interation = 55
# ===================
# Residual = 1.0367458525077974e-05
# Interation = 56
# ===================
# Residual = 8.71262273015539e-06
# Interation = 57
# ===================
# Residual = 7.3254585482841545e-06
# Interation = 58
# ===================
# Residual = 6.162096178261748e-06
# Interation = 59
# ===================
# Residual = 5.185946347270956e-06
# Interation = 60
# ===================
# Residual = 4.366478226382448e-06
# Interation = 61
# ===================
# Residual = 3.6782045206899287e-06
# Interation = 62
# ===================
# Residual = 3.0998383201536302e-06
# Interation = 63
# ===================
# Residual = 2.613592393326479e-06
# Interation = 64
# ===================
# Residual = 2.204596647552622e-06
# Interation = 65
# ===================
# Residual = 1.8604136380088718e-06
# Interation = 66
# ===================
# Residual = 1.5706354730261287e-06
# Interation = 67
# ===================
# Residual = 1.3265482962052833e-06
# Interation = 68
# ===================
# Residual = 1.120852908057394e-06
# Interation = 69
# ===================
# Residual = 9.47432027661745e-07
# Interation = 70
# ===================
# Residual = 8.01156327148964e-07
# Interation = 71
# ===================
# Residual = 6.777227078594269e-07
# Interation = 72
# ===================
# Residual = 5.735193904118685e-07
# Interation = 73
# ===================
# Residual = 4.85513329749767e-07
# Interation = 74
# ===================
# Residual = 4.111562045336078e-07
# Interation = 75
# ===================
# Residual = 3.483058911929702e-07
# Interation = 76
# ===================
# Residual = 2.951608263309417e-07
# Interation = 77
# ===================
# Residual = 2.5020512570415354e-07
# Interation = 78
# ===================
# Residual = 2.1216266734189887e-07
# Interation = 79
# ===================
# Residual = 1.7995865755848308e-07
# Interation = 80
# ===================
# Residual = 1.526874435378422e-07
# Interation = 81
# ===================
# Residual = 1.2958554424190445e-07
# Interation = 82
# ===================
# Residual = 1.1000903910044609e-07
# Interation = 83
# ===================
# Residual = 9.341460162375112e-08
# Interation = 84
# ===================
# Residual = 7.93435881907399e-08
# Interation = 85
# ===================
# Residual = 6.740867108071879e-08
# Interation = 86
# ===================
# Residual = 5.728261483334196e-08
# Interation = 87
# ===================
# Residual = 4.868884000205285e-08
# Interation = 88
# ===================
# Residual = 4.139348821730333e-08
# Interation = 89
# ===================
# Residual = 3.519874917128318e-08
# Interation = 90
# ===================
# Residual = 2.9937238289629604e-08
# Interation = 91
# ===================
# Residual = 2.546726743786203e-08
# Interation = 92
# ===================
# Residual = 2.1668856638109274e-08
# Interation = 93
# ===================
# Residual = 1.8440373019678502e-08
# Interation = 94
# ===================
# Residual = 1.569569627888283e-08
# Interation = 95
# ===================
# Residual = 1.336182852606598e-08
# Interation = 96
# ===================
# Residual = 1.1376875217053566e-08
# Interation = 97
# ===================
# Residual = 9.688338941743788e-09
# Interation = 98
# ===================
# Residual = 8.251680973123912e-09
# Interation = 99
# ===================
# Residual = 7.029103644980696e-09
# Interation = 100
# ===================
# Residual = 5.988521665889018e-09
# Interation = 101
# ===================
# Residual = 5.102691904980488e-09
# Interation = 102
# ===================
# Residual = 4.348475345757593e-09
# Interation = 103
# ===================
# Residual = 3.7062149431159694e-09
# Interation = 104
# ===================
# Residual = 3.1592085098715497e-09
# Interation = 105
# ===================
# Residual = 2.6932596740976938e-09
# Interation = 106
# ===================
# Residual = 2.2963001655281567e-09
# Interation = 107
# ===================
# Residual = 1.9580690144039795e-09
# Interation = 108
# ===================
# Residual = 1.6698392134634014e-09
# Interation = 109
# ===================
# Residual = 1.4241867905754369e-09
# Interation = 110
# ===================
# Residual = 1.214796335906922e-09
# Interation = 111
# ===================
# Residual = 1.0362943211465668e-09
# Interation = 112
# ===================
# Residual = 8.841060705684061e-10
# Interation = 113
# ===================
# Residual = 7.543377938595373e-10
# Interation = 114
# ===================
# Residual = 6.43674987187997e-10
# Interation = 115
# ===================
# Residual = 5.492945020871861e-10
# Interation = 116
# ===================
# Residual = 4.687924997326873e-10
# Interation = 117
# ===================
# Residual = 4.001214532336924e-10
# Interation = 118
# ===================
# Residual = 3.415373293320532e-10
# Interation = 119
# ===================
# Residual = 2.915536429533519e-10
# Interation = 120
# ===================
# Residual = 2.4890378787758056e-10
# Interation = 121
# ===================
# Residual = 2.1250831129215715e-10
# Interation = 122
# ===================
# Residual = 1.8144801977257248e-10
# Interation = 123
# ===================
# Residual = 1.549383334233253e-10
# Interation = 124
# ===================
# Residual = 1.3231085855754434e-10
# Interation = 125
# ===================
# Residual = 1.1299535835942186e-10
# Interation = 126
# ===================
# Residual = 9.65058172463709e-11
# Interation = 127
# ===================

# %% [markdown]
# Error GMM on fine grid

# %%
UREAL = Ureal.reshape(sqrtinputsize,sqrtinputsize)
GMMU = GMM_U.reshape(sqrtinputsize,sqrtinputsize)
deltaU = GMMU - UREAL

energynorm = np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=0),np.gradient(UREAL,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=1),np.gradient(UREAL,h,axis=1)),Media)*(h**2)))
l2norm = np.sqrt((np.linalg.norm(UREAL)**2)*(h**2))
h1norm = np.sqrt((np.linalg.norm(np.gradient(UREAL,h,axis=0))**2+np.linalg.norm(np.gradient(UREAL,h,axis=1))**2+np.linalg.norm(UREAL)**2)*(h**2))

print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),Media)*(h**2))))
print('L2 norm: ')
print(np.sqrt((np.linalg.norm(deltaU)**2)*(h**2)))
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2)))

print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),Media)*(h**2)))/energynorm)
print('L2 norm: ')
print(np.sqrt((np.linalg.norm(deltaU)**2)*(h**2))/l2norm)
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2))/h1norm)
# Out:
# Energy norm:
# 2.1958784708947072
# L2 norm:
# 0.1855312537339012
# H1 norm:
# 3.5732076305282603
# Energy norm:
# 0.33536022720671027
# L2 norm:
# 0.3710625074678024
# H1 norm:
# 0.3918142496306595

# %% [markdown]
# Solution

# %%
plt.imshow(GMM_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# Residual

# %%
plt.semilogy(GMM_Res)

# %% [markdown]
# Radius

# %%
GMM_Radius = rho(inputsize,A1.to_full(),16*np.transpose(R),R,w,s)
print('GMM_Radius = {}'.format(GMM_Radius))
# Out:
# GMM_Radius = 0.8906700063986657

# %% [markdown]
# Global DMM optimization

# %%
Rnew, wnew, Rhoold, Rhonew, Radius = homotopy_optimizer_GD(inputsize, A0, A1.to_full(), R,  2/3, s, 
                                                           learning_rate = 1e-6,accept_radius =
                                                           GMM_Radius*10,step_length =  1e-2, lam = np.zeros([1,outputsize]))
# Out:
# ======Section 1======
# L = 0.02
# rho = 0.8321124864099111
# ===================
# L = 0.03
# rho = 0.8322055718666528
# ===================
# L = 0.04
# rho = 0.8323115015609784
# ===================
# L = 0.05
# rho = 0.8324300089152732
# ===================
# L = 0.060000000000000005
# rho = 0.8325608549475776
# ===================
# L = 0.07
# rho = 0.8327038248627692
# ===================
# L = 0.08
# rho = 0.8328587249861751
# ===================
# L = 0.09
# rho = 0.8330253800008885
# ===================
# L = 0.09999999999999999
# rho = 0.8332036304554168
# ===================
# L = 0.10999999999999999
# rho = 0.8333933305129136
# ===================
# L = 0.11999999999999998
# rho = 0.8335943459172399
# ===================
# L = 0.12999999999999998
# rho = 0.8338065521545271
# ===================
# L = 0.13999999999999999
# rho = 0.8340298327918774
# ===================
# L = 0.15
# rho = 0.8342640779773604
# ===================
# L = 0.16
# rho = 0.8345091830876378
# ===================
# L = 0.17
# rho = 0.8347650475113902
# ===================
# L = 0.18000000000000002
# rho = 0.835031573558287
# ===================
# L = 0.19000000000000003
# rho = 0.8353086654845644
# ===================
# L = 0.20000000000000004
# rho = 0.8355962286273869
# ===================
# L = 0.21000000000000005
# rho = 0.8358941686410947
# ===================
# L = 0.22000000000000006
# rho = 0.836202390829205
# ===================
# L = 0.23000000000000007
# rho = 0.8365207995666681
# ===================
# L = 0.24000000000000007
# rho = 0.8368492978073897
# ===================
# L = 0.25000000000000006
# rho = 0.8371877866724426
# ===================
# L = 0.26000000000000006
# rho = 0.8375361651147284
# ===================
# L = 0.2700000000000001
# rho = 0.8378943296561
# ===================
# L = 0.2800000000000001
# rho = 0.8382621741931784
# ===================
# L = 0.2900000000000001
# rho = 0.8386395898682476
# ===================
# L = 0.3000000000000001
# rho = 0.839026465001758
# ===================
# L = 0.3100000000000001
# rho = 0.8394226850830699
# ===================
# L = 0.3200000000000001
# rho = 0.8398281328161784
# ===================
# L = 0.3300000000000001
# rho = 0.840242688217246
# ===================
# L = 0.34000000000000014
# rho = 0.8406662287608744
# ===================
# L = 0.35000000000000014
# rho = 0.8410986295721433
# ===================
# L = 0.36000000000000015
# rho = 0.8415397636615692
# ===================
# L = 0.37000000000000016
# rho = 0.841989502200263
# ===================
# L = 0.38000000000000017
# rho = 0.8424477148327276
# ===================
# L = 0.3900000000000002
# rho = 0.8429142700249089
# ===================
# L = 0.4000000000000002
# rho = 0.8433890354453205
# ===================
# L = 0.4100000000000002
# rho = 0.8438718783772895
# ===================
# L = 0.4200000000000002
# rho = 0.8443626661606339
# ===================
# L = 0.4300000000000002
# rho = 0.8448612666613639
# ===================
# L = 0.4400000000000002
# rho = 0.8453675487683249
# ===================
# L = 0.45000000000000023
# rho = 0.8458813829160433
# ===================
# L = 0.46000000000000024
# rho = 0.8464026416334188
# ===================
# L = 0.47000000000000025
# rho = 0.8469312001183231
# ===================
# L = 0.48000000000000026
# rho = 0.847466936838608
# ===================
# L = 0.49000000000000027
# rho = 0.8480097341605154
# ===================
# L = 0.5000000000000002
# rho = 0.8485594790059982
# ===================
# L = 0.5100000000000002
# rho = 0.8491160635410295
# ===================
# L = 0.5200000000000002
# rho = 0.8496793858975843
# ===================
# L = 0.5300000000000002
# rho = 0.8502493509326368
# ===================
# L = 0.5400000000000003
# rho = 0.8508258710282363
# ===================
# L = 0.5500000000000003
# rho = 0.8514088669374992
# ===================
# L = 0.5600000000000003
# rho = 0.8519982686822154
# ===================
# L = 0.5700000000000003
# rho = 0.8525940165086967
# ===================
# L = 0.5800000000000003
# rho = 0.853196061909537
# ===================
# L = 0.5900000000000003
# rho = 0.8538043687200925
# ===================
# L = 0.6000000000000003
# rho = 0.8544189142997742
# ===================
# L = 0.6100000000000003
# rho = 0.8550396908096625
# ===================
# L = 0.6200000000000003
# rho = 0.8556667065995603
# ===================
# L = 0.6300000000000003
# rho = 0.856299987719403
# ===================
# L = 0.6400000000000003
# rho = 0.856939579571979
# ===================
# L = 0.6500000000000004
# rho = 0.8575855487262324
# ===================
# L = 0.6600000000000004
# rho = 0.8582379849130439
# ===================
# L = 0.6700000000000004
# rho = 0.8588970032283866
# ===================
# L = 0.6800000000000004
# rho = 0.8595627465721797
# ===================
# L = 0.6900000000000004
# rho = 0.8602353883550875
# ===================
# L = 0.7000000000000004
# rho = 0.8609151355100099
# ===================
# L = 0.7100000000000004
# rho = 0.8616022318501816
# ===================
# L = 0.7200000000000004
# rho = 0.8622969618217455
# ===================
# L = 0.7300000000000004
# rho = 0.8629996547055122
# ===================
# L = 0.7400000000000004
# rho = 0.8637106893305085
# ===================
# L = 0.7500000000000004
# rho = 0.8644304993710274
# ===================
# L = 0.7600000000000005
# rho = 0.8651595793093911
# ===================
# L = 0.7700000000000005
# rho = 0.865898491158771
# ===================
# L = 0.7800000000000005
# rho = 0.8666478720544171
# ===================
# L = 0.7900000000000005
# rho = 0.8674084428378219
# ===================
# L = 0.8000000000000005
# rho = 0.8681810177770316
# ===================
# L = 0.8100000000000005
# rho = 0.8689665155878837
# ===================
# L = 0.8200000000000005
# rho = 0.869765971945866
# ===================
# L = 0.8300000000000005
# rho = 0.8705805537070317
# ===================
# L = 0.8400000000000005
# rho = 0.8714115750895992
# ===================
# L = 0.8500000000000005
# rho = 0.8722605161061712
# ===================
# L = 0.8600000000000005
# rho = 0.8731290435807788
# ===================
# L = 0.8700000000000006
# rho = 0.8740190351361954
# ===================
# L = 0.8800000000000006
# rho = 0.8749326065964554
# ===================
# L = 0.8900000000000006
# rho = 0.875872143318977
# ===================
# L = 0.9000000000000006
# rho = 0.8768403360524625
# ===================
# L = 0.9100000000000006
# rho = 0.8778402220143022
# ===================
# L = 0.9200000000000006
# rho = 0.87887523199968
# ===================
# L = 0.9300000000000006
# rho = 0.8799492444820831
# ===================
# L = 0.9400000000000006
# rho = 0.8810666478542942
# ===================
# L = 0.9500000000000006
# rho = 0.8822324122110541
# ===================
# L = 0.9600000000000006
# rho = 0.8834521724235722
# ===================
# L = 0.9700000000000006
# rho = 0.8847323247583214
# ===================
# L = 0.9800000000000006
# rho = 0.8860801400418657
# ===================
# L = 0.9900000000000007
# rho = 0.8875038975270607
# ===================
# L = 1.0000000000000007
# rho = 0.8890130454399321
# ===================
# ======Section 2======
# the 0 steps
# rho = 0.8906183971374277
# ===================
# the 1 steps
# rho = 0.8906167894532824
# ===================
# the 2 steps
# rho = 0.8906151822613071
# ===================
# the 3 steps
# rho = 0.8906135755611266
# ===================
# the 4 steps
# rho = 0.8906119693523654
# ===================
# the 5 steps
# rho = 0.8906103636346483
# ===================
# the 6 steps
# rho = 0.890608758407601
# ===================
# the 7 steps
# rho = 0.8906071536708492
# ===================
# the 8 steps
# rho = 0.8906055494240189
# ===================
# the 9 steps
# rho = 0.8906039456667367
# ===================
# the 10 steps
# rho = 0.8906023423986296
# ===================
# the 11 steps
# rho = 0.8906007396193245
# ===================
# the 12 steps
# rho = 0.8905991373284491
# ===================
# the 13 steps
# rho = 0.8905975355256316
# ===================
# the 14 steps
# rho = 0.8905959342105
# ===================
# the 15 steps
# rho = 0.890594333382683
# ===================
# the 16 steps
# rho = 0.8905927330418097
# ===================
# the 17 steps
# rho = 0.8905911331875095
# ===================
# the 18 steps
# rho = 0.8905895338194121
# ===================
# the 19 steps
# rho = 0.8905879349371476
# ===================
# the 20 steps
# rho = 0.8905863365403465
# ===================
# the 21 steps
# rho = 0.8905847386286396
# ===================
# the 22 steps
# rho = 0.8905831412016579
# ===================
# the 23 steps
# rho = 0.8905815442590335
# ===================
# the 24 steps
# rho = 0.8905799478003977
# ===================
# the 25 steps
# rho = 0.8905783518253831
# ===================
# the 26 steps
# rho = 0.890576756333622
# ===================
# the 27 steps
# rho = 0.8905751613247477
# ===================
# the 28 steps
# rho = 0.8905735667983933
# ===================
# the 29 steps
# rho = 0.8905719727541926
# ===================
# the 30 steps
# rho = 0.8905703791917797
# ===================
# the 31 steps
# rho = 0.8905687861107888
# ===================
# the 32 steps
# rho = 0.8905671935108548
# ===================
# the 33 steps
# rho = 0.8905656013916126
# ===================
# the 34 steps
# rho = 0.8905640097526979
# ===================
# the 35 steps
# rho = 0.8905624185937463
# ===================
# the 36 steps
# rho = 0.8905608279143941
# ===================
# the 37 steps
# rho = 0.8905592377142777
# ===================
# the 38 steps
# rho = 0.8905576479930339
# ===================
# the 39 steps
# rho = 0.8905560587503002
# ===================
# the 40 steps
# rho = 0.890554469985714
# ===================
# the 41 steps
# rho = 0.8905528816989131
# ===================
# the 42 steps
# rho = 0.8905512938895359
# ===================
# the 43 steps
# rho = 0.890549706557221
# ===================
# the 44 steps
# rho = 0.8905481197016074
# ===================
# the 45 steps
# rho = 0.8905465333223344
# ===================
# the 46 steps
# rho = 0.8905449474190416
# ===================
# the 47 steps
# rho = 0.890543361991369
# ===================
# the 48 steps
# rho = 0.890541777038957
# ===================
# the 49 steps
# rho = 0.8905401925614463
# ===================
# the 50 steps
# rho = 0.8905386085584781
# ===================
# the 51 steps
# rho = 0.8905370250296937
# ===================
# the 52 steps
# rho = 0.8905354419747346
# ===================
# the 53 steps
# rho = 0.8905338593932434
# ===================
# the 54 steps
# rho = 0.890532277284862
# ===================
# the 55 steps
# rho = 0.8905306956492336
# ===================
# the 56 steps
# rho = 0.8905291144860012
# ===================
# the 57 steps
# rho = 0.8905275337948083
# ===================
# the 58 steps
# rho = 0.8905259535752987
# ===================
# the 59 steps
# rho = 0.8905243738271165
# ===================
# the 60 steps
# rho = 0.8905227945499061
# ===================
# the 61 steps
# rho = 0.8905212157433129
# ===================
# the 62 steps
# rho = 0.8905196374069816
# ===================
# the 63 steps
# rho = 0.890518059540558
# ===================
# the 64 steps
# rho = 0.8905164821436875
# ===================
# the 65 steps
# rho = 0.890514905216017
# ===================
# the 66 steps
# rho = 0.8905133287571925
# ===================
# the 67 steps
# rho = 0.8905117527668611
# ===================
# the 68 steps
# rho = 0.8905101772446702
# ===================
# the 69 steps
# rho = 0.8905086021902674
# ===================
# the 70 steps
# rho = 0.8905070276033004
# ===================
# the 71 steps
# rho = 0.8905054534834175
# ===================
# the 72 steps
# rho = 0.8905038798302674
# ===================
# the 73 steps
# rho = 0.890502306643499
# ===================
# the 74 steps
# rho = 0.8905007339227616
# ===================
# the 75 steps
# rho = 0.890499161667705
# ===================
# the 76 steps
# rho = 0.8904975898779789
# ===================
# the 77 steps
# rho = 0.8904960185532336
# ===================
# the 78 steps
# rho = 0.8904944476931197
# ===================
# the 79 steps
# rho = 0.8904928772972884
# ===================
# the 80 steps
# rho = 0.890491307365391
# ===================
# the 81 steps
# rho = 0.8904897378970789
# ===================
# the 82 steps
# rho = 0.8904881688920042
# ===================
# the 83 steps
# rho = 0.8904866003498193
# ===================
# the 84 steps
# rho = 0.8904850322701767
# ===================
# the 85 steps
# rho = 0.8904834646527294
# ===================
# the 86 steps
# rho = 0.8904818974971308
# ===================
# the 87 steps
# rho = 0.8904803308030346
# ===================
# the 88 steps
# rho = 0.8904787645700946
# ===================
# the 89 steps
# rho = 0.8904771987979653
# ===================
# the 90 steps
# rho = 0.8904756334863011
# ===================
# the 91 steps
# rho = 0.8904740686347573
# ===================
# the 92 steps
# rho = 0.890472504242989
# ===================
# the 93 steps
# rho = 0.8904709403106518
# ===================
# the 94 steps
# rho = 0.8904693768374019
# ===================
# the 95 steps
# rho = 0.8904678138228953
# ===================
# the 96 steps
# rho = 0.890466251266789
# ===================
# the 97 steps
# rho = 0.8904646891687398
# ===================
# the 98 steps
# rho = 0.8904631275284048
# ===================
# the 99 steps
# rho = 0.8904615663454419
# ===================
# the 100 steps
# rho = 0.890460005619509
# ===================
# the 101 steps
# rho = 0.8904584453502642
# ===================
# the 102 steps
# rho = 0.8904568855373663
# ===================
# the 103 steps
# rho = 0.8904553261804742
# ===================
# the 104 steps
# rho = 0.8904537672792472
# ===================
# the 105 steps
# rho = 0.8904522088333447
# ===================
# the 106 steps
# rho = 0.8904506508424268
# ===================
# the 107 steps
# rho = 0.8904490933061537
# ===================
# the 108 steps
# rho = 0.8904475362241862
# ===================
# the 109 steps
# rho = 0.8904459795961848
# ===================
# the 110 steps
# rho = 0.8904444234218108
# ===================
# the 111 steps
# rho = 0.8904428677007261
# ===================
# the 112 steps
# rho = 0.8904413124325921
# ===================
# the 113 steps
# rho = 0.8904397576170715
# ===================
# the 114 steps
# rho = 0.8904382032538263
# ===================
# the 115 steps
# rho = 0.8904366493425195
# ===================
# the 116 steps
# rho = 0.8904350958828146
# ===================
# the 117 steps
# rho = 0.8904335428743749
# ===================
# the 118 steps
# rho = 0.890431990316864
# ===================
# the 119 steps
# rho = 0.8904304382099463
# ===================
# the 120 steps
# rho = 0.890428886553286
# ===================
# the 121 steps
# rho = 0.8904273353465482
# ===================
# the 122 steps
# rho = 0.8904257845893978
# ===================
# the 123 steps
# rho = 0.8904242342815003
# ===================
# the 124 steps
# rho = 0.8904226844225214
# ===================
# the 125 steps
# rho = 0.890421135012127
# ===================
# the 126 steps
# rho = 0.8904195860499838
# ===================
# the 127 steps
# rho = 0.8904180375357584
# ===================
# the 128 steps
# rho = 0.8904164894691178
# ===================
# the 129 steps
# rho = 0.8904149418497291
# ===================
# the 130 steps
# rho = 0.8904133946772603
# ===================
# the 131 steps
# rho = 0.8904118479513792
# ===================
# the 132 steps
# rho = 0.8904103016717542
# ===================
# the 133 steps
# rho = 0.8904087558380538
# ===================
# the 134 steps
# rho = 0.8904072104499471
# ===================
# the 135 steps
# rho = 0.8904056655071031
# ===================
# the 136 steps
# rho = 0.8904041210091914
# ===================
# the 137 steps
# rho = 0.8904025769558821
# ===================
# the 138 steps
# rho = 0.8904010333468452
# ===================
# the 139 steps
# rho = 0.8903994901817512
# ===================
# the 140 steps
# rho = 0.890397947460271
# ===================
# the 141 steps
# rho = 0.8903964051820759
# ===================
# the 142 steps
# rho = 0.8903948633468369
# ===================
# the 143 steps
# rho = 0.8903933219542263
# ===================
# the 144 steps
# rho = 0.8903917810039157
# ===================
# the 145 steps
# rho = 0.8903902404955778
# ===================
# the 146 steps
# rho = 0.8903887004288852
# ===================
# the 147 steps
# rho = 0.8903871608035109
# ===================
# the 148 steps
# rho = 0.8903856216191282
# ===================
# the 149 steps
# rho = 0.8903840828754109
# ===================
# the 150 steps
# rho = 0.8903825445720327
# ===================
# the 151 steps
# rho = 0.8903810067086683
# ===================
# the 152 steps
# rho = 0.8903794692849918
# ===================
# the 153 steps
# rho = 0.8903779323006782
# ===================
# the 154 steps
# rho = 0.8903763957554027
# ===================
# the 155 steps
# rho = 0.890374859648841
# ===================
# the 156 steps
# rho = 0.8903733239806688
# ===================
# the 157 steps
# rho = 0.8903717887505621
# ===================
# the 158 steps
# rho = 0.8903702539581976
# ===================
# the 159 steps
# rho = 0.8903687196032518
# ===================
# the 160 steps
# rho = 0.8903671856854019
# ===================
# the 161 steps
# rho = 0.890365652204325
# ===================
# the 162 steps
# rho = 0.890364119159699
# ===================
# the 163 steps
# rho = 0.8903625865512019
# ===================
# the 164 steps
# rho = 0.890361054378512
# ===================
# the 165 steps
# rho = 0.8903595226413077
# ===================
# the 166 steps
# rho = 0.8903579913392679
# ===================
# the 167 steps
# rho = 0.8903564604720718
# ===================
# the 168 steps
# rho = 0.8903549300393993
# ===================
# the 169 steps
# rho = 0.8903534000409296
# ===================
# the 170 steps
# rho = 0.8903518704763431
# ===================
# the 171 steps
# rho = 0.8903503413453202
# ===================
# the 172 steps
# rho = 0.8903488126475417
# ===================
# the 173 steps
# rho = 0.8903472843826885
# ===================
# the 174 steps
# rho = 0.8903457565504422
# ===================
# the 175 steps
# rho = 0.8903442291504841
# ===================
# the 176 steps
# rho = 0.890342702182496
# ===================
# the 177 steps
# rho = 0.8903411756461607
# ===================
# the 178 steps
# rho = 0.8903396495411602
# ===================
# the 179 steps
# rho = 0.8903381238671777
# ===================
# the 180 steps
# rho = 0.8903365986238962
# ===================
# the 181 steps
# rho = 0.8903350738109991
# ===================
# the 182 steps
# rho = 0.8903335494281702
# ===================
# the 183 steps
# rho = 0.8903320254750934
# ===================
# the 184 steps
# rho = 0.8903305019514535
# ===================
# the 185 steps
# rho = 0.8903289788569346
# ===================
# the 186 steps
# rho = 0.8903274561912218
# ===================
# the 187 steps
# rho = 0.8903259339540006
# ===================
# the 188 steps
# rho = 0.8903244121449563
# ===================
# the 189 steps
# rho = 0.8903228907637747
# ===================
# the 190 steps
# rho = 0.8903213698101421
# ===================
# the 191 steps
# rho = 0.890319849283745
# ===================
# the 192 steps
# rho = 0.8903183291842698
# ===================
# the 193 steps
# rho = 0.8903168095114038
# ===================
# the 194 steps
# rho = 0.8903152902648341
# ===================
# the 195 steps
# rho = 0.8903137714442488
# ===================
# the 196 steps
# rho = 0.8903122530493354
# ===================
# the 197 steps
# rho = 0.8903107350797822
# ===================
# the 198 steps
# rho = 0.8903092175352777
# ===================
# the 199 steps
# rho = 0.8903077004155108
# ===================
# the 200 steps
# rho = 0.8903061837201706
# ===================
# the 201 steps
# rho = 0.8903046674489464
# ===================
# the 202 steps
# rho = 0.8903031516015278
# ===================
# the 203 steps
# rho = 0.8903016361776052
# ===================
# the 204 steps
# rho = 0.8903001211768685
# ===================
# the 205 steps
# rho = 0.8902986065990085
# ===================
# the 206 steps
# rho = 0.8902970924437158
# ===================
# the 207 steps
# rho = 0.8902955787106819
# ===================
# the 208 steps
# rho = 0.8902940653995979
# ===================
# the 209 steps
# rho = 0.8902925525101557
# ===================
# the 210 steps
# rho = 0.8902910400420474
# ===================
# the 211 steps
# rho = 0.8902895279949653
# ===================
# the 212 steps
# rho = 0.890288016368602
# ===================
# the 213 steps
# rho = 0.8902865051626504
# ===================
# the 214 steps
# rho = 0.8902849943768038
# ===================
# the 215 steps
# rho = 0.8902834840107554
# ===================
# the 216 steps
# rho = 0.8902819740641993
# ===================
# the 217 steps
# rho = 0.8902804645368295
# ===================
# the 218 steps
# rho = 0.8902789554283402
# ===================
# the 219 steps
# rho = 0.8902774467384263
# ===================
# the 220 steps
# rho = 0.8902759384667825
# ===================
# the 221 steps
# rho = 0.8902744306131042
# ===================
# the 222 steps
# rho = 0.8902729231770867
# ===================
# the 223 steps
# rho = 0.8902714161584262
# ===================
# the 224 steps
# rho = 0.8902699095568184
# ===================
# the 225 steps
# rho = 0.8902684033719598
# ===================
# the 226 steps
# rho = 0.890266897603547
# ===================
# the 227 steps
# rho = 0.8902653922512772
# ===================
# the 228 steps
# rho = 0.8902638873148474
# ===================
# the 229 steps
# rho = 0.8902623827939552
# ===================
# the 230 steps
# rho = 0.8902608786882983
# ===================
# the 231 steps
# rho = 0.8902593749975749
# ===================
# the 232 steps
# rho = 0.8902578717214835
# ===================
# the 233 steps
# rho = 0.8902563688597226
# ===================
# the 234 steps
# rho = 0.8902548664119911
# ===================
# the 235 steps
# rho = 0.8902533643779884
# ===================
# the 236 steps
# rho = 0.8902518627574139
# ===================
# the 237 steps
# rho = 0.8902503615499673
# ===================
# the 238 steps
# rho = 0.8902488607553489
# ===================
# the 239 steps
# rho = 0.8902473603732589
# ===================
# the 240 steps
# rho = 0.8902458604033981
# ===================
# the 241 steps
# rho = 0.8902443608454673
# ===================
# the 242 steps
# rho = 0.890242861699168
# ===================
# the 243 steps
# rho = 0.8902413629642011
# ===================
# the 244 steps
# rho = 0.8902398646402689
# ===================
# the 245 steps
# rho = 0.8902383667270732
# ===================
# the 246 steps
# rho = 0.8902368692243167
# ===================
# the 247 steps
# rho = 0.8902353721317013
# ===================
# the 248 steps
# rho = 0.8902338754489306
# ===================
# the 249 steps
# rho = 0.8902323791757075
# ===================
# the 250 steps
# rho = 0.8902308833117354
# ===================
# the 251 steps
# rho = 0.8902293878567181
# ===================
# the 252 steps
# rho = 0.8902278928103597
# ===================
# the 253 steps
# rho = 0.8902263981723645
# ===================
# the 254 steps
# rho = 0.8902249039424368
# ===================
# the 255 steps
# rho = 0.8902234101202817
# ===================
# the 256 steps
# rho = 0.8902219167056044
# ===================
# the 257 steps
# rho = 0.8902204236981098
# ===================
# the 258 steps
# rho = 0.8902189310975043
# ===================
# the 259 steps
# rho = 0.8902174389034933
# ===================
# the 260 steps
# rho = 0.8902159471157833
# ===================
# the 261 steps
# rho = 0.8902144557340808
# ===================
# the 262 steps
# rho = 0.8902129647580924
# ===================
# the 263 steps
# rho = 0.8902114741875254
# ===================
# the 264 steps
# rho = 0.8902099840220871
# ===================
# the 265 steps
# rho = 0.8902084942614849
# ===================
# the 266 steps
# rho = 0.890207004905427
# ===================
# the 267 steps
# rho = 0.8902055159536213
# ===================
# the 268 steps
# rho = 0.8902040274057763
# ===================
# the 269 steps
# rho = 0.8902025392616009
# ===================
# the 270 steps
# rho = 0.8902010515208039
# ===================
# the 271 steps
# rho = 0.8901995641830944
# ===================
# the 272 steps
# rho = 0.8901980772481822
# ===================
# the 273 steps
# rho = 0.8901965907157772
# ===================
# the 274 steps
# rho = 0.8901951045855893
# ===================
# the 275 steps
# rho = 0.8901936188573286
# ===================
# the 276 steps
# rho = 0.890192133530706
# ===================
# the 277 steps
# rho = 0.8901906486054325
# ===================
# the 278 steps
# rho = 0.8901891640812192
# ===================
# the 279 steps
# rho = 0.8901876799577773
# ===================
# the 280 steps
# rho = 0.8901861962348188
# ===================
# the 281 steps
# rho = 0.8901847129120551
# ===================
# the 282 steps
# rho = 0.8901832299891993
# ===================
# the 283 steps
# rho = 0.8901817474659633
# ===================
# the 284 steps
# rho = 0.8901802653420601
# ===================
# the 285 steps
# rho = 0.8901787836172027
# ===================
# the 286 steps
# rho = 0.8901773022911046
# ===================
# the 287 steps
# rho = 0.8901758213634791
# ===================
# the 288 steps
# rho = 0.8901743408340402
# ===================
# the 289 steps
# rho = 0.890172860702502
# ===================
# the 290 steps
# rho = 0.890171380968579
# ===================
# the 291 steps
# rho = 0.8901699016319857
# ===================
# the 292 steps
# rho = 0.890168422692437
# ===================
# the 293 steps
# rho = 0.8901669441496484
# ===================
# the 294 steps
# rho = 0.8901654660033351
# ===================
# the 295 steps
# rho = 0.8901639882532127
# ===================
# the 296 steps
# rho = 0.8901625108989976
# ===================
# the 297 steps
# rho = 0.8901610339404057
# ===================
# the 298 steps
# rho = 0.8901595573771538
# ===================
# the 299 steps
# rho = 0.8901580812089586
# ===================
# the 300 steps
# rho = 0.890156605435537
# ===================
# the 301 steps
# rho = 0.8901551300566063
# ===================
# the 302 steps
# rho = 0.8901536550718844
# ===================
# the 303 steps
# rho = 0.8901521804810889
# ===================
# the 304 steps
# rho = 0.8901507062839379
# ===================
# the 305 steps
# rho = 0.8901492324801499
# ===================
# the 306 steps
# rho = 0.8901477590694435
# ===================
# the 307 steps
# rho = 0.8901462860515377
# ===================
# the 308 steps
# rho = 0.8901448134261515
# ===================
# the 309 steps
# rho = 0.8901433411930044
# ===================
# the 310 steps
# rho = 0.8901418693518159
# ===================
# the 311 steps
# rho = 0.8901403979023063
# ===================
# the 312 steps
# rho = 0.8901389268441956
# ===================
# the 313 steps
# rho = 0.8901374561772043
# ===================
# the 314 steps
# rho = 0.8901359859010531
# ===================
# the 315 steps
# rho = 0.890134516015463
# ===================
# the 316 steps
# rho = 0.8901330465201555
# ===================
# the 317 steps
# rho = 0.8901315774148518
# ===================
# the 318 steps
# rho = 0.8901301086992738
# ===================
# the 319 steps
# rho = 0.8901286403731433
# ===================
# the 320 steps
# rho = 0.8901271724361831
# ===================
# the 321 steps
# rho = 0.8901257048881153
# ===================
# the 322 steps
# rho = 0.8901242377286629
# ===================
# the 323 steps
# rho = 0.8901227709575489
# ===================
# the 324 steps
# rho = 0.8901213045744968
# ===================
# the 325 steps
# rho = 0.89011983857923
# ===================
# the 326 steps
# rho = 0.8901183729714723
# ===================
# the 327 steps
# rho = 0.8901169077509481
# ===================
# the 328 steps
# rho = 0.8901154429173815
# ===================
# the 329 steps
# rho = 0.8901139784704972
# ===================
# the 330 steps
# rho = 0.89011251441002
# ===================
# the 331 steps
# rho = 0.8901110507356751
# ===================
# the 332 steps
# rho = 0.8901095874471879
# ===================
# the 333 steps
# rho = 0.8901081245442839
# ===================
# the 334 steps
# rho = 0.8901066620266892
# ===================
# the 335 steps
# rho = 0.8901051998941298
# ===================
# the 336 steps
# rho = 0.890103738146332
# ===================
# the 337 steps
# rho = 0.8901022767830229
# ===================
# the 338 steps
# rho = 0.8901008158039289
# ===================
# the 339 steps
# rho = 0.8900993552087775
# ===================
# the 340 steps
# rho = 0.890097894997296
# ===================
# the 341 steps
# rho = 0.8900964351692119
# ===================
# the 342 steps
# rho = 0.8900949757242534
# ===================
# the 343 steps
# rho = 0.8900935166621486
# ===================
# the 344 steps
# rho = 0.8900920579826261
# ===================
# the 345 steps
# rho = 0.8900905996854143
# ===================
# the 346 steps
# rho = 0.8900891417702422
# ===================
# the 347 steps
# rho = 0.8900876842368391
# ===================
# the 348 steps
# rho = 0.8900862270849345
# ===================
# the 349 steps
# rho = 0.8900847703142578
# ===================
# the 350 steps
# rho = 0.8900833139245391
# ===================
# the 351 steps
# rho = 0.8900818579155088
# ===================
# the 352 steps
# rho = 0.890080402286897
# ===================
# the 353 steps
# rho = 0.8900789470384347
# ===================
# the 354 steps
# rho = 0.8900774921698525
# ===================
# the 355 steps
# rho = 0.890076037680882
# ===================
# the 356 steps
# rho = 0.8900745835712544
# ===================
# the 357 steps
# rho = 0.8900731298407013
# ===================
# the 358 steps
# rho = 0.8900716764889549
# ===================
# the 359 steps
# rho = 0.8900702235157472
# ===================
# the 360 steps
# rho = 0.8900687709208108
# ===================
# the 361 steps
# rho = 0.8900673187038783
# ===================
# the 362 steps
# rho = 0.8900658668646826
# ===================
# the 363 steps
# rho = 0.8900644154029569
# ===================
# the 364 steps
# rho = 0.8900629643184347
# ===================
# the 365 steps
# rho = 0.8900615136108496
# ===================
# the 366 steps
# rho = 0.8900600632799356
# ===================
# the 367 steps
# rho = 0.8900586133254267
# ===================
# the 368 steps
# rho = 0.8900571637470577
# ===================
# the 369 steps
# rho = 0.8900557145445628
# ===================
# the 370 steps
# rho = 0.8900542657176771
# ===================
# the 371 steps
# rho = 0.8900528172661358
# ===================
# the 372 steps
# rho = 0.8900513691896743
# ===================
# the 373 steps
# rho = 0.8900499214880283
# ===================
# the 374 steps
# rho = 0.8900484741609336
# ===================
# the 375 steps
# rho = 0.8900470272081262
# ===================
# the 376 steps
# rho = 0.8900455806293428
# ===================
# the 377 steps
# rho = 0.8900441344243197
# ===================
# the 378 steps
# rho = 0.8900426885927941
# ===================
# the 379 steps
# rho = 0.8900412431345028
# ===================
# the 380 steps
# rho = 0.8900397980491833
# ===================
# the 381 steps
# rho = 0.8900383533365731
# ===================
# the 382 steps
# rho = 0.8900369089964102
# ===================
# the 383 steps
# rho = 0.8900354650284326
# ===================
# the 384 steps
# rho = 0.8900340214323785
# ===================
# the 385 steps
# rho = 0.8900325782079869
# ===================
# the 386 steps
# rho = 0.8900311353549959
# ===================
# the 387 steps
# rho = 0.8900296928731452
# ===================
# the 388 steps
# rho = 0.8900282507621737
# ===================
# the 389 steps
# rho = 0.8900268090218211
# ===================
# the 390 steps
# rho = 0.8900253676518272
# ===================
# the 391 steps
# rho = 0.8900239266519319
# ===================
# the 392 steps
# rho = 0.8900224860218754
# ===================
# the 393 steps
# rho = 0.8900210457613982
# ===================
# the 394 steps
# rho = 0.8900196058702413
# ===================
# the 395 steps
# rho = 0.8900181663481455
# ===================
# the 396 steps
# rho = 0.8900167271948519
# ===================
# the 397 steps
# rho = 0.890015288410102
# ===================
# the 398 steps
# rho = 0.8900138499936375
# ===================
# the 399 steps
# rho = 0.8900124119452005
# ===================
# the 400 steps
# rho = 0.8900109742645329
# ===================
# the 401 steps
# rho = 0.8900095369513773
# ===================
# the 402 steps
# rho = 0.8900081000054761
# ===================
# the 403 steps
# rho = 0.8900066634265724
# ===================
# the 404 steps
# rho = 0.8900052272144093
# ===================
# the 405 steps
# rho = 0.89000379136873
# ===================
# the 406 steps
# rho = 0.8900023558892783
# ===================
# the 407 steps
# rho = 0.8900009207757977
# ===================
# the 408 steps
# rho = 0.8899994860280327
# ===================
# the 409 steps
# rho = 0.8899980516457272
# ===================
# the 410 steps
# rho = 0.8899966176286259
# ===================
# the 411 steps
# rho = 0.8899951839764734
# ===================
# the 412 steps
# rho = 0.889993750689015
# ===================
# the 413 steps
# rho = 0.8899923177659957
# ===================
# the 414 steps
# rho = 0.8899908852071612
# ===================
# the 415 steps
# rho = 0.8899894530122568
# ===================
# the 416 steps
# rho = 0.8899880211810288
# ===================
# the 417 steps
# rho = 0.8899865897132233
# ===================
# the 418 steps
# rho = 0.8899851586085867
# ===================
# the 419 steps
# rho = 0.8899837278668654
# ===================
# the 420 steps
# rho = 0.8899822974878067
# ===================
# the 421 steps
# rho = 0.8899808674711573
# ===================
# the 422 steps
# rho = 0.8899794378166648
# ===================
# the 423 steps
# rho = 0.8899780085240766
# ===================
# the 424 steps
# rho = 0.8899765795931406
# ===================
# the 425 steps
# rho = 0.8899751510236049
# ===================
# the 426 steps
# rho = 0.8899737228152176
# ===================
# the 427 steps
# rho = 0.8899722949677272
# ===================
# the 428 steps
# rho = 0.8899708674808826
# ===================
# the 429 steps
# rho = 0.8899694403544325
# ===================
# the 430 steps
# rho = 0.8899680135881264
# ===================
# the 431 steps
# rho = 0.8899665871817135
# ===================
# the 432 steps
# rho = 0.8899651611349435
# ===================
# the 433 steps
# rho = 0.8899637354475664
# ===================
# the 434 steps
# rho = 0.889962310119332
# ===================
# the 435 steps
# rho = 0.8899608851499909
# ===================
# the 436 steps
# rho = 0.8899594605392936
# ===================
# the 437 steps
# rho = 0.8899580362869909
# ===================
# the 438 steps
# rho = 0.8899566123928339
# ===================
# the 439 steps
# rho = 0.8899551888565737
# ===================
# the 440 steps
# rho = 0.8899537656779618
# ===================
# the 441 steps
# rho = 0.88995234285675
# ===================
# the 442 steps
# rho = 0.8899509203926902
# ===================
# the 443 steps
# rho = 0.8899494982855344
# ===================
# the 444 steps
# rho = 0.8899480765350354
# ===================
# the 445 steps
# rho = 0.8899466551409454
# ===================
# the 446 steps
# rho = 0.8899452341030175
# ===================
# the 447 steps
# rho = 0.8899438134210046
# ===================
# the 448 steps
# rho = 0.8899423930946602
# ===================
# the 449 steps
# rho = 0.8899409731237375
# ===================
# the 450 steps
# rho = 0.8899395535079906
# ===================
# the 451 steps
# rho = 0.8899381342471733
# ===================
# the 452 steps
# rho = 0.8899367153410398
# ===================
# the 453 steps
# rho = 0.8899352967893446
# ===================
# the 454 steps
# rho = 0.8899338785918423
# ===================
# the 455 steps
# rho = 0.8899324607482876
# ===================
# the 456 steps
# rho = 0.8899310432584359
# ===================
# the 457 steps
# rho = 0.8899296261220424
# ===================
# the 458 steps
# rho = 0.8899282093388625
# ===================
# the 459 steps
# rho = 0.8899267929086523
# ===================
# the 460 steps
# rho = 0.8899253768311676
# ===================
# the 461 steps
# rho = 0.8899239611061643
# ===================
# the 462 steps
# rho = 0.8899225457333995
# ===================
# the 463 steps
# rho = 0.8899211307126293
# ===================
# the 464 steps
# rho = 0.889919716043611
# ===================
# the 465 steps
# rho = 0.8899183017261014
# ===================
# the 466 steps
# rho = 0.8899168877598579
# ===================
# the 467 steps
# rho = 0.8899154741446382
# ===================
# the 468 steps
# rho = 0.8899140608801999
# ===================
# the 469 steps
# rho = 0.8899126479663011
# ===================
# the 470 steps
# rho = 0.8899112354026999
# ===================
# the 471 steps
# rho = 0.8899098231891548
# ===================
# the 472 steps
# rho = 0.8899084113254245
# ===================
# the 473 steps
# rho = 0.8899069998112678
# ===================
# the 474 steps
# rho = 0.8899055886464438
# ===================
# the 475 steps
# rho = 0.889904177830712
# ===================
# the 476 steps
# rho = 0.8899027673638316
# ===================
# the 477 steps
# rho = 0.8899013572455626
# ===================
# the 478 steps
# rho = 0.8898999474756649
# ===================
# the 479 steps
# rho = 0.8898985380538987
# ===================
# the 480 steps
# rho = 0.8898971289800245
# ===================
# the 481 steps
# rho = 0.8898957202538028
# ===================
# the 482 steps
# rho = 0.8898943118749943
# ===================
# the 483 steps
# rho = 0.8898929038433606
# ===================
# the 484 steps
# rho = 0.8898914961586625
# ===================
# the 485 steps
# rho = 0.8898900888206616
# ===================
# the 486 steps
# rho = 0.8898886818291197
# ===================
# the 487 steps
# rho = 0.8898872751837988
# ===================
# the 488 steps
# rho = 0.8898858688844608
# ===================
# the 489 steps
# rho = 0.8898844629308684
# ===================
# the 490 steps
# rho = 0.8898830573227838
# ===================
# the 491 steps
# rho = 0.8898816520599702
# ===================
# the 492 steps
# rho = 0.8898802471421903
# ===================
# the 493 steps
# rho = 0.8898788425692076
# ===================
# the 494 steps
# rho = 0.8898774383407853
# ===================
# the 495 steps
# rho = 0.8898760344566872
# ===================
# the 496 steps
# rho = 0.8898746309166772
# ===================
# the 497 steps
# rho = 0.8898732277205195
# ===================
# the 498 steps
# rho = 0.8898718248679781
# ===================
# the 499 steps
# rho = 0.8898704223588179
# ===================
# the 500 steps
# rho = 0.8898690201928031
# ===================
# the 501 steps
# rho = 0.8898676183696992
# ===================
# the 502 steps
# rho = 0.8898662168892711
# ===================
# the 503 steps
# rho = 0.8898648157512842
# ===================
# the 504 steps
# rho = 0.8898634149555043
# ===================
# the 505 steps
# rho = 0.8898620145016969
# ===================
# the 506 steps
# rho = 0.889860614389628
# ===================
# the 507 steps
# rho = 0.8898592146190643
# ===================
# the 508 steps
# rho = 0.8898578151897717
# ===================
# the 509 steps
# rho = 0.8898564161015171
# ===================
# the 510 steps
# rho = 0.8898550173540674
# ===================
# the 511 steps
# rho = 0.8898536189471895
# ===================
# the 512 steps
# rho = 0.889852220880651
# ===================
# the 513 steps
# rho = 0.8898508231542192
# ===================
# the 514 steps
# rho = 0.8898494257676617
# ===================
# the 515 steps
# rho = 0.8898480287207466
# ===================
# the 516 steps
# rho = 0.889846632013242
# ===================
# the 517 steps
# rho = 0.8898452356449162
# ===================
# the 518 steps
# rho = 0.8898438396155379
# ===================
# the 519 steps
# rho = 0.8898424439248758
# ===================
# the 520 steps
# rho = 0.8898410485726986
# ===================
# the 521 steps
# rho = 0.8898396535587759
# ===================
# the 522 steps
# rho = 0.8898382588828768
# ===================
# the 523 steps
# rho = 0.8898368645447712
# ===================
# the 524 steps
# rho = 0.8898354705442285
# ===================
# the 525 steps
# rho = 0.889834076881019
# ===================
# the 526 steps
# rho = 0.8898326835549129
# ===================
# the 527 steps
# rho = 0.8898312905656806
# ===================
# the 528 steps
# rho = 0.8898298979130927
# ===================
# the 529 steps
# rho = 0.8898285055969202
# ===================
# the 530 steps
# rho = 0.889827113616934
# ===================
# the 531 steps
# rho = 0.8898257219729054
# ===================
# the 532 steps
# rho = 0.889824330664606
# ===================
# the 533 steps
# rho = 0.8898229396918073
# ===================
# the 534 steps
# rho = 0.8898215490542813
# ===================
# the 535 steps
# rho = 0.8898201587518001
# ===================
# the 536 steps
# rho = 0.8898187687841359
# ===================
# the 537 steps
# rho = 0.8898173791510614
# ===================
# the 538 steps
# rho = 0.889815989852349
# ===================
# the 539 steps
# rho = 0.889814600887772
# ===================
# the 540 steps
# rho = 0.8898132122571032
# ===================
# the 541 steps
# rho = 0.889811823960116
# ===================
# the 542 steps
# rho = 0.8898104359965842
# ===================
# the 543 steps
# rho = 0.8898090483662812
# ===================
# the 544 steps
# rho = 0.889807661068981
# ===================
# the 545 steps
# rho = 0.8898062741044579
# ===================
# the 546 steps
# rho = 0.8898048874724861
# ===================
# the 547 steps
# rho = 0.8898035011728402
# ===================
# the 548 steps
# rho = 0.8898021152052951
# ===================
# the 549 steps
# rho = 0.8898007295696256
# ===================
# the 550 steps
# rho = 0.8897993442656068
# ===================
# the 551 steps
# rho = 0.8897979592930144
# ===================
# the 552 steps
# rho = 0.8897965746516235
# ===================
# the 553 steps
# rho = 0.8897951903412102
# ===================
# the 554 steps
# rho = 0.8897938063615504
# ===================
# the 555 steps
# rho = 0.8897924227124203
# ===================
# the 556 steps
# rho = 0.8897910393935962
# ===================
# the 557 steps
# rho = 0.8897896564048547
# ===================
# the 558 steps
# rho = 0.8897882737459727
# ===================
# the 559 steps
# rho = 0.8897868914167271
# ===================
# the 560 steps
# rho = 0.889785509416895
# ===================
# the 561 steps
# rho = 0.8897841277462539
# ===================
# the 562 steps
# rho = 0.8897827464045814
# ===================
# the 563 steps
# rho = 0.8897813653916553
# ===================
# the 564 steps
# rho = 0.8897799847072535
# ===================
# the 565 steps
# rho = 0.8897786043511541
# ===================
# the 566 steps
# rho = 0.8897772243231357
# ===================
# the 567 steps
# rho = 0.8897758446229767
# ===================
# the 568 steps
# rho = 0.889774465250456
# ===================
# the 569 steps
# rho = 0.8897730862053527
# ===================
# the 570 steps
# rho = 0.8897717074874456
# ===================
# the 571 steps
# rho = 0.8897703290965145
# ===================
# the 572 steps
# rho = 0.8897689510323389
# ===================
# the 573 steps
# rho = 0.8897675732946984
# ===================
# the 574 steps
# rho = 0.889766195883373
# ===================
# the 575 steps
# rho = 0.8897648187981431
# ===================
# the 576 steps
# rho = 0.8897634420387889
# ===================
# the 577 steps
# rho = 0.889762065605091
# ===================
# the 578 steps
# rho = 0.8897606894968301
# ===================
# the 579 steps
# rho = 0.8897593137137872
# ===================
# the 580 steps
# rho = 0.8897579382557436
# ===================
# the 581 steps
# rho = 0.8897565631224804
# ===================
# the 582 steps
# rho = 0.8897551883137795
# ===================
# the 583 steps
# rho = 0.8897538138294225
# ===================
# the 584 steps
# rho = 0.8897524396691912
# ===================
# the 585 steps
# rho = 0.8897510658328678
# ===================
# the 586 steps
# rho = 0.8897496923202349
# ===================
# the 587 steps
# rho = 0.8897483191310748
# ===================
# the 588 steps
# rho = 0.8897469462651701
# ===================
# the 589 steps
# rho = 0.8897455737223041
# ===================
# the 590 steps
# rho = 0.8897442015022596
# ===================
# the 591 steps
# rho = 0.8897428296048201
# ===================
# the 592 steps
# rho = 0.889741458029769
# ===================
# the 593 steps
# rho = 0.8897400867768902
# ===================
# the 594 steps
# rho = 0.8897387158459673
# ===================
# the 595 steps
# rho = 0.8897373452367847
# ===================
# the 596 steps
# rho = 0.8897359749491264
# ===================
# the 597 steps
# rho = 0.889734604982777
# ===================
# the 598 steps
# rho = 0.8897332353375214
# ===================
# the 599 steps
# rho = 0.889731866013144
# ===================
# the 600 steps
# rho = 0.8897304970094302
# ===================
# the 601 steps
# rho = 0.8897291283261652
# ===================
# the 602 steps
# rho = 0.8897277599631345
# ===================
# the 603 steps
# rho = 0.8897263919201235
# ===================
# the 604 steps
# rho = 0.8897250241969183
# ===================
# the 605 steps
# rho = 0.8897236567933048
# ===================
# the 606 steps
# rho = 0.8897222897090691
# ===================
# the 607 steps
# rho = 0.8897209229439977
# ===================
# the 608 steps
# rho = 0.8897195564978774
# ===================
# the 609 steps
# rho = 0.8897181903704947
# ===================
# the 610 steps
# rho = 0.8897168245616367
# ===================
# the 611 steps
# rho = 0.8897154590710905
# ===================
# the 612 steps
# rho = 0.8897140938986435
# ===================
# the 613 steps
# rho = 0.8897127290440834
# ===================
# the 614 steps
# rho = 0.8897113645071976
# ===================
# the 615 steps
# rho = 0.8897100002877744
# ===================
# the 616 steps
# rho = 0.8897086363856016
# ===================
# the 617 steps
# rho = 0.8897072728004678
# ===================
# the 618 steps
# rho = 0.8897059095321613
# ===================
# the 619 steps
# rho = 0.8897045465804707
# ===================
# the 620 steps
# rho = 0.8897031839451852
# ===================
# the 621 steps
# rho = 0.8897018216260936
# ===================
# the 622 steps
# rho = 0.8897004596229852
# ===================
# the 623 steps
# rho = 0.8896990979356495
# ===================
# the 624 steps
# rho = 0.8896977365638761
# ===================
# the 625 steps
# rho = 0.8896963755074548
# ===================
# the 626 steps
# rho = 0.8896950147661757
# ===================
# the 627 steps
# rho = 0.8896936543398289
# ===================
# the 628 steps
# rho = 0.8896922942282047
# ===================
# the 629 steps
# rho = 0.8896909344310938
# ===================
# the 630 steps
# rho = 0.8896895749482869
# ===================
# the 631 steps
# rho = 0.8896882157795751
# ===================
# the 632 steps
# rho = 0.8896868569247492
# ===================
# the 633 steps
# rho = 0.8896854983836009
# ===================
# the 634 steps
# rho = 0.8896841401559212
# ===================
# the 635 steps
# rho = 0.8896827822415024
# ===================
# the 636 steps
# rho = 0.8896814246401359
# ===================
# the 637 steps
# rho = 0.889680067351614
# ===================
# the 638 steps
# rho = 0.8896787103757288
# ===================
# the 639 steps
# rho = 0.8896773537122729
# ===================
# the 640 steps
# rho = 0.8896759973610386
# ===================
# the 641 steps
# rho = 0.8896746413218191
# ===================
# the 642 steps
# rho = 0.889673285594407
# ===================
# the 643 steps
# rho = 0.8896719301785957
# ===================
# the 644 steps
# rho = 0.8896705750741785
# ===================
# the 645 steps
# rho = 0.8896692202809491
# ===================
# the 646 steps
# rho = 0.8896678657987007
# ===================
# the 647 steps
# rho = 0.8896665116272278
# ===================
# the 648 steps
# rho = 0.8896651577663242
# ===================
# the 649 steps
# rho = 0.8896638042157843
# ===================
# the 650 steps
# rho = 0.8896624509754023
# ===================
# the 651 steps
# rho = 0.8896610980449731
# ===================
# the 652 steps
# rho = 0.8896597454242914
# ===================
# the 653 steps
# rho = 0.8896583931131523
# ===================
# the 654 steps
# rho = 0.8896570411113508
# ===================
# the 655 steps
# rho = 0.8896556894186824
# ===================
# the 656 steps
# rho = 0.8896543380349426
# ===================
# the 657 steps
# rho = 0.8896529869599273
# ===================
# the 658 steps
# rho = 0.8896516361934321
# ===================
# the 659 steps
# rho = 0.8896502857352532
# ===================
# the 660 steps
# rho = 0.8896489355851871
# ===================
# the 661 steps
# rho = 0.88964758574303
# ===================
# the 662 steps
# rho = 0.8896462362085786
# ===================
# the 663 steps
# rho = 0.8896448869816298
# ===================
# the 664 steps
# rho = 0.8896435380619805
# ===================
# the 665 steps
# rho = 0.8896421894494279
# ===================
# the 666 steps
# rho = 0.8896408411437694
# ===================
# the 667 steps
# rho = 0.8896394931448024
# ===================
# the 668 steps
# rho = 0.8896381454523249
# ===================
# the 669 steps
# rho = 0.8896367980661345
# ===================
# the 670 steps
# rho = 0.8896354509860294
# ===================
# the 671 steps
# rho = 0.8896341042118078
# ===================
# the 672 steps
# rho = 0.8896327577432682
# ===================
# the 673 steps
# rho = 0.8896314115802093
# ===================
# the 674 steps
# rho = 0.8896300657224298
# ===================
# the 675 steps
# rho = 0.8896287201697285
# ===================
# the 676 steps
# rho = 0.8896273749219048
# ===================
# the 677 steps
# rho = 0.889626029978758
# ===================
# the 678 steps
# rho = 0.8896246853400874
# ===================
# the 679 steps
# rho = 0.889623341005693
# ===================
# the 680 steps
# rho = 0.8896219969753743
# ===================
# the 681 steps
# rho = 0.8896206532489316
# ===================
# the 682 steps
# rho = 0.889619309826165
# ===================
# the 683 steps
# rho = 0.889617966706875
# ===================
# the 684 steps
# rho = 0.889616623890862
# ===================
# the 685 steps
# rho = 0.8896152813779269
# ===================
# the 686 steps
# rho = 0.8896139391678705
# ===================
# the 687 steps
# rho = 0.8896125972604939
# ===================
# the 688 steps
# rho = 0.8896112556555987
# ===================
# the 689 steps
# rho = 0.8896099143529859
# ===================
# the 690 steps
# rho = 0.8896085733524571
# ===================
# the 691 steps
# rho = 0.8896072326538147
# ===================
# the 692 steps
# rho = 0.88960589225686
# ===================
# the 693 steps
# rho = 0.8896045521613956
# ===================
# the 694 steps
# rho = 0.8896032123672236
# ===================
# the 695 steps
# rho = 0.8896018728741464
# ===================
# the 696 steps
# rho = 0.889600533681967
# ===================
# the 697 steps
# rho = 0.8895991947904881
# ===================
# the 698 steps
# rho = 0.8895978561995126
# ===================
# the 699 steps
# rho = 0.8895965179088438
# ===================
# the 700 steps
# rho = 0.8895951799182853
# ===================
# the 701 steps
# rho = 0.8895938422276403
# ===================
# the 702 steps
# rho = 0.8895925048367125
# ===================
# the 703 steps
# rho = 0.889591167745306
# ===================
# the 704 steps
# ...
# ===================
# the 729 steps
# rho = 0.8895565078623396
# ===================
# the 730 steps
# rho = 0.8895551787845069
# ===================
# the 731 steps
# rho = 0.889553850000774
# ===================
# the 732 steps
# rho = 0.8895525215109501
# ===================
# the 733 steps
# rho = 0.8895511933148438
# ===================
# the 734 steps
# rho = 0.8895498654122644
# ===================
# the 735 steps
# rho = 0.8895485378030215
# ===================
# the 736 steps
# rho = 0.8895472104869242
# ===================
# the 737 steps
# rho = 0.8895458834637824
# ===================
# the 738 steps
# rho = 0.8895445567334062
# ===================
# the 739 steps
# rho = 0.8895432302956051
# ===================
# the 740 steps
# rho = 0.8895419041501896
# ===================
# the 741 steps
# rho = 0.8895405782969702
# ===================
# the 742 steps
# rho = 0.8895392527357571
# ===================
# the 743 steps
# rho = 0.8895379274663611
# ===================
# the 744 steps
# rho = 0.889536602488593
# ===================
# the 745 steps
# rho = 0.8895352778022639
# ===================
# the 746 steps
# rho = 0.8895339534071851
# ===================
# the 747 steps
# rho = 0.8895326293031678
# ===================
# the 748 steps
# rho = 0.8895313054900232
# ===================
# the 749 steps
# rho = 0.8895299819675636
# ===================
# the 750 steps
# rho = 0.8895286587356005
# ===================
# the 751 steps
# rho = 0.8895273357939459
# ===================
# the 752 steps
# rho = 0.889526013142412
# ===================
# the 753 steps
# rho = 0.8895246907808113
# ===================
# the 754 steps
# rho = 0.8895233687089561
# ===================
# the 755 steps
# rho = 0.889522046926659
# ===================
# the 756 steps
# rho = 0.8895207254337332
# ===================
# the 757 steps
# rho = 0.8895194042299913
# ===================
# the 758 steps
# rho = 0.8895180833152466
# ===================
# the 759 steps
# rho = 0.8895167626893126
# ===================
# the 760 steps
# rho = 0.8895154423520025
# ===================
# the 761 steps
# rho = 0.8895141223031302
# ===================
# the 762 steps
# rho = 0.8895128025425093
# ===================
# the 763 steps
# rho = 0.889511483069954
# ===================
# the 764 steps
# rho = 0.8895101638852781
# ===================
# the 765 steps
# rho = 0.8895088449882963
# ===================
# the 766 steps
# rho = 0.8895075263788228
# ===================
# the 767 steps
# rho = 0.8895062080566722
# ===================
# the 768 steps
# rho = 0.8895048900216597
# ===================
# the 769 steps
# rho = 0.8895035722735997
# ===================
# the 770 steps
# rho = 0.8895022548123076
# ===================
# the 771 steps
# rho = 0.8895009376375986
# ===================
# the 772 steps
# rho = 0.8894996207492883
# ===================
# the 773 steps
# rho = 0.8894983041471921
# ===================
# the 774 steps
# rho = 0.889496987831126
# ===================
# the 775 steps
# rho = 0.8894956718009055
# ===================
# the 776 steps
# rho = 0.889494356056347
# ===================
# the 777 steps
# rho = 0.8894930405972667
# ===================
# the 778 steps
# rho = 0.889491725423481
# ===================
# the 779 steps
# rho = 0.8894904105348064
# ===================
# the 780 steps
# rho = 0.8894890959310596
# ===================
# the 781 steps
# rho = 0.8894877816120577
# ===================
# the 782 steps
# rho = 0.8894864675776174
# ===================
# the 783 steps
# rho = 0.8894851538275562
# ===================
# the 784 steps
# rho = 0.8894838403616914
# ===================
# the 785 steps
# rho = 0.8894825271798404
# ===================
# the 786 steps
# rho = 0.8894812142818209
# ===================
# the 787 steps
# rho = 0.8894799016674508
# ===================
# the 788 steps
# rho = 0.8894785893365482
# ===================
# the 789 steps
# rho = 0.8894772772889311
# ===================
# the 790 steps
# rho = 0.8894759655244178
# ===================
# the 791 steps
# rho = 0.889474654042827
# ===================
# the 792 steps
# rho = 0.889473342843977
# ===================
# the 793 steps
# rho = 0.8894720319276869
# ===================
# the 794 steps
# rho = 0.8894707212937754
# ===================
# the 795 steps
# rho = 0.8894694109420618
# ===================
# the 796 steps
# rho = 0.8894681008723653
# ===================
# the 797 steps
# rho = 0.8894667910845051
# ===================
# the 798 steps
# rho = 0.8894654815783012
# ===================
# the 799 steps
# rho = 0.889464172353573
# ===================
# the 800 steps
# rho = 0.8894628634101407
# ===================
# the 801 steps
# rho = 0.889461554747824
# ===================
# the 802 steps
# rho = 0.8894602463664433
# ===================
# the 803 steps
# rho = 0.8894589382658189
# ===================
# the 804 steps
# rho = 0.8894576304457713
# ===================
# the 805 steps
# rho = 0.8894563229061214
# ===================
# the 806 steps
# rho = 0.8894550156466897
# ===================
# the 807 steps
# rho = 0.8894537086672974
# ===================
# the 808 steps
# rho = 0.8894524019677656
# ===================
# the 809 steps
# rho = 0.8894510955479156
# ===================
# the 810 steps
# rho = 0.8894497894075689
# ===================
# the 811 steps
# rho = 0.889448483546547
# ===================
# the 812 steps
# rho = 0.8894471779646718
# ===================
# the 813 steps
# rho = 0.889445872661765
# ===================
# the 814 steps
# rho = 0.8894445676376488
# ===================
# the 815 steps
# rho = 0.8894432628921456
# ===================
# the 816 steps
# rho = 0.8894419584250775
# ===================
# the 817 steps
# rho = 0.8894406542362672
# ===================
# the 818 steps
# rho = 0.8894393503255373
# ===================
# the 819 steps
# rho = 0.8894380466927108
# ===================
# the 820 steps
# rho = 0.8894367433376105
# ===================
# the 821 steps
# rho = 0.8894354402600597
# ===================
# the 822 steps
# rho = 0.8894341374598818
# ===================
# the 823 steps
# rho = 0.8894328349368998
# ===================
# the 824 steps
# rho = 0.8894315326909379
# ===================
# the 825 steps
# rho = 0.8894302307218195
# ===================
# the 826 steps
# rho = 0.8894289290293687
# ===================
# the 827 steps
# rho = 0.8894276276134092
# ===================
# the 828 steps
# rho = 0.889426326473766
# ===================
# the 829 steps
# rho = 0.8894250256102626
# ===================
# the 830 steps
# rho = 0.889423725022724
# ===================
# the 831 steps
# rho = 0.8894224247109749
# ===================
# the 832 steps
# rho = 0.88942112467484
# ===================
# the 833 steps
# rho = 0.8894198249141443
# ===================
# the 834 steps
# rho = 0.8894185254287129
# ===================
# the 835 steps
# rho = 0.8894172262183714
# ===================
# the 836 steps
# rho = 0.8894159272829447
# ===================
# the 837 steps
# rho = 0.8894146286222587
# ===================
# the 838 steps
# rho = 0.8894133302361392
# ===================
# the 839 steps
# rho = 0.8894120321244121
# ===================
# the 840 steps
# rho = 0.8894107342869032
# ===================
# the 841 steps
# rho = 0.889409436723439
# ===================
# the 842 steps
# rho = 0.8894081394338456
# ===================
# the 843 steps
# rho = 0.8894068424179495
# ===================
# the 844 steps
# rho = 0.8894055456755775
# ===================
# the 845 steps
# rho = 0.8894042492065565
# ===================
# the 846 steps
# rho = 0.8894029530107131
# ===================
# the 847 steps
# rho = 0.8894016570878747
# ===================
# the 848 steps
# rho = 0.8894003614378683
# ===================
# the 849 steps
# rho = 0.8893990660605214
# ===================
# the 850 steps
# rho = 0.8893977709556616
# ===================
# the 851 steps
# rho = 0.8893964761231165
# ===================
# the 852 steps
# rho = 0.889395181562714
# ===================
# the 853 steps
# rho = 0.8893938872742821
# ===================
# the 854 steps
# rho = 0.8893925932576489
# ===================
# the 855 steps
# rho = 0.8893912995126426
# ===================
# the 856 steps
# rho = 0.8893900060390919
# ===================
# the 857 steps
# rho = 0.8893887128368251
# ===================
# the 858 steps
# rho = 0.889387419905671
# ===================
# the 859 steps
# rho = 0.8893861272454587
# ===================
# the 860 steps
# rho = 0.8893848348560169
# ===================
# the 861 steps
# rho = 0.889383542737175
# ===================
# the 862 steps
# rho = 0.8893822508887622
# ===================
# the 863 steps
# rho = 0.8893809593106081
# ===================
# the 864 steps
# rho = 0.8893796680025421
# ===================
# the 865 steps
# rho = 0.8893783769643941
# ===================
# the 866 steps
# rho = 0.8893770861959941
# ===================
# the 867 steps
# rho = 0.8893757956971721
# ===================
# the 868 steps
# rho = 0.8893745054677581
# ===================
# the 869 steps
# rho = 0.8893732155075826
# ===================
# the 870 steps
# rho = 0.8893719258164763
# ===================
# the 871 steps
# rho = 0.8893706363942695
# ===================
# the 872 steps
# rho = 0.8893693472407932
# ===================
# the 873 steps
# rho = 0.8893680583558782
# ===================
# the 874 steps
# rho = 0.8893667697393557
# ===================
# the 875 steps
# rho = 0.8893654813910569
# ===================
# the 876 steps
# rho = 0.8893641933108131
# ===================
# the 877 steps
# rho = 0.8893629054984559
# ===================
# the 878 steps
# rho = 0.8893616179538169
# ===================
# the 879 steps
# rho = 0.8893603306767278
# ===================
# the 880 steps
# rho = 0.8893590436670208
# ===================
# the 881 steps
# rho = 0.8893577569245278
# ===================
# the 882 steps
# rho = 0.8893564704490811
# ===================
# the 883 steps
# rho = 0.8893551842405132
# ===================
# the 884 steps
# rho = 0.8893538982986564
# ===================
# the 885 steps
# rho = 0.8893526126233434
# ===================
# the 886 steps
# rho = 0.8893513272144072
# ===================
# the 887 steps
# rho = 0.8893500420716808
# ===================
# the 888 steps
# rho = 0.889348757194997
# ===================
# the 889 steps
# rho = 0.8893474725841892
# ===================
# the 890 steps
# rho = 0.8893461882390908
# ===================
# the 891 steps
# rho = 0.8893449041595355
# ===================
# the 892 steps
# rho = 0.8893436203453566
# ===================
# the 893 steps
# rho = 0.8893423367963883
# ===================
# the 894 steps
# rho = 0.8893410535124642
# ===================
# the 895 steps
# rho = 0.8893397704934187
# ===================
# the 896 steps
# rho = 0.8893384877390859
# ===================
# the 897 steps
# rho = 0.8893372052493002
# ===================
# the 898 steps
# rho = 0.8893359230238962
# ===================
# the 899 steps
# rho = 0.8893346410627084
# ===================
# the 900 steps
# rho = 0.8893333593655719
# ===================
# the 901 steps
# rho = 0.8893320779323215
# ===================
# the 902 steps
# rho = 0.8893307967627921
# ===================
# the 903 steps
# rho = 0.8893295158568194
# ===================
# the 904 steps
# rho = 0.8893282352142384
# ===================
# the 905 steps
# rho = 0.8893269548348847
# ===================
# the 906 steps
# rho = 0.8893256747185939
# ===================
# the 907 steps
# rho = 0.889324394865202
# ===================
# the 908 steps
# rho = 0.8893231152745449
# ===================
# the 909 steps
# rho = 0.8893218359464585
# ===================
# the 910 steps
# rho = 0.8893205568807793
# ===================
# the 911 steps
# rho = 0.8893192780773435
# ===================
# the 912 steps
# rho = 0.8893179995359874
# ===================
# the 913 steps
# rho = 0.8893167212565481
# ===================
# the 914 steps
# rho = 0.8893154432388621
# ===================
# the 915 steps
# rho = 0.8893141654827665
# ===================
# the 916 steps
# rho = 0.8893128879880982
# ===================
# the 917 steps
# rho = 0.8893116107546943
# ===================
# the 918 steps
# rho = 0.8893103337823924
# ===================
# the 919 steps
# rho = 0.8893090570710298
# ===================
# the 920 steps
# rho = 0.8893077806204444
# ===================
# the 921 steps
# rho = 0.8893065044304735
# ===================
# the 922 steps
# rho = 0.8893052285009554
# ===================
# the 923 steps
# rho = 0.889303952831728
# ===================
# the 924 steps
# rho = 0.8893026774226295
# ===================
# the 925 steps
# rho = 0.8893014022734982
# ===================
# the 926 steps
# rho = 0.8893001273841724
# ===================
# the 927 steps
# rho = 0.8892988527544909
# ===================
# the 928 steps
# rho = 0.8892975783842925
# ===================
# the 929 steps
# rho = 0.8892963042734158
# ===================
# the 930 steps
# rho = 0.8892950304217
# ===================
# the 931 steps
# rho = 0.8892937568289841
# ===================
# the 932 steps
# rho = 0.8892924834951076
# ===================
# the 933 steps
# rho = 0.8892912104199097
# ===================
# the 934 steps
# rho = 0.8892899376032299
# ===================
# the 935 steps
# rho = 0.8892886650449082
# ===================
# the 936 steps
# rho = 0.8892873927447842
# ===================
# the 937 steps
# rho = 0.889286120702698
# ===================
# the 938 steps
# rho = 0.8892848489184895
# ===================
# the 939 steps
# rho = 0.889283577391999
# ===================
# the 940 steps
# rho = 0.889282306123067
# ===================
# the 941 steps
# rho = 0.889281035111534
# ===================
# the 942 steps
# rho = 0.8892797643572405
# ===================
# the 943 steps
# rho = 0.8892784938600274
# ===================
# the 944 steps
# rho = 0.8892772236197355
# ===================
# the 945 steps
# rho = 0.889275953636206
# ===================
# the 946 steps
# rho = 0.8892746839092801
# ===================
# the 947 steps
# rho = 0.8892734144387989
# ===================
# the 948 steps
# rho = 0.8892721452246041
# ===================
# the 949 steps
# rho = 0.8892708762665371
# ===================
# the 950 steps
# rho = 0.88926960756444
# ===================
# the 951 steps
# rho = 0.8892683391181541
# ===================
# the 952 steps
# rho = 0.8892670709275218
# ===================
# the 953 steps
# rho = 0.8892658029923851
# ===================
# the 954 steps
# rho = 0.8892645353125863
# ===================
# the 955 steps
# rho = 0.8892632678879678
# ===================
# the 956 steps
# rho = 0.889262000718372
# ===================
# the 957 steps
# rho = 0.8892607338036419
# ===================
# the 958 steps
# rho = 0.8892594671436201
# ===================
# the 959 steps
# rho = 0.8892582007381494
# ===================
# the 960 steps
# rho = 0.8892569345870731
# ===================
# the 961 steps
# rho = 0.8892556686902344
# ===================
# the 962 steps
# rho = 0.8892544030474764
# ===================
# the 963 steps
# rho = 0.8892531376586429
# ===================
# the 964 steps
# rho = 0.8892518725235772
# ===================
# the 965 steps
# rho = 0.889250607642123
# ===================
# the 966 steps
# rho = 0.8892493430141246
# ===================
# the 967 steps
# rho = 0.8892480786394258
# ===================
# the 968 steps
# rho = 0.8892468145178704
# ===================
# the 969 steps
# rho = 0.8892455506493031
# ===================
# the 970 steps
# rho = 0.8892442870335681
# ===================
# the 971 steps
# rho = 0.88924302367051
# ===================
# the 972 steps
# rho = 0.8892417605599734
# ===================
# the 973 steps
# rho = 0.8892404977018031
# ===================
# the 974 steps
# rho = 0.8892392350958441
# ===================
# the 975 steps
# rho = 0.8892379727419415
# ===================
# the 976 steps
# rho = 0.8892367106399404
# ===================
# the 977 steps
# rho = 0.889235448789686
# ===================
# the 978 steps
# rho = 0.8892341871910239
# ===================
# the 979 steps
# rho = 0.8892329258437998
# ===================
# the 980 steps
# rho = 0.8892316647478591
# ===================
# the 981 steps
# rho = 0.8892304039030479
# ===================
# the 982 steps
# rho = 0.8892291433092121
# ===================
# the 983 steps
# rho = 0.8892278829661978
# ===================
# the 984 steps
# rho = 0.8892266228738512
# ===================
# the 985 steps
# rho = 0.8892253630320188
# ===================
# the 986 steps
# rho = 0.889224103440547
# ===================
# the 987 steps
# rho = 0.8892228440992823
# ===================
# the 988 steps
# rho = 0.8892215850080718
# ===================
# the 989 steps
# rho = 0.889220326166762
# ===================
# the 990 steps
# rho = 0.8892190675752002
# ===================
# the 991 steps
# rho = 0.8892178092332336
# ===================
# the 992 steps
# rho = 0.8892165511407091
# ===================
# the 993 steps
# rho = 0.8892152932974743
# ===================
# the 994 steps
# rho = 0.8892140357033769
# ===================
# the 995 steps
# rho = 0.8892127783582643
# ===================
# the 996 steps
# rho = 0.8892115212619845
# ===================
# the 997 steps
# rho = 0.8892102644143852
# ===================
# the 998 steps
# rho = 0.8892090078153149
# ===================
# the 999 steps
# rho = 0.8892077514646212
# ===================
# ======End======

# %% [markdown]
# Global DMM on fine grid

# %%
DMM_U, DMM_Res = Multigrid_circle(inputsize, A1.to_full(), RightF, Rnew, s, wnew, error)
# Out:
# Residual = 3.9645354001415147
# Interation = 1
# ===================
# Residual = 1.0040853585624154
# Interation = 2
# ===================
# Residual = 0.6276925840189358
# Interation = 3
# ===================
# Residual = 0.4140303264450588
# Interation = 4
# ===================
# Residual = 0.28105392782879435
# Interation = 5
# ===================
# Residual = 0.19581891398330017
# Interation = 6
# ===================
# Residual = 0.14016596608542614
# Interation = 7
# ===================
# Residual = 0.10308829855264386
# Interation = 8
# ===================
# Residual = 0.07776364099458559
# Interation = 9
# ===================
# Residual = 0.05995990336606189
# Interation = 10
# ===================
# Residual = 0.04706036028058366
# Interation = 11
# ===================
# Residual = 0.037445032167614856
# Interation = 12
# ===================
# Residual = 0.03010035290190223
# Interation = 13
# ===================
# Residual = 0.024378597459908807
# Interation = 14
# ===================
# Residual = 0.019853249574018784
# Interation = 15
# ===================
# Residual = 0.016233491151951128
# Interation = 16
# ===================
# Residual = 0.01331387835054905
# Interation = 17
# ===================
# Residual = 0.010944483032857376
# Interation = 18
# ===================
# Residual = 0.00901282499120994
# Interation = 19
# ===================
# Residual = 0.007432619550254759
# Interation = 20
# ===================
# Residual = 0.006136522195296705
# Interation = 21
# ===================
# Residual = 0.005071273811090952
# Interation = 22
# ===================
# Residual = 0.004194332790825097
# Interation = 23
# ===================
# Residual = 0.0034714608770338817
# Interation = 24
# ===================
# Residual = 0.002874943381016934
# Interation = 25
# ===================
# Residual = 0.002382246383847189
# Interation = 26
# ===================
# Residual = 0.0019749846528209136
# Interation = 27
# ===================
# Residual = 0.0016381166482923985
# Interation = 28
# ===================
# Residual = 0.001359309364802561
# Interation = 29
# ===================
# Residual = 0.0011284326011268178
# Interation = 30
# ===================
# Residual = 0.0009371533804372536
# Interation = 31
# ===================
# Residual = 0.0007786088207994443
# Interation = 32
# ===================
# Residual = 0.0006471410672071517
# Interation = 33
# ===================
# Residual = 0.0005380817127758089
# Interation = 34
# ===================
# Residual = 0.0004475759394159172
# Interation = 35
# ===================
# Residual = 0.00037243870521764226
# Interation = 36
# ===================
# Residual = 0.00031003689961959943
# Interation = 37
# ===================
# Residual = 0.00025819261516659596
# Interation = 38
# ===================
# Residual = 0.0002151036411333952
# Interation = 39
# ===================
# Residual = 0.000179278036540545
# Interation = 40
# ===================
# Residual = 0.0001494802365366901
# Interation = 41
# ===================
# Residual = 0.00012468662224643671
# Interation = 42
# ===================
# Residual = 0.00010404886642164172
# Interation = 43
# ===================
# Residual = 8.686367560837034e-05
# Interation = 44
# ===================
# Residual = 7.254779934037142e-05
# Interation = 45
# ===================
# Residual = 6.061737986157962e-05
# Interation = 46
# ===================
# Residual = 5.067088137546241e-05
# Interation = 47
# ===================
# Residual = 4.237497298998595e-05
# Interation = 48
# ===================
# Residual = 3.545285023327334e-05
# Interation = 49
# ===================
# Residual = 2.9674570744146847e-05
# Interation = 50
# ===================
# Residual = 2.48490542853424e-05
# Interation = 51
# ===================
# Residual = 2.0817458481628755e-05
# Interation = 52
# ===================
# Residual = 1.7447692121516506e-05
# Interation = 53
# ===================
# Residual = 1.4629869348682206e-05
# Interation = 54
# ===================
# Residual = 1.2272542340124165e-05
# Interation = 55
# ===================
# Residual = 1.0299578230453877e-05
# Interation = 56
# ===================
# Residual = 8.647569375842963e-06
# Interation = 57
# ===================
# Residual = 7.263685225816677e-06
# Interation = 58
# ===================
# Residual = 6.103889970447908e-06
# Interation = 59
# ===================
# Residual = 5.131463217006256e-06
# Interation = 60
# ===================
# Residual = 4.315771782711391e-06
# Interation = 61
# ===================
# Residual = 3.631249647654858e-06
# Interation = 62
# ===================
# Residual = 3.0565505019296517e-06
# Interation = 63
# ===================
# Residual = 2.5738434311761718e-06
# Interation = 64
# ===================
# Residual = 2.168227375031721e-06
# Interation = 65
# ===================
# Residual = 1.827244124199969e-06
# Interation = 66
# ===================
# Residual = 1.5404731465754087e-06
# Interation = 67
# ===================
# Residual = 1.2991943434433988e-06
# Interation = 68
# ===================
# Residual = 1.0961072490854429e-06
# Interation = 69
# ===================
# Residual = 9.250971226671417e-07
# Interation = 70
# ===================
# Residual = 7.810400272032582e-07
# Interation = 71
# ===================
# Residual = 6.596403262017427e-07
# Interation = 72
# ===================
# Residual = 5.572951510612732e-07
# Interation = 73
# ===================
# Residual = 4.709813069435056e-07
# Interation = 74
# ===================
# Residual = 3.9816086783267916e-07
# Interation = 75
# ===================
# Residual = 3.3670233505456845e-07
# Interation = 76
# ===================
# Residual = 2.8481475754711e-07
# Interation = 77
# ===================
# Residual = 2.409926668418379e-07
# Interation = 78
# ===================
# Residual = 2.0397002375196962e-07
# Interation = 79
# ===================
# Residual = 1.7268168768098899e-07
# Interation = 80
# ===================
# Residual = 1.4623116051365595e-07
# Interation = 81
# ===================
# Residual = 1.238635757101248e-07
# Interation = 82
# ===================
# Residual = 1.049430651072745e-07
# Interation = 83
# ===================
# Residual = 8.893378836229754e-08
# Interation = 84
# ===================
# Residual = 7.538402095811678e-08
# Interation = 85
# ===================
# Residual = 6.39128065092805e-08
# Interation = 86
# ===================
# Residual = 5.4198749765713493e-08
# Interation = 87
# ===================
# Residual = 4.5970605633811155e-08
# Interation = 88
# ===================
# Residual = 3.899937469690034e-08
# Interation = 89
# ===================
# Residual = 3.309165545989544e-08
# Interation = 90
# ===================
# Residual = 2.808405630899343e-08
# Interation = 91
# ===================
# Residual = 2.383849462937776e-08
# Interation = 92
# ===================
# Residual = 2.023823878339857e-08
# Interation = 93
# ===================
# Residual = 1.7184577715657408e-08
# Interation = 94
# ===================
# Residual = 1.4594010868681092e-08
# Interation = 95
# ===================
# Residual = 1.2395888823016805e-08
# Interation = 96
# ===================
# Residual = 1.0530415804303929e-08
# Interation = 97
# ===================
# Residual = 8.946967857708835e-09
# Interation = 98
# ===================
# Residual = 7.602677971046505e-09
# Interation = 99
# ===================
# Residual = 6.461235017840994e-09
# Interation = 100
# ===================
# Residual = 5.491874721310767e-09
# Interation = 101
# ===================
# Residual = 4.668528064977704e-09
# Interation = 102
# ===================
# Residual = 3.9690967727943424e-09
# Interation = 103
# ===================
# Residual = 3.3748459974709728e-09
# Interation = 104
# ===================
# Residual = 2.869889416866594e-09
# Interation = 105
# ===================
# Residual = 2.440751098080342e-09
# Interation = 106
# ===================
# Residual = 2.076000981379799e-09
# Interation = 107
# ===================
# Residual = 1.7659395924411258e-09
# Interation = 108
# ===================
# Residual = 1.5023344647092603e-09
# Interation = 109
# ===================
# Residual = 1.2782005059266589e-09
# Interation = 110
# ===================
# Residual = 1.087604932979863e-09
# Interation = 111
# ===================
# Residual = 9.255124284438083e-10
# Interation = 112
# ===================
# Residual = 7.87645668732264e-10
# Interation = 113
# ===================
# Residual = 6.703722023633345e-10
# Interation = 114
# ===================
# Residual = 5.706063483443878e-10
# Interation = 115
# ===================
# Residual = 4.857256551494579e-10
# Interation = 116
# ===================
# Residual = 4.135036131537797e-10
# Interation = 117
# ===================
# Residual = 3.520465714448945e-10
# Interation = 118
# ===================
# Residual = 2.997448757119843e-10
# Interation = 119
# ===================
# Residual = 2.5523157253211496e-10
# Interation = 120
# ===================
# Residual = 2.1734343421787134e-10
# Interation = 121
# ===================
# Residual = 1.8509193926964288e-10
# Interation = 122
# ===================
# Residual = 1.5763668926374437e-10
# Interation = 123
# ===================
# Residual = 1.3426221046459585e-10
# Interation = 124
# ===================
# Residual = 1.143609782900081e-10
# Interation = 125
# ===================
# Residual = 9.741531880997197e-11
# Interation = 126
# ===================

# %% [markdown]
# Error DMM on fine grid

# %%
UREAL = Ureal.reshape(sqrtinputsize,sqrtinputsize)
DMMU = DMM_U.reshape(sqrtinputsize,sqrtinputsize)
deltaU = DMMU - UREAL

energynorm = np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=0),np.gradient(UREAL,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=1),np.gradient(UREAL,h,axis=1)),Media)*(h**2)))
l2norm = np.sqrt((np.linalg.norm(UREAL)**2)*(h**2))
h1norm = np.sqrt((np.linalg.norm(np.gradient(UREAL,h,axis=0))**2+np.linalg.norm(np.gradient(UREAL,h,axis=1))**2+np.linalg.norm(UREAL)**2)*(h**2))

print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),Media)*(h**2))))
print('L2 norm: ')
print(np.sqrt((np.linalg.norm(deltaU)**2)*(h**2)))
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2)))

print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),Media)*(h**2)))/energynorm)
print('L2 norm: ')
print(np.sqrt((np.linalg.norm(deltaU)**2)*(h**2))/l2norm)
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2))/h1norm)
# Out:
# Energy norm:
# 2.1958784708941366
# L2 norm:
# 0.18553125373393836
# H1 norm:
# 3.5732076305280414
# Energy norm:
# 0.3353602272066231
# L2 norm:
# 0.3710625074678767
# H1 norm:
# 0.39181424963063544

# %% [markdown]
# Solution

# %%
plt.imshow(DMM_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# Residual

# %%
plt.semilogy(DMM_Res)

# %% [markdown]
# Radius

# %%
DMM_Radius = Rhonew
print('DMM_Radius = {}'.format(DMM_Radius))
# Out:
# DMM_Radius = 0.8892077514646212

# %% [markdown]
# Rrestriction matrix after optimization

# %%
plt.imshow(Rnew)
plt.colorbar()

# %% [markdown]
# Rrestriction matrix (log(abs()) after optimization

# %%
plt.imshow(np.log(np.abs(Rnew)))
plt.colorbar()

# %% [markdown]
# Basis after optimization

# %%
basis1 = Rnew[int(0.45*outputsize)][:]
basis1 = basis1.reshape([sqrtinputsize,sqrtinputsize])
plt.imshow(basis1)
plt.colorbar()

# %%
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
size=basis1.shape
Y=np.arange(0,size[0],1)     
X=np.arange(0,size[1],1)

X,Y=np.meshgrid(X,Y)    
fig=plt.figure()
ax=fig.gca(projection='3d') 
ax.plot_surface(X,Y,basis1)
plt.show()

# %%
plt.plot(basis1[:][int(sqrtinputsize/2)])

# %% [markdown]
# Basis after optimization (log(abs()))

# %%
plt.imshow(np.log(np.abs(basis1)))
plt.colorbar()

# %%
fig=plt.figure()
ax=fig.gca(projection='3d') 
ax.plot_surface(X,Y,np.log(np.abs(basis1)))
plt.show()

# %%
plt.plot(np.log(np.abs(basis1[:][int(sqrtinputsize/2)])))

# %% [markdown]
# FEM use basis from global DMM

# %%
Anew = np.zeros([outputsize,outputsize])
[X1, Y1] = np.meshgrid(np.linspace(0, 1, sqrtinputsize),np.linspace(0, 1, sqrtinputsize))
[X2, Y2] = np.meshgrid(np.linspace(0, 1, sqrtoutputsize),np.linspace(0, 1, sqrtoutputsize))
A = a(X1,Y1)
for i in range(outputsize):
    for j in range(outputsize):
        basisi = Rnew[i][:].reshape([sqrtinputsize,sqrtinputsize])
        basisj = Rnew[j][:].reshape([sqrtinputsize,sqrtinputsize])
        gxbasisi = np.gradient(basisi,axis=0)/h
        gybasisi = np.gradient(basisi,axis=1)/h
        gxbasisj = np.gradient(basisj,axis=0)/h
        gybasisj = np.gradient(basisj,axis=1)/h
        Anew[i][j]=(np.sum(A*gxbasisi*gxbasisj)+np.sum(A*gybasisi*gybasisj))*(H**2)
        
Fnew = np.zeros([outputsize,1])
for i in range(outputsize):
    basisi = Rnew[i][:].reshape([sqrtinputsize,sqrtinputsize])
    F = rightf(X1,Y1)
    Fnew[i]=np.sum(F*basisi)*(H**2)
    
UnewCoarse = np.linalg.solve(Anew,Fnew)
Unew = np.zeros([sqrtinputsize,sqrtinputsize])
for i in range(outputsize):
    basisi = Rnew[i][:].reshape([sqrtinputsize,sqrtinputsize])
    Unew = Unew + UnewCoarse[i]*basisi

plt.imshow(Unew)
plt.colorbar()

UREAL = u_real(X1,Y1).reshape(sqrtinputsize,sqrtinputsize)
deltaU = Unew - UREAL
A = a(X1,Y1)

energynorm = np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=0),np.gradient(UREAL,h,axis=0)),A)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=1),np.gradient(UREAL,h,axis=1)),A)*(h**2)))
l2norm = np.sqrt((np.sum(UREAL**2))*(h**2))
h1norm = np.sqrt((np.linalg.norm(np.gradient(UREAL,h,axis=0))**2+np.linalg.norm(np.gradient(UREAL,h,axis=1))**2+np.linalg.norm(UREAL)**2)*(h**2))
print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),A)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),A)*(h**2))))
print('L2 norm: ')
print(np.sqrt((np.linalg.norm(deltaU)**2)*(h**2)))
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2)))



print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),A)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),A)*(h**2)))/energynorm)
print('L2 norm: ')
print(np.sqrt((np.sum(deltaU**2))*(h**2))/l2norm)
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2))/h1norm)
# Out:
# Energy norm:
# 4.085817986602554
# L2 norm:
# 0.3266691543956257
# H1 norm:
# 6.134124364608792
# Energy norm:
# 0.6239966676088415
# L2 norm:
# 0.6533383087912514
# H1 norm:
# 0.6726273935290509

# %%
import os
os.system("say 'The program has finished, Please check the results'")
# Out:
# 0
