# %% [markdown]
# Import important parameter

# %%
inputsize = 47**2
e = 0.05

# %% [markdown]
# Import Package

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import autograd.numpy as np
from autograd import grad
import pyamg
import dmg.gallery as gallery
import dmg.dgmg as dgmg
import dmg.gmg_linear as gmg_linear
import dmg.classical_amg as classical_amg
from mpl_toolkits.mplot3d import Axes3D
import xlsxwriter
from scipy.ndimage import convolve

# %% [markdown]
# Define function

# %%
def Restriction(inputsize):
    inputsize = int(inputsize)
    sqrtinputsize = int(np.sqrt(inputsize))     
    sqrtoutputsize = int(sqrtinputsize/2)
    outputsize = int(sqrtoutputsize**2)
    OUTPUT = np.zeros([outputsize, inputsize])
    for j in range(sqrtoutputsize):
        for i in range(sqrtoutputsize):
            OUTPUT[i+sqrtoutputsize*j][2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][1+2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2+2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][1+sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/4
            OUTPUT[i+sqrtoutputsize*j][2+sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2*sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][1+2 *
                                       sqrtinputsize + 2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2+2 *
                                       sqrtinputsize+2*i+j*2*sqrtinputsize] = 1/16
    return OUTPUT

def Poisson(inputsize):
    inputsize = int(inputsize)
    sqrtinputsize = int(np.sqrt(inputsize))     
    sqrtoutputsize = int(sqrtinputsize/2)
    outputsize = int(sqrtoutputsize**2)
    OUTPUT = np.zeros([outputsize, inputsize])
    A1 = 2*np.eye(sqrtinputsize)
    for i in range(sqrtinputsize-1):
        A1[i, i+1] = -1
        A1[i+1, i] = -1
    I = np.eye(sqrtinputsize)
    OUTPUT = (np.kron(I, A1)+np.kron(A1, I))
    return OUTPUT


def Multigrid_circle(inputsize, A_A, B, R_A, s, w, error):
    A = np.matrix(A_A)
    P = 16.*np.transpose(R_A)
    R = np.matrix(R_A)
    M = np.matrix(w**(-1)*np.diag(np.diag(A)))
    K = M - A
    C = np.linalg.inv(M)*K
    b = np.linalg.inv(M)*B
    U0 = np.matrix(np.zeros([inputsize, 1]))
    RESIDUAL = []
    Residual=1
    i=0
    while Residual > error:
        for j in range(s):
            U0 = C*U0+b
        r = B - A*U0
        Residual = np.linalg.norm(r,2)
        rc = R*r
        Ac = R*A*P
        Uc = np.linalg.solve(Ac, rc)
        U = U0 + P*Uc
        for k in range(s):
            U = C*U+b
        U0 = U
        RESIDUAL.append(Residual)
        i=i+1
        print("Residual = {}".format(Residual))
        print("Interation = {}".format(i))
        print("===================")
    return U0, RESIDUAL

def rho(inputsize,A,P,R,w,s):
    M = (w**(-1)) * np.diag(np.diag(A))
    K = M - A
    MK = np.matmul(np.linalg.inv(M),K)
    I = np.eye(inputsize)
    IPRAPRA = I - np.matmul(np.matmul(np.matmul(P,np.linalg.inv(np.matmul(np.matmul(R,A),P))),R),A)
    C = np.matmul(np.matmul(MK,IPRAPRA),MK)
    for i in range(5):
        C = np.matmul(C,C)
    radius = np.linalg.norm(C)**(1/32)
    return radius

def optimizer_GD(inputsize, A1, R, w, s, learning_rate, lam):
    rhoold = rho(inputsize,A1,16*np.transpose(R),R,w,s)
    device = torch.device('cpu')
    R = torch.tensor(R,dtype = torch.double, requires_grad=True,device=device)
    w = torch.tensor(w,dtype = torch.double, requires_grad=True, device=device)
    lam = torch.tensor(lam,dtype = torch.double, requires_grad=True, device=device)
    A = torch.tensor(A1,dtype = torch.double, device=device)
    P = 16*torch.t(R)
    M = (w**(-1)) * torch.diag(torch.diag(A))
    K = M - A
    MK = torch.mm(torch.inverse(M),K)
    I = torch.eye(inputsize,dtype = torch.double, device=device)
    I1 = torch.ones([inputsize,1],dtype = torch.double, device=device)
    I2 = torch.ones([outputsize,1],dtype = torch.double, device=device)
    IPRAPRA = I - torch.mm(torch.mm(torch.mm(P,torch.inverse(torch.mm(torch.mm(R,A),P))),R),A)
    C = torch.mm(torch.mm(MK,IPRAPRA),MK)
    for i in range(5):
        C = torch.mm(C,C)
    loss = torch.norm(C)**(1/32) + torch.mm(lam,torch.mm(R,I1) - I2)
    loss.backward()
    with torch.no_grad():
        R-=learning_rate*R.grad
        w-=learning_rate*w.grad 
        lam-=learning_rate*lam.grad
    R = R.detach().numpy()
    w = w.detach().numpy()
    lam = lam.detach().numpy()
    rhonew = rho(inputsize,A1,16*np.transpose(R),R,w,s)
    return R, w, lam, rhoold, rhonew

def direct_optimizer_GD(inputsize, A0, A1, R, w, s, learning_rate, lam):
    Rhoold = rho(inputsize,A1,16*np.transpose(R),R,w,s)
    Rhonew = [Rhoold]
    for i in range(100):
        Rnew, wnew, lamnew, rhoold, rhonew = optimizer_GD(inputsize, A1, R, w, s, learning_rate, lam)
        R = Rnew
        w = wnew
        lam = lamnew
        print("rho = {}".format(rhonew))
        print("===================")
        Rhonew.append(rhonew)
        i+=1
    print("======End======")
    return R, w, Rhoold, Rhonew

def homotopy_optimizer_GD(inputsize, A0, A1, R, w, s, learning_rate ,accept_radius ,step_length,lam):
    Rhoold = rho(inputsize,A1,16*np.transpose(R),R,w,s)
    Radius = [Rhoold]
    L = step_length
    print("======Section 1======")
    while L < 1:
        M = (1-L)*A0 + L*A1
        Rnew, wnew, lamnew, rhoold, rhonew = optimizer_GD(inputsize, M, R, w, s, learning_rate, lam)
        Radius.append(rhonew)
        if rhonew > accept_radius:
            step_length = 0.1*step_length
            learning_rate = 0.1*learning_rate
            print('Decrease the step_length, learning_rate and Restart!!')
            print("step_length = {}".format(step_length))      
            print("learning_rate = {}".format(learning_rate))
            print("rhonew = {}".format(rhonew))
            print("===================")
            R = Restriction(inputsize)
            lam = np.zeros([1,outputsize])
            w = 2/3
            L = step_length
        else:
            R = Rnew
            w = wnew
            L += step_length
            lam = lamnew
            print("L = {}".format(L))
            print("rho = {}".format(rhonew))
            print("===================")
    print("======Section 2======")
    i = 0
    while rhoold>rhonew and i <100:
        Rnew, wnew, lamnew, rhoold, rhonew = optimizer_GD(inputsize, A1, R, w, s, learning_rate, lam)
        Radius.append(rhonew)
        R = Rnew
        w = wnew
        lam = lamnew
        print("the {} steps".format(i))
        print("rho = {}".format(rhonew))
        print("===================")
        i+=1            
    Rhonew = rhonew
    print("======End======")
    return R, w, Rhoold, Rhonew, Radius

# %% [markdown]
# Define parameter

# %%
s = 1
w = 2/3
error=10e-11
def u_real(x, y): return np.sin(np.pi*3*x)*np.sin(np.pi*5*y)
def rightf(x, y): return  (-(5/6))*np.pi*np.cos(5*np.pi*y)*np.sin(3*np.pi*x)*(-((np.pi*np.cos(np.pi*y)*(1.1 + np.sin(np.pi*x)))/(1.1 + np.sin(np.pi*y))**2)-(10*np.pi*np.cos(10*np.pi*y)*(1.1 + np.sin(10*np.pi*x)))/(1.1 + np.sin(10*np.pi*y))**2)-(1/2)*np.pi*np.cos(3*np.pi*x)*np.sin(5*np.pi*y)*((np.pi*np.cos(np.pi*x))/(1.1 + np.sin(np.pi*y)) + (10*np.pi*np.cos(10*np.pi*x))/(1.1 + np.sin(10*np.pi*y))) +  (17/3)*np.pi**2*np.sin(3*np.pi*x)*np.sin(5*np.pi*y)*((1.1 + np.sin(np.pi*x))/(1.1 + np.sin(np.pi*y)) + (1.1 + np.sin(10*np.pi*x))/(1.1 + np.sin(10*np.pi*y)))
def a(x,y): return (1/6)*((1.1 + np.sin(np.pi*x))/(1.1 + np.sin(np.pi*y)) + (1.1 +np.sin(np.pi*x*10))/(1.1 + np.sin(np.pi*y*10)))

sqrtinputsize = int(np.sqrt(inputsize))
sqrtmidputsize = int(sqrtinputsize/2)
midputsize = int(sqrtmidputsize**2)
sqrtoutputsize = int(sqrtmidputsize/2)
outputsize = int(sqrtoutputsize**2)

h = 1/(sqrtinputsize-1)
H = 1/(sqrtoutputsize-1)
A0 = Poisson(inputsize)
num_levels=2
n=sqrtinputsize
kx = np.zeros([n,n+1])
ky = np.zeros([n+1,n])
for i in range(n):
    for j in range(n+1):
        kx[i][j] = a((j-0.5)*h,i*h)
for i in range(n+1):
    for j in range(n):
        ky[i][j] = a(j*h,(i-0.5)*h)    
A1 = gallery.nonlinearPoisson((n,n), kx, ky)
n = inputsize
[X, Y] = np.meshgrid(np.linspace(0, 1, sqrtinputsize),np.linspace(0, 1, sqrtinputsize))
RightF = rightf(X,Y)*h**2
RightF = RightF.reshape(inputsize, 1)
Ureal = u_real(X,Y).reshape(inputsize, 1)
Media = a(X,Y)
R1 = Restriction(inputsize)
R2 = Restriction(midputsize)
R  = np.matmul(R2, R1)
P = 16*np.transpose(R)

# %% [markdown]
# GMM on fine grid

# %%
GMM_U, GMM_Res = Multigrid_circle(inputsize, A1.to_full(), RightF, R, s, w, error)
# Out:
# Residual = 4.223084109706287
# Interation = 1
# ===================
# Residual = 1.3114394230588917
# Interation = 2
# ===================
# Residual = 0.8437952877682781
# Interation = 3
# ===================
# Residual = 0.579082334365261
# Interation = 4
# ===================
# Residual = 0.413630737132403
# Interation = 5
# ===================
# Residual = 0.30384365939237046
# Interation = 6
# ===================
# Residual = 0.22782228725494044
# Interation = 7
# ===================
# Residual = 0.1734349835130639
# Interation = 8
# ===================
# Residual = 0.13352097028968812
# Interation = 9
# ===================
# Residual = 0.1036461577049483
# Interation = 10
# ===================
# Residual = 0.08094837825953227
# Interation = 11
# ===================
# Residual = 0.06350893651799458
# Interation = 12
# ===================
# Residual = 0.04999732469165628
# Interation = 13
# ===================
# Residual = 0.039463653961951825
# Interation = 14
# ===================
# Residual = 0.03121329360256248
# Interation = 15
# ===================
# Residual = 0.02472847971416447
# Interation = 16
# ===================
# Residual = 0.019617523516422396
# Interation = 17
# ===================
# Residual = 0.01558074770180054
# Interation = 18
# ===================
# Residual = 0.012386906068099108
# Interation = 19
# ===================
# Residual = 0.00985640236477237
# Interation = 20
# ===================
# Residual = 0.007849068698868847
# Interation = 21
# ===================
# Residual = 0.0062550970826819475
# Interation = 22
# ===================
# Residual = 0.0049882110879486624
# Interation = 23
# ===================
# Residual = 0.003980465405964594
# Interation = 24
# ===================
# Residual = 0.003178250406061921
# Interation = 25
# ===================
# Residual = 0.0025392017840082386
# Interation = 26
# ===================
# Residual = 0.0020297978483790552
# Interation = 27
# ===================
# Residual = 0.0016234838877898655
# Interation = 28
# ===================
# Residual = 0.0012992033335717035
# Interation = 29
# ===================
# Residual = 0.0010402445627934048
# Interation = 30
# ===================
# Residual = 0.0008333336390695342
# Interation = 31
# ===================
# Residual = 0.00066791931716609
# Interation = 32
# ===================
# Residual = 0.0005356087522208346
# Interation = 33
# ===================
# Residual = 0.00042972159483245254
# Interation = 34
# ===================
# Residual = 0.0003449372520191629
# Interation = 35
# ===================
# Residual = 0.0002770155784437521
# Interation = 36
# ===================
# Residual = 0.0002225755187774256
# Interation = 37
# ===================
# Residual = 0.00017891953726484152
# Interation = 38
# ===================
# Residual = 0.00014389426046655475
# Interation = 39
# ===================
# Residual = 0.00011577978714170101
# Interation = 40
# ===================
# Residual = 9.320171054267569e-05
# Interation = 41
# ===================
# Residual = 7.506114910705229e-05
# Interation = 42
# ===================
# Residual = 6.0479065992684355e-05
# Interation = 43
# ===================
# Residual = 4.8751933835622275e-05
# Interation = 44
# ===================
# Residual = 3.931641323568098e-05
# Interation = 45
# ===================
# Residual = 3.172119703531761e-05
# Interation = 46
# ===================
# Residual = 2.5604554649208592e-05
# Interation = 47
# ===================
# Residual = 2.0676413063929462e-05
# Interation = 48
# ===================
# Residual = 1.6704050649762906e-05
# Interation = 49
# ===================
# Residual = 1.3500669548435347e-05
# Interation = 50
# ===================
# Residual = 1.0916262856678925e-05
# Interation = 51
# ===================
# Residual = 8.830312181810815e-06
# Interation = 52
# ===================
# Residual = 7.145945869439709e-06
# Interation = 53
# ===================
# Residual = 5.785263454077657e-06
# Interation = 54
# ===================
# Residual = 4.685591726275068e-06
# Interation = 55
# ===================
# Residual = 3.7964853448410717e-06
# Interation = 56
# ===================
# Residual = 3.077322801294025e-06
# Interation = 57
# ===================
# Residual = 2.4953786504228826e-06
# Interation = 58
# ===================
# Residual = 2.024276935167816e-06
# Interation = 59
# ===================
# Residual = 1.642749852967615e-06
# Interation = 60
# ===================
# Residual = 1.3336409541671551e-06
# Interation = 61
# ===================
# Residual = 1.0831043410385752e-06
# Interation = 62
# ===================
# Residual = 8.799610304441824e-07
# Interation = 63
# ===================
# Residual = 7.15181400296378e-07
# Interation = 64
# ===================
# Residual = 5.814688442814847e-07
# Interation = 65
# ===================
# Residual = 4.7292467406389264e-07
# Interation = 66
# ===================
# Residual = 3.847783104868799e-07
# Interation = 67
# ===================
# Residual = 3.131699345601442e-07
# Interation = 68
# ===================
# Residual = 2.5497534242381936e-07
# Interation = 69
# ===================
# Residual = 2.0766471496374225e-07
# Interation = 70
# ===================
# Residual = 1.6918871800538568e-07
# Interation = 71
# ===================
# Residual = 1.3788657975760848e-07
# Interation = 72
# ===================
# Residual = 1.1241189207584796e-07
# Interation = 73
# ===================
# Residual = 9.167267996043602e-08
# Interation = 74
# ===================
# Residual = 7.478297781456527e-08
# Interation = 75
# ===================
# Residual = 6.102369300241466e-08
# Interation = 76
# ===================
# Residual = 4.981096148956335e-08
# Interation = 77
# ===================
# Residual = 4.067052668951277e-08
# Interation = 78
# ===================
# Residual = 3.321703889570679e-08
# Interation = 79
# ===================
# Residual = 2.7137264646257325e-08
# Interation = 80
# ===================
# Residual = 2.217650419991263e-08
# Interation = 81
# ===================
# Residual = 1.8127577855698504e-08
# Interation = 82
# ===================
# Residual = 1.4821905709844895e-08
# Interation = 83
# ===================
# Residual = 1.2122263993363881e-08
# Interation = 84
# ===================
# Residual = 9.916918182259122e-09
# Interation = 85
# ===================
# Residual = 8.114858164315023e-09
# Interation = 86
# ===================
# Residual = 6.641932925589171e-09
# Interation = 87
# ===================
# Residual = 5.437697414070229e-09
# Interation = 88
# ===================
# Residual = 4.452877947871577e-09
# Interation = 89
# ===================
# Residual = 3.647287576886937e-09
# Interation = 90
# ===================
# Residual = 2.9881353411696986e-09
# Interation = 91
# ===================
# Residual = 2.4486692616927776e-09
# Interation = 92
# ===================
# Residual = 2.007047349564292e-09
# Interation = 93
# ===================
# Residual = 1.6454339201813054e-09
# Interation = 94
# ===================
# Residual = 1.3492651254387371e-09
# Interation = 95
# ===================
# Residual = 1.1066402168033264e-09
# Interation = 96
# ===================
# Residual = 9.078333484369339e-10
# Interation = 97
# ===================
# Residual = 7.448935386792872e-10
# Interation = 98
# ===================
# Residual = 6.113208355885688e-10
# Interation = 99
# ===================
# Residual = 5.017993910949862e-10
# Interation = 100
# ===================
# Residual = 4.119790133155663e-10
# Interation = 101
# ===================
# Residual = 3.3829975516875183e-10
# Interation = 102
# ===================
# Residual = 2.778492303136702e-10
# Interation = 103
# ===================
# Residual = 2.2824307102360008e-10
# Interation = 104
# ===================
# Residual = 1.87526293589795e-10
# Interation = 105
# ===================
# Residual = 1.5409996206345551e-10
# Interation = 106
# ===================
# Residual = 1.2665407257911155e-10
# Interation = 107
# ===================
# Residual = 1.0411464030356371e-10
# Interation = 108
# ===================
# Residual = 8.559986543438965e-11
# Interation = 109
# ===================

# %% [markdown]
# Error GMM on fine grid

# %%
UREAL = Ureal.reshape(sqrtinputsize,sqrtinputsize)
GMMU = GMM_U.reshape(sqrtinputsize,sqrtinputsize)
deltaU = GMMU - UREAL

energynorm = np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=0),np.gradient(UREAL,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=1),np.gradient(UREAL,h,axis=1)),Media)*(h**2)))
l2norm = np.sqrt((np.linalg.norm(UREAL)**2)*(h**2))
h1norm = np.sqrt((np.linalg.norm(np.gradient(UREAL,h,axis=0))**2+np.linalg.norm(np.gradient(UREAL,h,axis=1))**2+np.linalg.norm(UREAL)**2)*(h**2))

print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),Media)*(h**2))))
print('L2 norm: ')
print(np.sqrt((np.linalg.norm(deltaU)**2)*(h**2)))
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2)))

print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),Media)*(h**2)))/energynorm)
print('L2 norm: ')
print(np.sqrt((np.linalg.norm(deltaU)**2)*(h**2))/l2norm)
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2))/h1norm)
# Out:
# Energy norm:
# 3.0648228500973356
# L2 norm:
# 0.3224776856580661
# H1 norm:
# 5.011567680314511
# Energy norm:
# 0.4411877314097541
# L2 norm:
# 0.6449553713161323
# H1 norm:
# 0.543570077694915

# %% [markdown]
# Solution

# %%
plt.imshow(GMM_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# Residual

# %%
plt.semilogy(GMM_Res)

# %% [markdown]
# Radius

# %%
GMM_Radius = rho(inputsize,A1.to_full(),16*np.transpose(R),R,w,s)
print('GMM_Radius = {}'.format(GMM_Radius))
# Out:
# GMM_Radius = 0.8864607027765364

# %% [markdown]
# Global DMM optimization

# %%
Rnew, wnew, Rhoold, Rhonew, Radius = homotopy_optimizer_GD(inputsize, A0, A1.to_full(), R,  2/3, s, 
                                                           learning_rate = 1e-6,accept_radius =
                                                           GMM_Radius*10,step_length =  1e-2, lam = np.zeros([1,outputsize]))
# Out:
# ======Section 1======
# L = 0.02
# rho = 0.8425336768301563
# ===================
# L = 0.03
# rho = 0.8424673069986434
# ===================
# L = 0.04
# rho = 0.8424090437862087
# ===================
# L = 0.05
# rho = 0.8423587172682705
# ===================
# L = 0.060000000000000005
# rho = 0.842316177342729
# ===================
# L = 0.07
# rho = 0.8422812919084751
# ===================
# L = 0.08
# rho = 0.8422539452401
# ===================
# L = 0.09
# rho = 0.8422340365335972
# ===================
# L = 0.09999999999999999
# rho = 0.842221478601644
# ===================
# L = 0.10999999999999999
# rho = 0.8422161967002257
# ===================
# L = 0.11999999999999998
# rho = 0.8422181274710552
# ===================
# L = 0.12999999999999998
# rho = 0.842227217986497
# ===================
# L = 0.13999999999999999
# rho = 0.8422434248856351
# ===================
# L = 0.15
# rho = 0.8422667135917526
# ===================
# L = 0.16
# rho = 0.8422970576028914
# ===================
# L = 0.17
# rho = 0.842334437848352
# ===================
# L = 0.18000000000000002
# rho = 0.8423788421050231
# ===================
# L = 0.19000000000000003
# rho = 0.8424302644683115
# ===================
# L = 0.20000000000000004
# rho = 0.8424887048732065
# ===================
# L = 0.21000000000000005
# rho = 0.8425541686616741
# ===================
# L = 0.22000000000000006
# rho = 0.8426266661931472
# ===================
# L = 0.23000000000000007
# rho = 0.8427062124953746
# ===================
# L = 0.24000000000000007
# rho = 0.8427928269533289
# ===================
# L = 0.25000000000000006
# rho = 0.8428865330342473
# ===================
# L = 0.26000000000000006
# rho = 0.8429873580472115
# ===================
# L = 0.2700000000000001
# rho = 0.8430953329359654
# ===================
# L = 0.2800000000000001
# rho = 0.8432104921039222
# ===================
# L = 0.2900000000000001
# rho = 0.8433328732705373
# ===================
# L = 0.3000000000000001
# rho = 0.8434625173584281
# ===================
# L = 0.3100000000000001
# rho = 0.8435994684107956
# ===================
# L = 0.3200000000000001
# rho = 0.8437437735388659
# ===================
# L = 0.3300000000000001
# rho = 0.8438954828992178
# ===================
# L = 0.34000000000000014
# rho = 0.8440546497009948
# ===================
# L = 0.35000000000000014
# rho = 0.844221330243126
# ===================
# L = 0.36000000000000015
# rho = 0.844395583981805
# ===================
# L = 0.37000000000000016
# rho = 0.8445774736285865
# ===================
# L = 0.38000000000000017
# rho = 0.8447670652795793
# ===================
# L = 0.3900000000000002
# rho = 0.8449644285763335
# ===================
# L = 0.4000000000000002
# rho = 0.845169636899134
# ===================
# L = 0.4100000000000002
# rho = 0.8453827675935479
# ===================
# L = 0.4200000000000002
# rho = 0.8456039022312012
# ===================
# L = 0.4300000000000002
# rho = 0.8458331269059131
# ===================
# L = 0.4400000000000002
# rho = 0.8460705325664726
# ===================
# L = 0.45000000000000023
# rho = 0.846316215387521
# ===================
# L = 0.46000000000000024
# rho = 0.8465702771801975
# ===================
# L = 0.47000000000000025
# rho = 0.8468328258444243
# ===================
# L = 0.48000000000000026
# rho = 0.8471039758649486
# ===================
# L = 0.49000000000000027
# rho = 0.8473838488535302
# ===================
# L = 0.5000000000000002
# rho = 0.8476725741399648
# ===================
# L = 0.5100000000000002
# rho = 0.8479702894149704
# ===================
# L = 0.5200000000000002
# rho = 0.8482771414283471
# ===================
# L = 0.5300000000000002
# rho = 0.8485932867462329
# ===================
# L = 0.5400000000000003
# rho = 0.8489188925717629
# ===================
# L = 0.5500000000000003
# rho = 0.849254137633959
# ===================
# L = 0.5600000000000003
# rho = 0.8495992131502708
# ===================
# L = 0.5700000000000003
# rho = 0.8499543238688523
# ===================
# L = 0.5800000000000003
# rho = 0.8503196891973963
# ===================
# L = 0.5900000000000003
# rho = 0.8506955444261772
# ===================
# L = 0.6000000000000003
# rho = 0.8510821420538855
# ===================
# L = 0.6100000000000003
# rho = 0.8514797532258754
# ===================
# L = 0.6200000000000003
# rho = 0.8518886692956201
# ===================
# L = 0.6300000000000003
# rho = 0.8523092035214865
# ===================
# L = 0.6400000000000003
# rho = 0.8527416929124204
# ===================
# L = 0.6500000000000004
# rho = 0.8531865002378107
# ===================
# L = 0.6600000000000004
# rho = 0.8536440162186879
# ===================
# L = 0.6700000000000004
# rho = 0.8541146619195585
# ===================
# L = 0.6800000000000004
# rho = 0.8545988913626047
# ===================
# L = 0.6900000000000004
# rho = 0.8550971943887481
# ===================
# L = 0.7000000000000004
# rho = 0.8556100997932354
# ===================
# L = 0.7100000000000004
# rho = 0.8561381787670126
# ===================
# L = 0.7200000000000004
# rho = 0.8566820486793083
# ===================
# L = 0.7300000000000004
# rho = 0.8572423772416136
# ===================
# L = 0.7400000000000004
# rho = 0.8578198870987704
# ===================
# L = 0.7500000000000004
# rho = 0.8584153608992732
# ===================
# L = 0.7600000000000005
# rho = 0.8590296469043366
# ===================
# L = 0.7700000000000005
# rho = 0.8596636652039918
# ===================
# L = 0.7800000000000005
# rho = 0.8603184146186886
# ===================
# L = 0.7900000000000005
# rho = 0.860994980376943
# ===================
# L = 0.8000000000000005
# rho = 0.8616945426738514
# ===================
# L = 0.8100000000000005
# rho = 0.8624183862323247
# ===================
# L = 0.8200000000000005
# rho = 0.8631679110092786
# ===================
# L = 0.8300000000000005
# rho = 0.863944644213588
# ===================
# L = 0.8400000000000005
# rho = 0.8647502538323873
# ===================
# L = 0.8500000000000005
# rho = 0.8655865638986099
# ===================
# L = 0.8600000000000005
# rho = 0.8664555717772519
# ===================
# L = 0.8700000000000006
# rho = 0.8673594678029789
# ===================
# L = 0.8800000000000006
# rho = 0.8683006576703689
# ===================
# L = 0.8900000000000006
# rho = 0.8692817880643094
# ===================
# L = 0.9000000000000006
# rho = 0.8703057761272243
# ===================
# L = 0.9100000000000006
# rho = 0.8713758434992197
# ===================
# L = 0.9200000000000006
# rho = 0.8724955558470223
# ===================
# L = 0.9300000000000006
# rho = 0.8736688690317808
# ===================
# L = 0.9400000000000006
# rho = 0.8749001833743274
# ===================
# L = 0.9500000000000006
# rho = 0.8761944078878786
# ===================
# L = 0.9600000000000006
# rho = 0.8775570369040172
# ===================
# L = 0.9700000000000006
# rho = 0.8789942422800513
# ===================
# L = 0.9800000000000006
# rho = 0.88051298543822
# ===================
# L = 0.9900000000000007
# rho = 0.8821211549951942
# ===================
# L = 1.0000000000000007
# rho = 0.8838277379249431
# ===================
# ======Section 2======
# the 0 steps
# rho = 0.885643035437028
# ===================
# the 1 steps
# rho = 0.8856175191074881
# ===================
# the 2 steps
# rho = 0.8855920619005616
# ===================
# the 3 steps
# rho = 0.8855666636975041
# ===================
# the 4 steps
# rho = 0.8855413243794444
# ===================
# the 5 steps
# rho = 0.8855160438273892
# ===================
# the 6 steps
# rho = 0.8854908219222255
# ===================
# the 7 steps
# rho = 0.8854656585447238
# ===================
# the 8 steps
# rho = 0.885440553575542
# ===================
# the 9 steps
# rho = 0.885415506895228
# ===================
# the 10 steps
# rho = 0.8853905183842238
# ===================
# the 11 steps
# rho = 0.885365587922867
# ===================
# the 12 steps
# rho = 0.8853407153913961
# ===================
# the 13 steps
# rho = 0.8853159006699519
# ===================
# the 14 steps
# rho = 0.8852911436385817
# ===================
# the 15 steps
# rho = 0.8852664441772423
# ===================
# the 16 steps
# rho = 0.8852418021658023
# ===================
# the 17 steps
# rho = 0.8852172174840465
# ===================
# the 18 steps
# rho = 0.8851926900116777
# ===================
# the 19 steps
# rho = 0.8851682196283208
# ===================
# the 20 steps
# rho = 0.8851438062135253
# ===================
# the 21 steps
# rho = 0.8851194496467684
# ===================
# the 22 steps
# rho = 0.8850951498074578
# ===================
# the 23 steps
# rho = 0.8850709065749359
# ===================
# the 24 steps
# rho = 0.8850467198284807
# ===================
# the 25 steps
# rho = 0.8850225894473107
# ===================
# the 26 steps
# rho = 0.8849985153105868
# ===================
# the 27 steps
# rho = 0.8849744972974155
# ===================
# the 28 steps
# rho = 0.8849505352868519
# ===================
# the 29 steps
# rho = 0.8849266291579024
# ===================
# the 30 steps
# rho = 0.884902778789528
# ===================
# the 31 steps
# rho = 0.8848789840606468
# ===================
# the 32 steps
# rho = 0.8848552448501362
# ===================
# the 33 steps
# rho = 0.8848315610368379
# ===================
# the 34 steps
# rho = 0.8848079324995579
# ===================
# the 35 steps
# rho = 0.8847843591170717
# ===================
# the 36 steps
# rho = 0.8847608407681252
# ===================
# the 37 steps
# rho = 0.8847373773314389
# ===================
# the 38 steps
# rho = 0.8847139686857096
# ===================
# the 39 steps
# rho = 0.8846906147096145
# ===================
# the 40 steps
# rho = 0.884667315281812
# ===================
# the 41 steps
# rho = 0.8846440702809457
# ===================
# the 42 steps
# rho = 0.8846208795856473
# ===================
# the 43 steps
# rho = 0.8845977430745379
# ===================
# the 44 steps
# rho = 0.8845746606262322
# ===================
# the 45 steps
# rho = 0.8845516321193401
# ===================
# the 46 steps
# rho = 0.8845286574324696
# ===================
# the 47 steps
# rho = 0.8845057364442296
# ===================
# the 48 steps
# rho = 0.8844828690332321
# ===================
# the 49 steps
# rho = 0.8844600550780951
# ===================
# the 50 steps
# rho = 0.8844372944574449
# ===================
# the 51 steps
# rho = 0.8844145870499188
# ===================
# the 52 steps
# rho = 0.8843919327341673
# ===================
# the 53 steps
# rho = 0.8843693313888569
# ===================
# the 54 steps
# rho = 0.8843467828926727
# ===================
# the 55 steps
# rho = 0.8843242871243204
# ===================
# the 56 steps
# rho = 0.8843018439625289
# ===================
# the 57 steps
# rho = 0.8842794532860532
# ===================
# the 58 steps
# rho = 0.8842571149736757
# ===================
# the 59 steps
# rho = 0.8842348289042098
# ===================
# the 60 steps
# rho = 0.8842125949565016
# ===================
# the 61 steps
# rho = 0.8841904130094324
# ===================
# the 62 steps
# rho = 0.8841682829419207
# ===================
# the 63 steps
# rho = 0.8841462046329256
# ===================
# the 64 steps
# rho = 0.884124177961447
# ===================
# the 65 steps
# rho = 0.8841022028065308
# ===================
# the 66 steps
# rho = 0.8840802790472685
# ===================
# the 67 steps
# rho = 0.8840584065628005
# ===================
# the 68 steps
# rho = 0.8840365852323192
# ===================
# the 69 steps
# rho = 0.8840148149350693
# ===================
# the 70 steps
# rho = 0.8839930955503517
# ===================
# the 71 steps
# rho = 0.8839714269575248
# ===================
# the 72 steps
# rho = 0.883949809036007
# ===================
# the 73 steps
# rho = 0.8839282416652785
# ===================
# the 74 steps
# rho = 0.8839067247248837
# ===================
# the 75 steps
# rho = 0.8838852580944336
# ===================
# the 76 steps
# rho = 0.8838638416536072
# ===================
# the 77 steps
# rho = 0.883842475282154
# ===================
# the 78 steps
# rho = 0.8838211588598959
# ===================
# the 79 steps
# rho = 0.8837998922667293
# ===================
# the 80 steps
# rho = 0.8837786753826273
# ===================
# the 81 steps
# rho = 0.8837575080876415
# ===================
# the 82 steps
# rho = 0.883736390261904
# ===================
# the 83 steps
# rho = 0.8837153217856295
# ===================
# the 84 steps
# rho = 0.8836943025391168
# ===================
# the 85 steps
# rho = 0.8836733324027518
# ===================
# the 86 steps
# rho = 0.8836524112570079
# ===================
# the 87 steps
# rho = 0.8836315389824491
# ===================
# the 88 steps
# rho = 0.8836107154597318
# ===================
# the 89 steps
# rho = 0.8835899405696057
# ===================
# the 90 steps
# rho = 0.8835692141929173
# ===================
# the 91 steps
# rho = 0.8835485362106098
# ===================
# the 92 steps
# rho = 0.8835279065037266
# ===================
# the 93 steps
# rho = 0.8835073249534122
# ===================
# the 94 steps
# rho = 0.8834867914409138
# ===================
# the 95 steps
# rho = 0.8834663058475842
# ===================
# the 96 steps
# rho = 0.8834458680548822
# ===================
# the 97 steps
# rho = 0.8834254779443755
# ===================
# the 98 steps
# rho = 0.8834051353977413
# ===================
# the 99 steps
# rho = 0.8833848402967693
# ===================
# ======End======

# %% [markdown]
# Global DMM on fine grid

# %%
DMM_U, DMM_Res = Multigrid_circle(inputsize, A1.to_full(), RightF, Rnew, s, wnew, error)
# Out:
# Residual = 4.2228930649295355
# Interation = 1
# ===================
# Residual = 1.3113175383114717
# Interation = 2
# ===================
# Residual = 0.8436812340275516
# Interation = 3
# ===================
# Residual = 0.5789790066283379
# Interation = 4
# ===================
# Residual = 0.4135382998286977
# Interation = 5
# ===================
# Residual = 0.30376165687548357
# Interation = 6
# ===================
# Residual = 0.22775004126730602
# Interation = 7
# ===================
# Residual = 0.1733717052271771
# Interation = 8
# ===================
# Residual = 0.133465828202057
# Interation = 9
# ===================
# Residual = 0.10359832143898892
# Interation = 10
# ===================
# Residual = 0.08090704582117753
# Interation = 11
# ===================
# Residual = 0.0634733510821174
# Interation = 12
# ===================
# Residual = 0.049966784588817
# Interation = 13
# ===================
# Residual = 0.03943751792862147
# Interation = 14
# ===================
# Residual = 0.03119098257854797
# Interation = 15
# ===================
# Residual = 0.024709476116522078
# Interation = 16
# ===================
# Residual = 0.019601368729114353
# Interation = 17
# ===================
# Residual = 0.01556703838271944
# Interation = 18
# ===================
# Residual = 0.01237528975400357
# Interation = 19
# ===================
# Residual = 0.009846572744410908
# Interation = 20
# ===================
# Residual = 0.007840760827173087
# Interation = 21
# ===================
# Residual = 0.006248082727010337
# Interation = 22
# ===================
# Residual = 0.004982294331562822
# Interation = 23
# ===================
# Residual = 0.003975478583262349
# Interation = 24
# ===================
# Residual = 0.003174050406589393
# Interation = 25
# ===================
# Residual = 0.002535666735714835
# Interation = 26
# ===================
# Residual = 0.0020268241724207487
# Interation = 27
# ===================
# Residual = 0.0016209837056801483
# Interation = 28
# ===================
# Residual = 0.001297102200635598
# Interation = 29
# ===================
# Residual = 0.0010384794985183639
# Interation = 30
# ===================
# Residual = 0.0008318514239283563
# Interation = 31
# ===================
# Residual = 0.0006666750259914597
# Interation = 32
# ===================
# Residual = 0.0005345644958115337
# Interation = 33
# ===================
# Residual = 0.0004288454434763343
# Interation = 34
# ===================
# Residual = 0.00034420231706145586
# Interation = 35
# ===================
# Residual = 0.00027639923049050047
# Interation = 36
# ===================
# Residual = 0.00022205872347932923
# Interation = 37
# ===================
# Residual = 0.0001784862919899231
# Interation = 38
# ===================
# Residual = 0.0001435311172313064
# Interation = 39
# ===================
# Residual = 0.0001154754491225007
# Interation = 40
# ===================
# Residual = 9.294669121924646e-05
# Interation = 41
# ===================
# Residual = 7.484748458464046e-05
# Interation = 42
# ===================
# Residual = 6.030007243671203e-05
# Interation = 43
# ===================
# Residual = 4.860200308887898e-05
# Interation = 44
# ===================
# Residual = 3.91908407365124e-05
# Interation = 45
# ===================
# Residual = 3.1616037006890835e-05
# Interation = 46
# ===================
# Residual = 2.5516498312869895e-05
# Interation = 47
# ===================
# Residual = 2.0602686258299194e-05
# Interation = 48
# ===================
# Residual = 1.66423278018204e-05
# Interation = 49
# ===================
# Residual = 1.3449001402628837e-05
# Interation = 50
# ===================
# Residual = 1.0873015793270643e-05
# Interation = 51
# ===================
# Residual = 8.794117272156617e-06
# Interation = 52
# ===================
# Residual = 7.115656121814111e-06
# Interation = 53
# ===================
# Residual = 5.759917939443335e-06
# Interation = 54
# ===================
# Residual = 4.664385472875088e-06
# Interation = 55
# ===================
# Residual = 3.7787441017545553e-06
# Interation = 56
# ===================
# Residual = 3.0624818616515137e-06
# Interation = 57
# ===================
# Residual = 2.482965106316363e-06
# Interation = 58
# ===================
# Residual = 2.0138947875136774e-06
# Interation = 59
# ===================
# Residual = 1.634067539252183e-06
# Interation = 60
# ===================
# Residual = 1.3263808883224536e-06
# Interation = 61
# ===================
# Residual = 1.0770341484978729e-06
# Interation = 62
# ===================
# Residual = 8.748862034704123e-07
# Interation = 63
# ===================
# Residual = 7.109391452135409e-07
# Interation = 64
# ===================
# Residual = 5.779229200259041e-07
# Interation = 65
# ===================
# Residual = 4.6996107640908705e-07
# Interation = 66
# ===================
# Residual = 3.82301647732033e-07
# Interation = 67
# ===================
# Residual = 3.111003998697192e-07
# Interation = 68
# ===================
# Residual = 2.532461779658265e-07
# Interation = 69
# ===================
# Residual = 2.0622007689067567e-07
# Interation = 70
# ===================
# Residual = 1.679819017427306e-07
# Interation = 71
# ===================
# Residual = 1.3687852615118775e-07
# Interation = 72
# ===================
# Residual = 1.1156993971240495e-07
# Interation = 73
# ===================
# Residual = 9.096952081070303e-08
# Interation = 74
# ===================
# Residual = 7.419578267566786e-08
# Interation = 75
# ===================
# Residual = 6.053337957241028e-08
# Interation = 76
# ===================
# Residual = 4.940157487171073e-08
# Interation = 77
# ===================
# Residual = 4.0328737701719895e-08
# Interation = 78
# ===================
# Residual = 3.293170594245339e-08
# Interation = 79
# ===================
# Residual = 2.6899079298078657e-08
# Interation = 80
# ===================
# Residual = 2.197769022138891e-08
# Interation = 81
# ===================
# Residual = 1.79616379239733e-08
# Interation = 82
# ===================
# Residual = 1.4683411839333587e-08
# Interation = 83
# ===================
# Residual = 1.2006682157946641e-08
# Interation = 84
# ===================
# Residual = 9.820462981345441e-09
# Interation = 85
# ===================
# Residual = 8.03436934650613e-09
# Interation = 86
# ===================
# Residual = 6.574768916601748e-09
# Interation = 87
# ===================
# Residual = 5.381656915157952e-09
# Interation = 88
# ===================
# Residual = 4.4061188746362284e-09
# Interation = 89
# ===================
# Residual = 3.608271997391956e-09
# Interation = 90
# ===================
# Residual = 2.9555837731061537e-09
# Interation = 91
# ===================
# Residual = 2.4215105585231694e-09
# Interation = 92
# ===================
# Residual = 1.98438725105988e-09
# Interation = 93
# ===================
# Residual = 1.626528679478839e-09
# Interation = 94
# ===================
# Residual = 1.3334927873900164e-09
# Interation = 95
# ===================
# Residual = 1.093479689753314e-09
# Interation = 96
# ===================
# Residual = 8.968538637916671e-10
# Interation = 97
# ===================
# Residual = 7.357318282084232e-10
# Interation = 98
# ===================
# Residual = 6.036771807301009e-10
# Interation = 99
# ===================
# Residual = 4.954206959536091e-10
# Interation = 100
# ===================
# Residual = 4.066564109712777e-10
# Interation = 101
# ===================
# Residual = 3.3385968859449026e-10
# Interation = 102
# ===================
# Residual = 2.741432542271867e-10
# Interation = 103
# ===================
# Residual = 2.2514922355976092e-10
# Interation = 104
# ===================
# Residual = 1.8494336478083062e-10
# Interation = 105
# ===================
# Residual = 1.519440922007808e-10
# Interation = 106
# ===================
# Residual = 1.2485559086212413e-10
# Interation = 107
# ===================
# Residual = 1.0261128510477203e-10
# Interation = 108
# ===================
# Residual = 8.434531874648706e-11
# Interation = 109
# ===================

# %% [markdown]
# Error DMM on fine grid

# %%
UREAL = Ureal.reshape(sqrtinputsize,sqrtinputsize)
DMMU = DMM_U.reshape(sqrtinputsize,sqrtinputsize)
deltaU = DMMU - UREAL

energynorm = np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=0),np.gradient(UREAL,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=1),np.gradient(UREAL,h,axis=1)),Media)*(h**2)))
l2norm = np.sqrt((np.linalg.norm(UREAL)**2)*(h**2))
h1norm = np.sqrt((np.linalg.norm(np.gradient(UREAL,h,axis=0))**2+np.linalg.norm(np.gradient(UREAL,h,axis=1))**2+np.linalg.norm(UREAL)**2)*(h**2))

print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),Media)*(h**2))))
print('L2 norm: ')
print(np.sqrt((np.linalg.norm(deltaU)**2)*(h**2)))
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2)))

print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),Media)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),Media)*(h**2)))/energynorm)
print('L2 norm: ')
print(np.sqrt((np.linalg.norm(deltaU)**2)*(h**2))/l2norm)
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2))/h1norm)
# Out:
# Energy norm:
# 3.064822850097476
# L2 norm:
# 0.3224776856581147
# H1 norm:
# 5.011567680314904
# Energy norm:
# 0.4411877314097743
# L2 norm:
# 0.6449553713162295
# H1 norm:
# 0.5435700776949577

# %% [markdown]
# Solution

# %%
plt.imshow(DMM_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# Residual

# %%
plt.semilogy(DMM_Res)

# %% [markdown]
# Radius

# %%
DMM_Radius = Rhonew
print('DMM_Radius = {}'.format(DMM_Radius))
# Out:
# DMM_Radius = 0.8833848402967693

# %% [markdown]
# Rrestriction matrix after optimization

# %%
plt.imshow(Rnew)
plt.colorbar()

# %% [markdown]
# Rrestriction matrix (log(abs()) after optimization

# %%
plt.imshow(np.log(np.abs(Rnew)))
plt.colorbar()

# %% [markdown]
# Basis after optimization

# %%
basis1 = Rnew[int(0.45*outputsize)][:]
basis1 = basis1.reshape([sqrtinputsize,sqrtinputsize])
plt.imshow(basis1)
plt.colorbar()

# %%
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
size=basis1.shape
Y=np.arange(0,size[0],1)     
X=np.arange(0,size[1],1)

X,Y=np.meshgrid(X,Y)    
fig=plt.figure()
ax=fig.gca(projection='3d') 
ax.plot_surface(X,Y,basis1)
plt.show()

# %%
plt.plot(basis1[:][int(sqrtinputsize/2)])

# %% [markdown]
# Basis after optimization (log(abs()))

# %%
plt.imshow(np.log(np.abs(basis1)))
plt.colorbar()

# %%
fig=plt.figure()
ax=fig.gca(projection='3d') 
ax.plot_surface(X,Y,np.log(np.abs(basis1)))
plt.show()

# %%
plt.plot(np.log(np.abs(basis1[:][int(sqrtinputsize/2)])))

# %% [markdown]
# FEM use basis from global DMM

# %%
Anew = np.zeros([outputsize,outputsize])
[X1, Y1] = np.meshgrid(np.linspace(0, 1, sqrtinputsize),np.linspace(0, 1, sqrtinputsize))
[X2, Y2] = np.meshgrid(np.linspace(0, 1, sqrtoutputsize),np.linspace(0, 1, sqrtoutputsize))
A = a(X1,Y1)
for i in range(outputsize):
    for j in range(outputsize):
        basisi = Rnew[i][:].reshape([sqrtinputsize,sqrtinputsize])
        basisj = Rnew[j][:].reshape([sqrtinputsize,sqrtinputsize])
        gxbasisi = np.gradient(basisi,axis=0)/h
        gybasisi = np.gradient(basisi,axis=1)/h
        gxbasisj = np.gradient(basisj,axis=0)/h
        gybasisj = np.gradient(basisj,axis=1)/h
        Anew[i][j]=(np.sum(A*gxbasisi*gxbasisj)+np.sum(A*gybasisi*gybasisj))*(H**2)
        
Fnew = np.zeros([outputsize,1])
for i in range(outputsize):
    basisi = Rnew[i][:].reshape([sqrtinputsize,sqrtinputsize])
    F = rightf(X1,Y1)
    Fnew[i]=np.sum(F*basisi)*(H**2)
    
UnewCoarse = np.linalg.solve(Anew,Fnew)
Unew = np.zeros([sqrtinputsize,sqrtinputsize])
for i in range(outputsize):
    basisi = Rnew[i][:].reshape([sqrtinputsize,sqrtinputsize])
    Unew = Unew + UnewCoarse[i]*basisi

plt.imshow(Unew)
plt.colorbar()

UREAL = u_real(X1,Y1).reshape(sqrtinputsize,sqrtinputsize)
deltaU = Unew - UREAL
A = a(X1,Y1)

energynorm = np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=0),np.gradient(UREAL,h,axis=0)),A)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(UREAL,h,axis=1),np.gradient(UREAL,h,axis=1)),A)*(h**2)))
l2norm = np.sqrt((np.sum(UREAL**2))*(h**2))
h1norm = np.sqrt((np.linalg.norm(np.gradient(UREAL,h,axis=0))**2+np.linalg.norm(np.gradient(UREAL,h,axis=1))**2+np.linalg.norm(UREAL)**2)*(h**2))
print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),A)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),A)*(h**2))))
print('L2 norm: ')
print(np.sqrt((np.linalg.norm(deltaU)**2)*(h**2)))
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2)))



print('Energy norm: ')
print(np.sqrt(np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=0),np.gradient(deltaU,h,axis=0)),A)*(h**2))+np.sum(np.multiply(np.multiply(np.gradient(deltaU,h,axis=1),np.gradient(deltaU,h,axis=1)),A)*(h**2)))/energynorm)
print('L2 norm: ')
print(np.sqrt((np.sum(deltaU**2))*(h**2))/l2norm)
print('H1 norm: ')
print(np.sqrt((np.linalg.norm(np.gradient(deltaU,h,axis=0))**2+np.linalg.norm(np.gradient(deltaU,h,axis=1))**2+np.linalg.norm(deltaU)**2)*(h**2))/h1norm)
# Out:
# Energy norm:
# 3.166545102368695
# L2 norm:
# 0.27229034001723423
# H1 norm:
# 5.138126057534861
# Energy norm:
# 0.45583086476803825
# L2 norm:
# 0.5445806800344685
# H1 norm:
# 0.5572969893774269

# %%
import os
os.system("say 'The program has finished, Please check the results'")
# Out:
# 0
