# %% [markdown]
# **这个Notebook不需要文件夹中任何一个.py文件, 所有函数在Notebook中定义.**

# %% [markdown]
# ## Package Import

# %%
import numpy as np
import matplotlib.pyplot as plt
import autograd.numpy as np
from autograd import grad
import pyamg

# %% [markdown]
# ## Define R, P, Poisson, Nonlinear Poisson

# %%
def Restriction(inputsize):
    inputsize = int(inputsize)
    sqrtinputsize = int(np.sqrt(inputsize))
    outputsize = int((2**(np.log2(np.sqrt(inputsize)+1)-1)-1)**2)
    sqrtoutputsize = int(np.sqrt(outputsize))
    OUTPUT = np.zeros([outputsize, inputsize])
    for j in range(sqrtoutputsize):
        for i in range(sqrtoutputsize):
            OUTPUT[i+sqrtoutputsize*j][2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][1+2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2+2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][1+sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/4
            OUTPUT[i+sqrtoutputsize*j][2+sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2*sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][1+2 *
                                       sqrtinputsize + 2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2+2 *
                                       sqrtinputsize+2*i+j*2*sqrtinputsize] = 1/16
    return OUTPUT


def Interpolation(inputsize):
    inputsize = int(inputsize)
    OUTPUT = 4*np.transpose(Restriction(inputsize))
    return OUTPUT


def Poisson(inputsize):
    inputsize = int(inputsize)
    sqrtinputsize = int(np.sqrt(inputsize))
    A1 = 2*np.eye(sqrtinputsize)
    for i in range(sqrtinputsize-1):
        A1[i, i+1] = -1
        A1[i+1, i] = -1
    I = np.eye(sqrtinputsize)
    OUTPUT = (np.kron(I, A1)+np.kron(A1, I))
    return OUTPUT


def NonlinearPoisson(inputsize):
    inputsize = int(inputsize)
    sqrtinputsize = int(np.sqrt(inputsize))
    area = 1
    [X, Y] = np.meshgrid(np.linspace(0, 1, sqrtinputsize),
                         np.linspace(0, 1, sqrtinputsize))
    A = area*(a(X, Y).reshape([inputsize, 1]))
    Poi = Poisson(inputsize)
    for i in range(inputsize):
        Poi[i][:] = A[i]*Poi[i][:]
    OUTPUT = Poi
    return OUTPUT

# %% [markdown]
# ## Define Multigrid

# %%
def Multigrid_circle(inputsize, A_A, B, P_A, R_A, s, w, NUM_EPOCH):
    A = np.matrix(A_A)
    P = np.matrix(P_A)
    R = np.matrix(R_A)
    M = np.matrix(w**(-1)*np.diag(np.diag(A)))
    K = M - A
    C = np.linalg.inv(M)*K
    b = np.linalg.inv(M)*B
    U0 = np.matrix(np.zeros([inputsize, 1]))
    RESIDUAL = []
    for i in range(NUM_EPOCH):
        for j in range(s):
            U0 = C*U0+b
        r = B - A*U0
        Residual = np.linalg.norm(r,2)
        rc = R*r
        Ac = R*A*P
        Uc = np.linalg.solve(Ac, rc)
        U = U0 + P*Uc
        for k in range(s):
            U = C*U+b
        U0 = U
        RESIDUAL.append(Residual)
        print("Residual = {}".format(Residual))
        print("Interation = {}".format(i))
        print("===================")
    return U0, RESIDUAL

# %% [markdown]
# ## Define Spectral Radius Calculator

# %%
def rho(inputsize,A,P,R,w,s):
    M = (w**(-1)) * np.diag(np.diag(A))
    K = M - A
    MK = np.matmul(np.linalg.inv(M),K)
    I = np.eye(inputsize)
    IPRAPRA = I - np.matmul(np.matmul(np.matmul(P,np.linalg.inv(np.matmul(np.matmul(R,A),P))),R),A)
    C = np.matmul(np.matmul(MK,IPRAPRA),MK)
    for i in range(5):
        C = np.matmul(C,C)
    radius = np.linalg.norm(C)**(1/32)
    return radius

def rhoAuto(INPUT):
    P = INPUT[0]
    R = INPUT[1]
    w = INPUT[2]
    M = (w**(-1)) * np.diag(np.diag(A1))
    K = M - A1
    MK = np.matmul(np.linalg.inv(M),K)
    I = np.eye(inputsize)
    IPRAPRA = I - np.matmul(np.matmul(np.matmul(P,np.linalg.inv(np.matmul(np.matmul(R,A1),P))),R),A1)
    C = np.matmul(np.matmul(MK,IPRAPRA),MK)
    for i in range(5):
        C = np.matmul(C,C)
    radius = np.linalg.norm(C)**(1/32)
    return radius

# %% [markdown]
# ## Define Optimizer

# %%
def optimizer_GD(inputsize, A, P, R, w, s, learning_rate):
    rhoold = rho(inputsize,A,P,R,w,s)
    INPUT = [P,R,w]
    rhoGra = grad(rhoAuto)
    delta = rhoGra(INPUT)
    P -= learning_rate*delta[0]
    R -= learning_rate*delta[1]
    w -= learning_rate*delta[2]
    rhonew = rho(inputsize,A,P,R,w,s)
    return P, R, w, rhoold, rhonew

def homotopy_optimizer_GD(inputsize, A0, A1, P, R, w, s, learning_rate ,accept_radius ,step_length):
    Rhoold = rho(inputsize,A1,P,R,w,s)
    L = step_length
    while L < 1:
        M = (1-L)*A0 + L*A1
        Pnew, Rnew, wnew, rhoold, rhonew = optimizer_GD(inputsize, M, P, R, w, s, learning_rate)
        if rhonew > accept_radius:
            step_length = 0.1*step_length
            learning_rate = 0.1*learning_rate
            print('Decrease the step_length, learning_rate and try again!!')
            print("step_length = {}".format(step_length))      
            print("learning_rate = {}".format(learning_rate))
            print("rhonew = {}".format(rhonew))
            print("===================")
            L = step_length
        else:
            P = Pnew
            R = Rnew
            w = wnew
            L += step_length
            print("L = {}".format(L))
            print("rho = {}".format(rhonew))
            print("===================")
    Rhonew = rhonew
    return P, R, w, Rhoold, Rhonew

# %% [markdown]
# # Experiment 1

# %%
u_real = lambda x,y: np.sin(np.pi*3*x)*np.sin(np.pi*5*y)
rightf = lambda x,y:  34*np.pi**2*np.sin(3*np.pi*x)*np.sin(5*np.pi*y)

# %%
finegridsize = 6
inputsize = (2**finegridsize-1)**2
inputsize = int(inputsize)
sqrtinputsize = int(np.sqrt(inputsize))
outputsize = int((2**(np.log2(np.sqrt(inputsize)+1)-1)-1)**2)
sqrtoutputsize = int(np.sqrt(outputsize))
h = 1/(sqrtinputsize+1)
A0 = Poisson(inputsize)
A1 = A0
[X, Y] = np.meshgrid(np.linspace(0, 1, sqrtinputsize),np.linspace(0, 1, sqrtinputsize))
RightF = rightf(X,Y)*h**2
RightF = RightF.reshape(inputsize, 1)
R = Restriction(inputsize)
P = Interpolation(inputsize)
s = 1
w = 2/3
MAX_ITER = 50

# %% [markdown]
# ## GMM

# %% [markdown]
# **Calculate Result and Residual**

# %%
GMM_U, GMM_Res = Multigrid_circle(inputsize, A1, RightF, P, R, s, w, MAX_ITER)
# Out:
# Residual = 2.503099251329196
# Interation = 0
# ===================
# Residual = 0.22744827105225837
# Interation = 1
# ===================
# Residual = 0.030724721681700515
# Interation = 2
# ===================
# Residual = 0.005703096333607183
# Interation = 3
# ===================
# Residual = 0.0018022340376319358
# Interation = 4
# ===================
# Residual = 0.0007089030049745723
# Interation = 5
# ===================
# Residual = 0.000291575461055154
# Interation = 6
# ===================
# Residual = 0.00012164766558888646
# Interation = 7
# ===================
# Residual = 5.11665235151337e-05
# Interation = 8
# ===================
# Residual = 2.16450073864671e-05
# Interation = 9
# ===================
# Residual = 9.196369584079576e-06
# Interation = 10
# ===================
# Residual = 3.920682122280042e-06
# Interation = 11
# ===================
# Residual = 1.676143301616071e-06
# Interation = 12
# ===================
# Residual = 7.182208189246246e-07
# Interation = 13
# ===================
# Residual = 3.0835124737944503e-07
# Interation = 14
# ===================
# Residual = 1.3260291121006058e-07
# Interation = 15
# ===================
# Residual = 5.710630984117087e-08
# Interation = 16
# ===================
# Residual = 2.462416696420298e-08
# Interation = 17
# ===================
# Residual = 1.0629729317453228e-08
# Interation = 18
# ===================
# Residual = 4.593182259371807e-09
# Interation = 19
# ===================
# Residual = 1.9865157166260252e-09
# Interation = 20
# ===================
# Residual = 8.598442597041312e-10
# Interation = 21
# ===================
# Residual = 3.724478119098645e-10
# Interation = 22
# ===================
# Residual = 1.6143606679081853e-10
# Interation = 23
# ===================
# Residual = 7.001697710360201e-11
# Interation = 24
# ===================
# Residual = 3.03838956677944e-11
# Interation = 25
# ===================
# Residual = 1.3192136572494071e-11
# Interation = 26
# ===================
# Residual = 5.730278105563715e-12
# Interation = 27
# ===================
# Residual = 2.490437734505998e-12
# Interation = 28
# ===================
# Residual = 1.082614887099783e-12
# Interation = 29
# ===================
# Residual = 4.708387998493626e-13
# Interation = 30
# ===================
# Residual = 2.0498213159483066e-13
# Interation = 31
# ===================
# Residual = 8.98414217003129e-14
# Interation = 32
# ===================
# Residual = 4.067389797608784e-14
# Interation = 33
# ===================
# Residual = 2.106257122255561e-14
# Interation = 34
# ===================
# Residual = 1.499238117217194e-14
# Interation = 35
# ===================
# Residual = 1.3318099728647927e-14
# Interation = 36
# ===================
# Residual = 1.2555516779647526e-14
# Interation = 37
# ===================
# Residual = 1.2885200803575836e-14
# Interation = 38
# ===================
# Residual = 1.3132053076869236e-14
# Interation = 39
# ===================
# Residual = 1.3063098291008902e-14
# Interation = 40
# ===================
# Residual = 1.2481533352684755e-14
# Interation = 41
# ===================
# Residual = 1.296294327721435e-14
# Interation = 42
# ===================
# Residual = 1.2686964969362794e-14
# Interation = 43
# ===================
# Residual = 1.2878817917629371e-14
# Interation = 44
# ===================
# Residual = 1.2884091257789534e-14
# Interation = 45
# ===================
# Residual = 1.3033055367562713e-14
# Interation = 46
# ===================
# Residual = 1.2834127729810537e-14
# Interation = 47
# ===================
# Residual = 1.3120038535080074e-14
# Interation = 48
# ===================
# Residual = 1.2824921962818134e-14
# Interation = 49
# ===================

# %% [markdown]
# **Plot Result**

# %%
plt.imshow(GMM_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# **Plot Residual**

# %%
plt.semilogy(GMM_Res)

# %% [markdown]
# **Calculate Spectral Radius**

# %%
GMM_Radius = rho(inputsize,A1,P,R,w,s)
print('GMM_Radius = {}'.format(GMM_Radius))
# Out:
# GMM_Radius = 0.4638002613988788

# %% [markdown]
# ## AMG

# %% [markdown]
# **Define Solver and Solve**

# %%
amg_solver = pyamg.classical.classical.ruge_stuben_solver(A1,max_levels = 2)
pyamg.relaxation.smoothing.change_smoothers(amg_solver,presmoother=("sor", {"omega": w, "iterations": s}),postsmoother=None)
AMG_Res = []
print(amg_solver)
AMG_U = amg_solver.solve(RightF, maxiter = MAX_ITER, tol=0, residuals=AMG_Res)
# Out:
# D:\anaconda\lib\site-packages\pyamg\classical\classical.py:101: SparseEfficiencyWarning: Implicit conversion of A to CSR
#   SparseEfficiencyWarning)
# multilevel_solver
# Number of Levels:     2
# Operator Complexity:  1.886
# Grid Complexity:      1.500
# Coarse Solver:        'pinv2'
#   level   unknowns     nonzeros
#     0         3969        19593 [53.02%]
#     1         1985        17361 [46.98%]

# %% [markdown]
# **Plot Result**

# %%
plt.imshow(AMG_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# **Plot Residual**

# %%
plt.semilogy(AMG_Res)

# %% [markdown]
# ## DMM

# %% [markdown]
# **Optimize R, P, $\omega$**

# %%
Pnew, Rnew, wnew, Rhoold, Rhonew = homotopy_optimizer_GD(inputsize, A1, A1, P, R, w, s, learning_rate = 1e-2 ,accept_radius = GMM_Fro_norm,step_length = 1e-2)
# Out:
# L = 0.02
# rho = 0.45940200771524065
# ===================
# L = 0.03
# rho = 0.4544168500696842
# ===================
# L = 0.04
# rho = 0.4494893371004232
# ===================
# L = 0.05
# rho = 0.4446186936356254
# ===================
# L = 0.060000000000000005
# rho = 0.4398041594780984
# ===================
# L = 0.07
# rho = 0.4350449889031331
# ===================
# L = 0.08
# rho = 0.4303404501834616
# ===================
# L = 0.09
# rho = 0.4256898251394015
# ===================
# L = 0.09999999999999999
# rho = 0.4210924087124606
# ===================
# L = 0.10999999999999999
# rho = 0.41654750856539957
# ===================
# L = 0.11999999999999998
# rho = 0.4120544455073026
# ===================
# L = 0.12999999999999998
# rho = 0.4076126973294868
# ===================
# L = 0.13999999999999999
# rho = 0.40324819816710294
# ===================
# L = 0.15
# rho = 0.4025920988343973
# ===================
# L = 0.16
# rho = 0.43471932312675005
# ===================
# L = 0.17
# rho = 0.38993870763373106
# ===================
# L = 0.18000000000000002
# rho = 0.38574152351520474
# ===================
# L = 0.19000000000000003
# rho = 0.3815973262572911
# ===================
# L = 0.20000000000000004
# rho = 0.3776663835236964
# ===================
# L = 0.21000000000000005
# rho = 0.37653141266384726
# ===================
# L = 0.22000000000000006
# rho = 0.37723508263436784
# ===================
# L = 0.23000000000000007
# rho = 0.37672130736631143
# ===================
# L = 0.24000000000000007
# rho = 0.37788960415124345
# ===================
# L = 0.25000000000000006
# rho = 0.3767983792220231
# ===================
# L = 0.26000000000000006
# rho = 0.3860745225717047
# ===================
# L = 0.2700000000000001
# rho = 0.3885197771593709
# ===================
# L = 0.2800000000000001
# rho = 0.38434136509765376
# ===================
# L = 0.2900000000000001
# rho = 0.38023401115253885
# ===================
# L = 0.3000000000000001
# rho = 0.37680298489952996
# ===================
# L = 0.3100000000000001
# rho = 0.37687492789323707
# ===================
# L = 0.3200000000000001
# rho = 0.37780377732512077
# ===================
# L = 0.3300000000000001
# rho = 0.37624840650178504
# ===================
# L = 0.34000000000000014
# rho = 0.3767007461297181
# ===================
# L = 0.35000000000000014
# rho = 0.37651111758046285
# ===================
# L = 0.36000000000000015
# rho = 0.3778074646384785
# ===================
# L = 0.37000000000000016
# rho = 0.3760952658901015
# ===================
# L = 0.38000000000000017
# rho = 0.37682184812129355
# ===================
# L = 0.3900000000000002
# rho = 0.37670896171636903
# ===================
# L = 0.4000000000000002
# rho = 0.37854057538070524
# ===================
# L = 0.4100000000000002
# rho = 0.37705505678955364
# ===================
# L = 0.4200000000000002
# rho = 0.37595115378383775
# ===================
# L = 0.4300000000000002
# rho = 0.37629556333214276
# ===================
# L = 0.4400000000000002
# rho = 0.3788841838433987
# ===================
# L = 0.45000000000000023
# rho = 0.3792980360020076
# ===================
# L = 0.46000000000000024
# rho = 0.3775606481301914
# ===================
# L = 0.47000000000000025
# rho = 0.37799411750731604
# ===================
# L = 0.48000000000000026
# rho = 0.37650575293667005
# ===================
# L = 0.49000000000000027
# rho = 0.37640471934475594
# ===================
# L = 0.5000000000000002
# rho = 0.3777633168823174
# ===================
# L = 0.5100000000000002
# rho = 0.37654150187108315
# ===================
# L = 0.5200000000000002
# rho = 0.3788322004206922
# ===================
# L = 0.5300000000000002
# rho = 0.3796266838130482
# ===================
# L = 0.5400000000000003
# rho = 0.377920260966966
# ===================
# L = 0.5500000000000003
# rho = 0.3777213636166139
# ===================
# L = 0.5600000000000003
# rho = 0.3759926076770466
# ===================
# L = 0.5700000000000003
# rho = 0.37732946764320763
# ===================
# L = 0.5800000000000003
# rho = 0.379864050666472
# ===================
# L = 0.5900000000000003
# rho = 0.3791350917544598
# ===================
# L = 0.6000000000000003
# rho = 0.37669340978737814
# ===================
# L = 0.6100000000000003
# rho = 0.37626101176422827
# ===================
# L = 0.6200000000000003
# rho = 0.37679278121554033
# ===================
# L = 0.6300000000000003
# rho = 0.37985626614121826
# ===================
# L = 0.6400000000000003
# rho = 0.3794448705321805
# ===================
# L = 0.6500000000000004
# rho = 0.3772792310874005
# ===================
# L = 0.6600000000000004
# rho = 0.37697172081525715
# ===================
# L = 0.6700000000000004
# rho = 0.37612790013005654
# ===================
# L = 0.6800000000000004
# rho = 0.37816797350444903
# ===================
# L = 0.6900000000000004
# rho = 0.3783601531578746
# ===================
# L = 0.7000000000000004
# rho = 0.37719402955619274
# ===================
# L = 0.7100000000000004
# rho = 0.3766035482348573
# ===================
# L = 0.7200000000000004
# rho = 0.37634554746739135
# ===================
# L = 0.7300000000000004
# rho = 0.377863926999352
# ===================
# L = 0.7400000000000004
# rho = 0.37593465301481976
# ===================
# L = 0.7500000000000004
# rho = 0.3763307863087168
# ===================
# L = 0.7600000000000005
# rho = 0.37783175982889944
# ===================
# L = 0.7700000000000005
# rho = 0.3769479620859854
# ===================
# L = 0.7800000000000005
# rho = 0.37655684742262124
# ===================
# L = 0.7900000000000005
# rho = 0.376378276717595
# ===================
# L = 0.8000000000000005
# rho = 0.3763492978291847
# ===================
# L = 0.8100000000000005
# rho = 0.3768889127897034
# ===================
# L = 0.8200000000000005
# rho = 0.37632240585740306
# ===================
# L = 0.8300000000000005
# rho = 0.3774378578036222
# ===================
# L = 0.8400000000000005
# rho = 0.37587991897336215
# ===================
# L = 0.8500000000000005
# rho = 0.37632089189314966
# ===================
# L = 0.8600000000000005
# rho = 0.3762642506267054
# ===================
# L = 0.8700000000000006
# rho = 0.3775207695310473
# ===================
# L = 0.8800000000000006
# rho = 0.3757793283964159
# ===================
# L = 0.8900000000000006
# rho = 0.3760954511894577
# ===================
# L = 0.9000000000000006
# rho = 0.37620577715510534
# ===================
# L = 0.9100000000000006
# rho = 0.37739970673997153
# ===================
# L = 0.9200000000000006
# rho = 0.37579980591415146
# ===================
# L = 0.9300000000000006
# rho = 0.37620189008586885
# ===================
# L = 0.9400000000000006
# rho = 0.37621562302594164
# ===================
# L = 0.9500000000000006
# rho = 0.3774468213770403
# ===================
# L = 0.9600000000000006
# rho = 0.37576427297504544
# ===================
# L = 0.9700000000000006
# rho = 0.3761126264442133
# ===================
# L = 0.9800000000000006
# rho = 0.376190815662856
# ===================
# L = 0.9900000000000007
# rho = 0.3773991524540211
# ===================
# L = 1.0000000000000007
# rho = 0.3757678220272322
# ===================

# %% [markdown]
# **Calculate Result and Residual**

# %%
DMM_U, DMM_Res = Multigrid_circle(inputsize, A1, RightF, Pnew, Rnew, s, wnew, 40)
# Out:
# Residual = 2.4957903747436836
# Interation = 0
# ===================
# Residual = 0.09135924108010184
# Interation = 1
# ===================
# Residual = 0.00851030477826739
# Interation = 2
# ===================
# Residual = 0.002152946596277506
# Interation = 3
# ===================
# Residual = 0.0006853832841559544
# Interation = 4
# ===================
# Residual = 0.00022562842956597978
# Interation = 5
# ===================
# Residual = 7.539059119876107e-05
# Interation = 6
# ===================
# Residual = 2.5423578248262014e-05
# Interation = 7
# ===================
# Residual = 8.627511301180249e-06
# Interation = 8
# ===================
# Residual = 2.9411772222293884e-06
# Interation = 9
# ===================
# Residual = 1.0061784955108428e-06
# Interation = 10
# ===================
# Residual = 3.451710407036181e-07
# Interation = 11
# ===================
# Residual = 1.1868093433771079e-07
# Interation = 12
# ===================
# Residual = 4.0884329785801226e-08
# Interation = 13
# ===================
# Residual = 1.410730995678682e-08
# Interation = 14
# ===================
# Residual = 4.874751917616117e-09
# Interation = 15
# ===================
# Residual = 1.6865957922585532e-09
# Interation = 16
# ===================
# Residual = 5.842019840272766e-10
# Interation = 17
# ===================
# Residual = 2.0256440552309064e-10
# Interation = 18
# ===================
# Residual = 7.030275781278536e-11
# Interation = 19
# ===================
# Residual = 2.4420621069337857e-11
# Interation = 20
# ===================
# Residual = 8.489825682107574e-12
# Interation = 21
# ===================
# Residual = 2.9539262173910042e-12
# Interation = 22
# ===================
# Residual = 1.0282388727169856e-12
# Interation = 23
# ===================
# Residual = 3.585162727717008e-13
# Interation = 24
# ===================
# Residual = 1.2551897390094186e-13
# Interation = 25
# ===================
# Residual = 4.577500048684462e-14
# Interation = 26
# ===================
# Residual = 2.0159193464897655e-14
# Interation = 27
# ===================
# Residual = 1.3806570732607932e-14
# Interation = 28
# ===================
# Residual = 1.2830143291435373e-14
# Interation = 29
# ===================
# Residual = 1.1948945589337954e-14
# Interation = 30
# ===================
# Residual = 1.2371060134894491e-14
# Interation = 31
# ===================
# Residual = 1.2489409111004679e-14
# Interation = 32
# ===================
# Residual = 1.2502006930954345e-14
# Interation = 33
# ===================
# Residual = 1.2574849876427353e-14
# Interation = 34
# ===================
# Residual = 1.2750375052865886e-14
# Interation = 35
# ===================
# Residual = 1.2058336881406778e-14
# Interation = 36
# ===================
# Residual = 1.2243674653668758e-14
# Interation = 37
# ===================
# Residual = 1.2203588867352734e-14
# Interation = 38
# ===================
# Residual = 1.219480707045496e-14
# Interation = 39
# ===================

# %% [markdown]
# **Plot Result**

# %%
plt.imshow(DMM_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# **Plot Residual**

# %%
plt.semilogy(DMM_Res)

# %% [markdown]
# **Calculate Spectral Radius**

# %%
DMM_Radius = Rhonew
print('DMM_Radius = {}'.format(DMM_Radius))
# Out:
# DMM_Radius = 0.3757678220272322

# %% [markdown]
# ## Compare

# %%
print('GMM_Radius = {}'.format(GMM_Radius))
print('DMM_Radius = {}'.format(DMM_Radius))
print("GMM_Radius : DMM_Radius = 1 : %f" %(DMM_Radius/GMM_Radius))
# Out:
# GMM_Radius = 0.4638002613988788
# DMM_Radius = 0.3757678220272322
# GMM_Radius : DMM_Radius = 1 : 0.810193

# %%
plt.semilogy(GMM_Res, label = 'GMM_Res')
plt.semilogy(AMG_Res, label = 'AMG_Res')
plt.semilogy(DMM_Res, label = 'DMM_Res')
plt.legend(loc='upper right')

# %% [markdown]
# ## R, P and  $\omega$ after Optimization

# %%
print('omega after optimization = {}'.format(wnew))
# Out:
# omega after optimization = 0.800724187796087

# %%
print('P after optimization ')
plt.imshow(np.log10(np.abs(Pnew)))
plt.colorbar()
# Out:
# P after optimization

# %%
print('R after optimization ')
plt.imshow(np.log10(np.abs(Rnew)))
plt.colorbar()
# Out:
# R after optimization

# %%
print("P under log10(abs())")
plt.plot(np.log10(np.abs(Pnew))[round(0.5*inputsize)][:])
# Out:
# P under log10(abs())

# %%
print("R under log10(abs())")
plt.plot(np.log10(np.abs(Rnew))[:][round(0.5*outputsize)])
# Out:
# R under log10(abs())

# %%
import win32com.client
import winsound
speak = win32com.client.Dispatch('SAPI.SPVOICE')
speak.Speak('The program has finished, please check the result')
# Out:
# 1
