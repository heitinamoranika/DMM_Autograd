# %% [markdown]
# **这个Notebook不需要文件夹中任何一个.py文件, 所有函数在Notebook中定义.**

# %% [markdown]
# ## Package Import

# %%
import numpy as np
import matplotlib.pyplot as plt
import autograd.numpy as np
from autograd import grad
import pyamg

# %% [markdown]
# ## Define R, P, Poisson, Nonlinear Poisson

# %%
def Restriction(inputsize):
    inputsize = int(inputsize)
    sqrtinputsize = int(np.sqrt(inputsize))
    outputsize = int((2**(np.log2(np.sqrt(inputsize)+1)-1)-1)**2)
    sqrtoutputsize = int(np.sqrt(outputsize))
    OUTPUT = np.zeros([outputsize, inputsize])
    for j in range(sqrtoutputsize):
        for i in range(sqrtoutputsize):
            OUTPUT[i+sqrtoutputsize*j][2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][1+2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2+2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][1+sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/4
            OUTPUT[i+sqrtoutputsize*j][2+sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2*sqrtinputsize +
                                       2*i+j*2*sqrtinputsize] = 1/16
            OUTPUT[i+sqrtoutputsize*j][1+2 *
                                       sqrtinputsize + 2*i+j*2*sqrtinputsize] = 1/8
            OUTPUT[i+sqrtoutputsize*j][2+2 *
                                       sqrtinputsize+2*i+j*2*sqrtinputsize] = 1/16
    return OUTPUT


def Interpolation(inputsize):
    inputsize = int(inputsize)
    OUTPUT = 4*np.transpose(Restriction(inputsize))
    return OUTPUT


def Poisson(inputsize):
    inputsize = int(inputsize)
    sqrtinputsize = int(np.sqrt(inputsize))
    A1 = 2*np.eye(sqrtinputsize)
    for i in range(sqrtinputsize-1):
        A1[i, i+1] = -1
        A1[i+1, i] = -1
    I = np.eye(sqrtinputsize)
    OUTPUT = (np.kron(I, A1)+np.kron(A1, I))
    return OUTPUT


def NonlinearPoisson(inputsize):
    inputsize = int(inputsize)
    sqrtinputsize = int(np.sqrt(inputsize))
    area = 1
    [X, Y] = np.meshgrid(np.linspace(0, 1, sqrtinputsize),
                         np.linspace(0, 1, sqrtinputsize))
    A = area*(a(X, Y).reshape([inputsize, 1]))
    Poi = Poisson(inputsize)
    for i in range(inputsize):
        Poi[i][:] = A[i]*Poi[i][:]
    OUTPUT = Poi
    return OUTPUT

# %% [markdown]
# ## Define Multigrid

# %%
def Multigrid_circle(inputsize, A_A, B, P_A, R_A, s, w, NUM_EPOCH):
    A = np.matrix(A_A)
    P = np.matrix(P_A)
    R = np.matrix(R_A)
    M = np.matrix(w**(-1)*np.diag(np.diag(A)))
    K = M - A
    C = np.linalg.inv(M)*K
    b = np.linalg.inv(M)*B
    U0 = np.matrix(np.zeros([inputsize, 1]))
    RESIDUAL = []
    for i in range(NUM_EPOCH):
        for j in range(s):
            U0 = C*U0+b
        r = B - A*U0
        Residual = np.linalg.norm(r,2)
        rc = R*r
        Ac = R*A*P
        Uc = np.linalg.solve(Ac, rc)
        U = U0 + P*Uc
        for k in range(s):
            U = C*U+b
        U0 = U
        RESIDUAL.append(Residual)
        print("Residual = {}".format(Residual))
        print("Interation = {}".format(i))
        print("===================")
    return U0, RESIDUAL

# %% [markdown]
# ## Define Spectral Radius Calculator

# %%
def rho(inputsize,A,P,R,w,s):
    M = (w**(-1)) * np.diag(np.diag(A))
    K = M - A
    MK = np.matmul(np.linalg.inv(M),K)
    I = np.eye(inputsize)
    IPRAPRA = I - np.matmul(np.matmul(np.matmul(P,np.linalg.inv(np.matmul(np.matmul(R,A),P))),R),A)
    C = np.matmul(np.matmul(MK,IPRAPRA),MK)
    for i in range(5):
        C = np.matmul(C,C)
    radius = np.linalg.norm(C)**(1/32)
    return radius

def rhoAuto(INPUT):
    P = INPUT[0]
    R = INPUT[1]
    w = INPUT[2]
    M = (w**(-1)) * np.diag(np.diag(A1))
    K = M - A1
    MK = np.matmul(np.linalg.inv(M),K)
    I = np.eye(inputsize)
    IPRAPRA = I - np.matmul(np.matmul(np.matmul(P,np.linalg.inv(np.matmul(np.matmul(R,A1),P))),R),A1)
    C = np.matmul(np.matmul(MK,IPRAPRA),MK)
    for i in range(5):
        C = np.matmul(C,C)
    radius = np.linalg.norm(C)**(1/32)
    return radius

# %% [markdown]
# ## Define Optimizer

# %%
def optimizer_GD(inputsize, A, P, R, w, s, learning_rate):
    rhoold = rho(inputsize,A,P,R,w,s)
    INPUT = [P,R,w]
    rhoGra = grad(rhoAuto)
    delta = rhoGra(INPUT)
    P -= learning_rate*delta[0]
    R -= learning_rate*delta[1]
    w -= learning_rate*delta[2]
    rhonew = rho(inputsize,A,P,R,w,s)
    return P, R, w, rhoold, rhonew

def homotopy_optimizer_GD(inputsize, A0, A1, P, R, w, s, learning_rate ,accept_radius ,step_length):
    Rhoold = rho(inputsize,A1,P,R,w,s)
    L = step_length
    print("======Section 1======")
    while L < 1:
        M = (1-L)*A0 + L*A1
        Pnew, Rnew, wnew, rhoold, rhonew = optimizer_GD(inputsize, M, P, R, w, s, learning_rate)
        if rhonew > accept_radius:
            step_length = 0.1*step_length
            learning_rate = 0.1*learning_rate
            print('Decrease the step_length, learning_rate and Restart!!')
            print("step_length = {}".format(step_length))      
            print("learning_rate = {}".format(learning_rate))
            print("rhonew = {}".format(rhonew))
            print("===================")
            R = Restriction(inputsize)
            P = Interpolation(inputsize)
            w = 2/3
            L = step_length
        else:
            P = Pnew
            R = Rnew
            w = wnew
            L += step_length
            print("L = {}".format(L))
            print("rho = {}".format(rhonew))
            print("===================")
    print("======Section 2======")
    i = 0
    while rhonew <= rhoold and i<100:
        Pnew, Rnew, wnew, rhoold, rhonew = optimizer_GD(inputsize, A1, P, R, w, s, learning_rate)
        P = Pnew
        R = Rnew
        w = wnew
        print("rho = {}".format(rhonew))
        print("===================")
        i+=1
    Rhonew = rhonew
    print("======End======")
    return P, R, w, Rhoold, Rhonew

# %%
finegridsize = 5
s = 1
w = 2/3
MAX_ITER = 50

# %% [markdown]
# # Experiment 1 (with large e1, e2, e3, e4, e5)

# %% [markdown]
# 选取比较大的参数, a函数频率较小

# %%
e1 = 1/1
e2 = 1/1
e3 = 1/1
e4 = 1/1
e5 = 1/1
def u_real(x, y): return np.sin(np.pi*3*x)*np.sin(np.pi*5*y)
def rightf(x, y): return 34*np.pi**2*np.sin(3*np.pi*x)*np.sin(5*np.pi*y)*(np.sin(4*x**2*y**2)/6 + (np.sin((2*np.pi*y)/e2) + 11/10)/(6*(np.cos((2*np.pi*x)/e2) + 11/10)) + (np.cos((2*np.pi*x)/e3) + 11/10)/(6*(np.sin((2*np.pi*y)/e3) + 11/10)) + (np.sin((2*np.pi*y)/e4) + 11/10)/(6*(np.cos((2*np.pi*x)/e4) + 11/10)) + (np.cos((2*np.pi*x)/e5) + 11/10)/(6*(np.sin((2*np.pi*y)/e5) + 11/10)) + (np.sin((2*np.pi*x)/e1) + 11/10)/(6*(np.sin((2*np.pi*y)/e1) + 11/10)) + 1/6) - 3*np.pi*np.cos(3*np.pi*x)*np.sin(5*np.pi*y)*((4*x*y**2*np.cos(4*x**2*y**2))/3 + (np.pi*np.cos((2*np.pi*x)/e1))/(3*e1*(np.sin((2*np.pi*y)/e1) + 11/10)) - (np.pi*np.sin((2*np.pi*x)/e3))/(3*e3*(np.sin((2*np.pi*y)/e3) + 11/10)) - (np.pi*np.sin((2*np.pi*x)/e5))/(3*e5*(np.sin((2*np.pi*y)/e5) + 11/10)) + (np.pi*np.sin((2*np.pi*x)/e2)*(np.sin((2*np.pi*y)/e2) + 11/10))/(3*e2*(np.cos((2*x*np.pi)/e2) + 11/10)**2) + (np.pi*np.sin((2*np.pi*x)/e4)*(np.sin((2*np.pi*y)/e4) + 11/10))/(3*e4*(np.cos((2*x*np.pi)/e4) + 11/10)**2)) - 5*np.pi*np.cos(5*np.pi*y)*np.sin(3*np.pi*x)*((4*x**2*y*np.cos(4*x**2*y**2))/3 + (np.pi*np.cos((2*np.pi*y)/e2))/(3*e2*(np.cos((2*np.pi*x)/e2) + 11/10)) + (np.pi*np.cos((2*np.pi*y)/e4))/(3*e4*(np.cos((2*np.pi*x)/e4) + 11/10)) - (np.pi*np.cos((2*np.pi*y)/e3)*(np.cos((2*np.pi*x)/e3) + 11/10))/(3*e3*(np.sin((2*y*np.pi)/e3) + 11/10)**2) - (np.pi*np.cos((2*np.pi*y)/e5)*(np.cos((2*np.pi*x)/e5) + 11/10))/(3*e5*(np.sin((2*y*np.pi)/e5) + 11/10)**2) - (np.pi*np.cos((2*np.pi*y)/e1)*(np.sin((2*np.pi*x)/e1) + 11/10))/(3*e1*(np.sin((2*y*np.pi)/e1) + 11/10)**2))
def a(x, y): return (1/6)*((1.1+np.sin(2*np.pi*x/e1))/(1.1+np.sin(2*np.pi*y/e1))+(1.1+np.sin(2*np.pi*y/e2))/(1.1+np.cos(2*np.pi*x/e2))+(1.1+np.cos(2*np.pi*x/e3))/(1.1+np.sin(2*np.pi*y/e3))+(1.1+np.sin(2*np.pi*y/e4))/(1.1+np.cos(2*np.pi*x/e4))+(1.1+np.cos(2*np.pi*x/e5))/(1.1+np.sin(2*np.pi*y/e5))+np.sin(4*(x**2)*(y**2))+1)

# %% [markdown]
# **Plot $a(x,y)$**

# %%
[X, Y] = np.meshgrid(np.linspace(0, 1, 1000),np.linspace(0, 1, 1000))
aplot = a(X,Y)
plt.imshow(aplot)
plt.colorbar()

# %% [markdown]
# 这里可以选取更细的网格, 但是为了更快的调试代码, 现在先暂时在粗的网格上做.

# %%
inputsize = (2**finegridsize-1)**2
inputsize = int(inputsize)
sqrtinputsize = int(np.sqrt(inputsize))
outputsize = int((2**(np.log2(np.sqrt(inputsize)+1)-1)-1)**2)
sqrtoutputsize = int(np.sqrt(outputsize))
h = 1/(sqrtinputsize+1)
A0 = Poisson(inputsize)
A1 = NonlinearPoisson(inputsize)
[X, Y] = np.meshgrid(np.linspace(0, 1, sqrtinputsize),np.linspace(0, 1, sqrtinputsize))
RightF = rightf(X,Y)*h**2
RightF = RightF.reshape(inputsize, 1)
R = Restriction(inputsize)
P = Interpolation(inputsize)

# %% [markdown]
# **Plot A0, A1 **

# %%
plt.imshow(A0)
plt.colorbar()

# %%
plt.imshow(A1)
plt.colorbar()

# %% [markdown]
# ## GMM

# %% [markdown]
# **Calculate Result and Residual**

# %%
GMM_U, GMM_Res = Multigrid_circle(inputsize, A1, RightF, P, R, s, w, MAX_ITER)
# Out:
# Residual = 13.77013706928415
# Interation = 0
# ===================
# Residual = 1.9569646875461966
# Interation = 1
# ===================
# Residual = 0.46645587303120617
# Interation = 2
# ===================
# Residual = 0.1314569071419313
# Interation = 3
# ===================
# Residual = 0.042138119162204876
# Interation = 4
# ===================
# Residual = 0.014711881619513563
# Interation = 5
# ===================
# Residual = 0.005428498954912842
# Interation = 6
# ===================
# Residual = 0.0020781829464162358
# Interation = 7
# ===================
# Residual = 0.0008161025019011986
# Interation = 8
# ===================
# Residual = 0.00032637925871829626
# Interation = 9
# ===================
# Residual = 0.00013229324092154074
# Interation = 10
# ===================
# Residual = 5.416958350709348e-05
# Interation = 11
# ===================
# Residual = 2.235373530882572e-05
# Interation = 12
# ===================
# Residual = 9.280404159220714e-06
# Interation = 13
# ===================
# Residual = 3.8711518884166964e-06
# Interation = 14
# ===================
# Residual = 1.6208437719613448e-06
# Interation = 15
# ===================
# Residual = 6.806791820318801e-07
# Interation = 16
# ===================
# Residual = 2.865455882324371e-07
# Interation = 17
# ===================
# Residual = 1.2086571236397366e-07
# Interation = 18
# ===================
# Residual = 5.1065044413331394e-08
# Interation = 19
# ===================
# Residual = 2.160444189503952e-08
# Interation = 20
# ===================
# Residual = 9.151137682092792e-09
# Interation = 21
# ===================
# Residual = 3.880203702860526e-09
# Interation = 22
# ===================
# Residual = 1.6467632341128635e-09
# Interation = 23
# ===================
# Residual = 6.994669548299365e-10
# Interation = 24
# ===================
# Residual = 2.9732642060981644e-10
# Interation = 25
# ===================
# Residual = 1.264770379371645e-10
# Interation = 26
# ===================
# Residual = 5.383779411278194e-11
# Interation = 27
# ===================
# Residual = 2.292956958072032e-11
# Interation = 28
# ===================
# Residual = 9.773164578750443e-12
# Interation = 29
# ===================
# Residual = 4.168056628080989e-12
# Interation = 30
# ===================
# Residual = 1.7788041382930027e-12
# Interation = 31
# ===================
# Residual = 7.595500743450394e-13
# Interation = 32
# ===================
# Residual = 3.2417674780786296e-13
# Interation = 33
# ===================
# Residual = 1.4247967962200963e-13
# Interation = 34
# ===================
# Residual = 6.759425752405348e-14
# Interation = 35
# ===================
# Residual = 3.958923947074156e-14
# Interation = 36
# ===================
# Residual = 3.312104212790472e-14
# Interation = 37
# ===================
# Residual = 3.077458300914088e-14
# Interation = 38
# ===================
# Residual = 2.912987856972184e-14
# Interation = 39
# ===================
# Residual = 2.993538938026264e-14
# Interation = 40
# ===================
# Residual = 3.107306509956115e-14
# Interation = 41
# ===================
# Residual = 2.9940819409315735e-14
# Interation = 42
# ===================
# Residual = 2.91195524287607e-14
# Interation = 43
# ===================
# Residual = 3.0698184207906125e-14
# Interation = 44
# ===================
# Residual = 3.053440087371248e-14
# Interation = 45
# ===================
# Residual = 2.9138958589858064e-14
# Interation = 46
# ===================
# Residual = 3.01040196262951e-14
# Interation = 47
# ===================
# Residual = 3.351000793703396e-14
# Interation = 48
# ===================
# Residual = 3.1190071399918846e-14
# Interation = 49
# ===================

# %% [markdown]
# **Plot Result**

# %%
plt.imshow(GMM_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# **Plot Residual**

# %%
plt.semilogy(GMM_Res)

# %% [markdown]
# **Calculate Spectral Radius**

# %%
GMM_Radius = rho(inputsize,A1,P,R,w,s)
print('GMM_Radius = {}'.format(GMM_Radius))
# Out:
# GMM_Radius = 0.4560221701279284

# %% [markdown]
# ## AMG

# %% [markdown]
# **Define Solver and Solve**

# %%
amg_solver = pyamg.classical.classical.ruge_stuben_solver(A1,max_levels = 2)
pyamg.relaxation.smoothing.change_smoothers(amg_solver,presmoother=("jacobi", {"omega": w, "iterations": s}),postsmoother=("jacobi", {"omega": w, "iterations": s}))
AMG_Res = []
print(amg_solver)
AMG_U= amg_solver.solve(RightF, maxiter = MAX_ITER, tol=0, residuals=AMG_Res)
# Out:
# multilevel_solver
# Number of Levels:     2
# Operator Complexity:  1.872
# Grid Complexity:      1.501
# Coarse Solver:        'pinv2'
#   level   unknowns     nonzeros
#     0          961         4681 [53.42%]
#     1          481         4081 [46.58%]
# D:\anaconda\lib\site-packages\pyamg\classical\classical.py:101: SparseEfficiencyWarning: Implicit conversion of A to CSR
#   SparseEfficiencyWarning)

# %% [markdown]
# **Plot Result**

# %%
plt.imshow(AMG_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# **Plot Residual**

# %%
plt.semilogy(AMG_Res)

# %% [markdown]
# ## DMM

# %% [markdown]
# **Optimize R, P, $\omega$**

# %% [markdown]
# learning_rate是梯度下降时步长, step_length是每一个M之间的距离, 两者都必须非常小, 不然会出现不好的结果.

# %%
Pnew, Rnew, wnew, Rhoold, Rhonew = homotopy_optimizer_GD(inputsize, A0, A1, Interpolation(inputsize), Restriction(inputsize),  2/3, s, learning_rate = 1e-1,accept_radius = GMM_Radius,step_length = 1e-1)
# Out:
# ======Section 1======
# L = 0.2
# rho = 0.4258813505802446
# ===================
# Decrease the step_length, learning_rate and Restart!!
# step_length = 0.010000000000000002
# learning_rate = 0.010000000000000002
# rhonew = 0.7619250529316286
# ===================
# L = 0.020000000000000004
# rho = 0.449785500585961
# ===================
# L = 0.030000000000000006
# rho = 0.4476915095217379
# ===================
# L = 0.04000000000000001
# rho = 0.4431892672843721
# ===================
# L = 0.05000000000000001
# rho = 0.44444867392282716
# ===================
# L = 0.06000000000000001
# rho = 0.43120382413077574
# ===================
# L = 0.07
# rho = 0.4264820460561328
# ===================
# L = 0.08000000000000002
# rho = 0.42184062824710067
# ===================
# L = 0.09000000000000002
# rho = 0.4172644474244863
# ===================
# L = 0.10000000000000003
# rho = 0.41274592375057795
# ===================
# L = 0.11000000000000004
# rho = 0.4082802468721722
# ===================
# L = 0.12000000000000005
# rho = 0.40386521117809343
# ===================
# L = 0.13000000000000006
# rho = 0.39949887701801434
# ===================
# L = 0.14000000000000007
# rho = 0.39518105571047885
# ===================
# L = 0.15000000000000008
# rho = 0.3909108173742976
# ===================
# L = 0.1600000000000001
# rho = 0.386688862634647
# ===================
# L = 0.1700000000000001
# rho = 0.38251440335848824
# ===================
# L = 0.1800000000000001
# rho = 0.37838857030938283
# ===================
# L = 0.1900000000000001
# rho = 0.3743112966699324
# ===================
# L = 0.20000000000000012
# rho = 0.37031978781939606
# ===================
# L = 0.21000000000000013
# rho = 0.36733068474431396
# ===================
# L = 0.22000000000000014
# rho = 0.36762605902803436
# ===================
# L = 0.23000000000000015
# rho = 0.36802635957400315
# ===================
# L = 0.24000000000000016
# rho = 0.3724926710957422
# ===================
# L = 0.25000000000000017
# rho = 0.3796766992068509
# ===================
# L = 0.2600000000000002
# rho = 0.41056968857534937
# ===================
# L = 0.2700000000000002
# rho = 0.39951168377818114
# ===================
# Decrease the step_length, learning_rate and Restart!!
# step_length = 0.0010000000000000002
# learning_rate = 0.0010000000000000002
# rhonew = 1.1582428064327854
# ===================
# L = 0.0020000000000000005
# rho = 0.4536010269120638
# ===================
# L = 0.003000000000000001
# rho = 0.4531228686198206
# ===================
# L = 0.004000000000000001
# rho = 0.4526432759661317
# ===================
# L = 0.005000000000000001
# rho = 0.4521624991964217
# ===================
# L = 0.006000000000000001
# rho = 0.45168117439943173
# ===================
# L = 0.007000000000000001
# rho = 0.4511997641653542
# ===================
# L = 0.008000000000000002
# rho = 0.4507185561280253
# ===================
# L = 0.009000000000000003
# rho = 0.45023772358110475
# ===================
# L = 0.010000000000000004
# rho = 0.44975737088976003
# ===================
# L = 0.011000000000000005
# rho = 0.4492775611298695
# ===================
# L = 0.012000000000000005
# rho = 0.4487983322785421
# ===================
# L = 0.013000000000000006
# rho = 0.4483197067834702
# ===================
# L = 0.014000000000000007
# rho = 0.4478416973489171
# ===================
# L = 0.015000000000000008
# rho = 0.4473643105161953
# ===================
# L = 0.016000000000000007
# rho = 0.4468875489202515
# ===================
# L = 0.017000000000000008
# rho = 0.44641141272908796
# ===================
# L = 0.01800000000000001
# rho = 0.4459359005676205
# ===================
# L = 0.01900000000000001
# rho = 0.44546101011137235
# ===================
# L = 0.02000000000000001
# rho = 0.44498673846691444
# ===================
# L = 0.02100000000000001
# rho = 0.4445130824140988
# ===================
# L = 0.022000000000000013
# rho = 0.4440400385587819
# ===================
# L = 0.023000000000000013
# rho = 0.44356760342781854
# ===================
# L = 0.024000000000000014
# rho = 0.4430957735270932
# ===================
# L = 0.025000000000000015
# rho = 0.4426245453761322
# ===================
# L = 0.026000000000000016
# rho = 0.4421539155280944
# ===================
# L = 0.027000000000000017
# rho = 0.4416838805808044
# ===================
# L = 0.028000000000000018
# rho = 0.44121443718244674
# ===================
# L = 0.02900000000000002
# rho = 0.4407455820341941
# ===================
# L = 0.03000000000000002
# rho = 0.44027731189117125
# ===================
# L = 0.03100000000000002
# rho = 0.43980962356259884
# ===================
# L = 0.03200000000000002
# rho = 0.4393425139115997
# ===================
# L = 0.03300000000000002
# rho = 0.4388759798549343
# ===================
# L = 0.03400000000000002
# rho = 0.4384100183627909
# ===================
# L = 0.035000000000000024
# rho = 0.43794462645867677
# ===================
# L = 0.036000000000000025
# rho = 0.43747980121941515
# ===================
# L = 0.037000000000000026
# rho = 0.4370155397752264
# ===================
# L = 0.03800000000000003
# rho = 0.4365518393098625
# ===================
# L = 0.03900000000000003
# rho = 0.43608869706076503
# ===================
# L = 0.04000000000000003
# rho = 0.43562611031921483
# ===================
# L = 0.04100000000000003
# rho = 0.4351640764304504
# ===================
# L = 0.04200000000000003
# rho = 0.4347025927937332
# ===================
# L = 0.04300000000000003
# rho = 0.4342416568623465
# ===================
# L = 0.04400000000000003
# rho = 0.43378126614351653
# ===================
# L = 0.04500000000000003
# rho = 0.43332141819824943
# ===================
# L = 0.046000000000000034
# rho = 0.432862110641083
# ===================
# L = 0.047000000000000035
# rho = 0.4324033411397511
# ===================
# L = 0.048000000000000036
# rho = 0.43194510741476333
# ===================
# L = 0.04900000000000004
# rho = 0.43148740723890483
# ===================
# L = 0.05000000000000004
# rho = 0.4310302384366587
# ===================
# L = 0.05100000000000004
# rho = 0.4305735988835592
# ===================
# L = 0.05200000000000004
# rho = 0.43011748650547904
# ===================
# L = 0.05300000000000004
# rho = 0.42966189927786047
# ===================
# L = 0.05400000000000004
# rho = 0.42920683522489245
# ===================
# L = 0.05500000000000004
# rho = 0.42875229241864427
# ===================
# L = 0.05600000000000004
# rho = 0.42829826897815937
# ===================
# L = 0.057000000000000044
# rho = 0.427844763068515
# ===================
# L = 0.058000000000000045
# rho = 0.42739177289985575
# ===================
# L = 0.059000000000000045
# rho = 0.42693929672640313
# ===================
# L = 0.060000000000000046
# rho = 0.4264873328454489
# ===================
# L = 0.06100000000000005
# rho = 0.4260358795963338
# ===================
# L = 0.06200000000000005
# rho = 0.4255849353594192
# ===================
# L = 0.06300000000000004
# rho = 0.42513449855505264
# ===================
# L = 0.06400000000000004
# rho = 0.4246845676425314
# ===================
# L = 0.06500000000000004
# rho = 0.4242351411190684
# ===================
# L = 0.06600000000000004
# rho = 0.4237862175187621
# ===================
# L = 0.06700000000000005
# rho = 0.4233377954115729
# ===================
# L = 0.06800000000000005
# rho = 0.4228898734023088
# ===================
# L = 0.06900000000000005
# rho = 0.422442450129622
# ===================
# L = 0.07000000000000005
# rho = 0.4219955242650174
# ===================
# L = 0.07100000000000005
# rho = 0.421549094511877
# ===================
# L = 0.07200000000000005
# rho = 0.42110315960449746
# ===================
# L = 0.07300000000000005
# rho = 0.42065771830714604
# ===================
# L = 0.07400000000000005
# rho = 0.42021276941313274
# ===================
# L = 0.07500000000000005
# rho = 0.4197683117439014
# ===================
# L = 0.07600000000000005
# rho = 0.419324344148139
# ===================
# L = 0.07700000000000005
# rho = 0.4188808655009055
# ===================
# L = 0.07800000000000006
# rho = 0.41843787470278165
# ===================
# L = 0.07900000000000006
# rho = 0.41799537067903786
# ===================
# L = 0.08000000000000006
# rho = 0.4175533523788239
# ===================
# L = 0.08100000000000006
# rho = 0.4171118187743771
# ===================
# L = 0.08200000000000006
# rho = 0.41667076886025284
# ===================
# L = 0.08300000000000006
# rho = 0.416230201652574
# ===================
# L = 0.08400000000000006
# rho = 0.41579011618830153
# ===================
# L = 0.08500000000000006
# rho = 0.4153505115245242
# ===================
# L = 0.08600000000000006
# rho = 0.4149113867377691
# ===================
# L = 0.08700000000000006
# rho = 0.41447274092333214
# ===================
# L = 0.08800000000000006
# rho = 0.41403457319462633
# ===================
# L = 0.08900000000000007
# rho = 0.4135968826825512
# ===================
# L = 0.09000000000000007
# rho = 0.4131596685348795
# ===================
# L = 0.09100000000000007
# rho = 0.4127229299156641
# ===================
# L = 0.09200000000000007
# rho = 0.41228666600466124
# ===================
# L = 0.09300000000000007
# rho = 0.4118508759967728
# ===================
# L = 0.09400000000000007
# rho = 0.41141555910150585
# ===================
# L = 0.09500000000000007
# rho = 0.4109807145424491
# ===================
# L = 0.09600000000000007
# rho = 0.41054634155676595
# ===================
# L = 0.09700000000000007
# rho = 0.410112439394704
# ===================
# L = 0.09800000000000007
# rho = 0.40967900731912066
# ===================
# L = 0.09900000000000007
# rho = 0.40924604460502423
# ===================
# L = 0.10000000000000007
# rho = 0.4088135505391292
# ===================
# L = 0.10100000000000008
# rho = 0.40838152441942754
# ===================
# L = 0.10200000000000008
# rho = 0.40794996555477364
# ===================
# L = 0.10300000000000008
# rho = 0.40751887326448344
# ===================
# L = 0.10400000000000008
# rho = 0.4070882468779464
# ===================
# L = 0.10500000000000008
# rho = 0.40665808573425194
# ===================
# L = 0.10600000000000008
# rho = 0.40622838918182724
# ===================
# L = 0.10700000000000008
# rho = 0.4057991565780883
# ===================
# L = 0.10800000000000008
# rho = 0.40537038728910296
# ===================
# L = 0.10900000000000008
# rho = 0.4049420806892653
# ===================
# L = 0.11000000000000008
# rho = 0.4045142361609816
# ===================
# L = 0.11100000000000008
# rho = 0.4040868530943673
# ===================
# L = 0.11200000000000009
# rho = 0.40365993088695423
# ===================
# L = 0.11300000000000009
# rho = 0.4032334689434088
# ===================
# L = 0.11400000000000009
# rho = 0.4028074666752595
# ===================
# L = 0.11500000000000009
# rho = 0.4023819235006345
# ===================
# L = 0.11600000000000009
# rho = 0.40195683884400846
# ===================
# L = 0.11700000000000009
# rho = 0.40153221213595874
# ===================
# L = 0.11800000000000009
# rho = 0.4011080428129292
# ===================
# L = 0.11900000000000009
# rho = 0.40068433031700457
# ===================
# L = 0.12000000000000009
# rho = 0.4002610740956907
# ===================
# L = 0.1210000000000001
# rho = 0.39983827360170465
# ===================
# L = 0.1220000000000001
# rho = 0.39941592829277106
# ===================
# L = 0.1230000000000001
# rho = 0.39899403763142705
# ===================
# L = 0.1240000000000001
# rho = 0.39857260108483367
# ===================
# L = 0.12500000000000008
# rho = 0.39815161812459376
# ===================
# L = 0.12600000000000008
# rho = 0.39773108822657816
# ===================
# L = 0.12700000000000009
# rho = 0.39731101087075693
# ===================
# L = 0.12800000000000009
# rho = 0.39689138554103687
# ===================
# L = 0.1290000000000001
# rho = 0.39647221172510644
# ===================
# L = 0.1300000000000001
# rho = 0.3960534889142846
# ===================
# L = 0.1310000000000001
# rho = 0.39563521660337714
# ===================
# L = 0.1320000000000001
# rho = 0.39521739429053704
# ===================
# L = 0.1330000000000001
# rho = 0.39480002147713117
# ===================
# L = 0.1340000000000001
# rho = 0.3943830976676112
# ===================
# L = 0.1350000000000001
# rho = 0.39396662236939034
# ===================
# L = 0.1360000000000001
# rho = 0.3935505950927243
# ===================
# L = 0.1370000000000001
# rho = 0.3931350153505969
# ===================
# L = 0.1380000000000001
# rho = 0.3927198826586112
# ===================
# L = 0.1390000000000001
# rho = 0.3923051965348835
# ===================
# L = 0.1400000000000001
# rho = 0.3918909564999433
# ===================
# L = 0.1410000000000001
# rho = 0.3914771620766372
# ===================
# L = 0.1420000000000001
# rho = 0.3910638127900368
# ===================
# L = 0.1430000000000001
# rho = 0.39065090816735293
# ===================
# L = 0.1440000000000001
# rho = 0.39023844773785227
# ===================
# L = 0.1450000000000001
# rho = 0.38982643103278264
# ===================
# L = 0.1460000000000001
# rho = 0.3894148575853023
# ===================
# L = 0.1470000000000001
# rho = 0.3890037269304184
# ===================
# L = 0.1480000000000001
# rho = 0.3885930386049341
# ===================
# L = 0.1490000000000001
# rho = 0.3881827921474084
# ===================
# L = 0.1500000000000001
# rho = 0.38777298709813185
# ===================
# L = 0.1510000000000001
# rho = 0.38736362299912425
# ===================
# L = 0.1520000000000001
# rho = 0.3869546993941619
# ===================
# L = 0.1530000000000001
# rho = 0.3865462158288486
# ===================
# L = 0.1540000000000001
# rho = 0.38613817185074284
# ===================
# L = 0.1550000000000001
# rho = 0.3857305670095709
# ===================
# L = 0.1560000000000001
# rho = 0.38532340085755734
# ===================
# L = 0.1570000000000001
# rho = 0.3849166729499237
# ===================
# L = 0.1580000000000001
# rho = 0.38451038284562794
# ===================
# L = 0.1590000000000001
# rho = 0.38410453010844614
# ===================
# L = 0.16000000000000011
# rho = 0.38369911430854126
# ===================
# L = 0.16100000000000012
# rho = 0.38329413502472987
# ===================
# L = 0.16200000000000012
# rho = 0.38288959184773835
# ===================
# L = 0.16300000000000012
# rho = 0.3824854843848733
# ===================
# L = 0.16400000000000012
# rho = 0.3820818122667031
# ===================
# L = 0.16500000000000012
# rho = 0.3816785751566013
# ===================
# L = 0.16600000000000012
# rho = 0.3812757727643562
# ===================
# L = 0.16700000000000012
# rho = 0.38087340486556237
# ===================
# L = 0.16800000000000012
# rho = 0.38047147132921294
# ===================
# L = 0.16900000000000012
# rho = 0.3800699721569281
# ===================
# L = 0.17000000000000012
# rho = 0.3796689075386736
# ===================
# L = 0.17100000000000012
# rho = 0.3792682779318297
# ===================
# L = 0.17200000000000013
# rho = 0.37886808417330115
# ===================
# L = 0.17300000000000013
# rho = 0.37846832763833604
# ===================
# L = 0.17400000000000013
# rho = 0.378069010465325
# ===================
# L = 0.17500000000000013
# rho = 0.3776701358737154
# ===================
# L = 0.17600000000000013
# rho = 0.37727170861321413
# ===================
# L = 0.17700000000000013
# rho = 0.37687373559792336
# ===================
# L = 0.17800000000000013
# rho = 0.37647622680068954
# ===================
# L = 0.17900000000000013
# rho = 0.37607919651315647
# ===================
# L = 0.18000000000000013
# rho = 0.3756826651190826
# ===================
# L = 0.18100000000000013
# rho = 0.3752866615868621
# ===================
# L = 0.18200000000000013
# rho = 0.37489122696784927
# ===================
# L = 0.18300000000000013
# rho = 0.3744964192978443
# ===================
# L = 0.18400000000000014
# rho = 0.3741023204498778
# ===================
# L = 0.18500000000000014
# rho = 0.37370904568920205
# ===================
# L = 0.18600000000000014
# rho = 0.3733167569492193
# ===================
# L = 0.18700000000000014
# rho = 0.3729256811913029
# ===================
# L = 0.18800000000000014
# rho = 0.37253613563507587
# ===================
# L = 0.18900000000000014
# rho = 0.3721485621291373
# ===================
# L = 0.19000000000000014
# rho = 0.3717635734054791
# ===================
# L = 0.19100000000000014
# rho = 0.37138201425160594
# ===================
# L = 0.19200000000000014
# rho = 0.3710050403776893
# ===================
# L = 0.19300000000000014
# rho = 0.37063421625193643
# ===================
# L = 0.19400000000000014
# rho = 0.3702716292110408
# ===================
# L = 0.19500000000000015
# rho = 0.36992000891006893
# ===================
# L = 0.19600000000000015
# rho = 0.3695828266671924
# ===================
# L = 0.19700000000000015
# rho = 0.36926432791399444
# ===================
# L = 0.19800000000000015
# rho = 0.368969426569859
# ===================
# L = 0.19900000000000015
# rho = 0.3687033747708345
# ===================
# L = 0.20000000000000015
# rho = 0.36847114125284075
# ===================
# L = 0.20100000000000015
# rho = 0.36827652574931424
# ===================
# L = 0.20200000000000015
# rho = 0.36812120941670434
# ===================
# L = 0.20300000000000015
# rho = 0.3680040865133579
# ===================
# L = 0.20400000000000015
# rho = 0.36792125474784154
# ===================
# L = 0.20500000000000015
# rho = 0.3678667019699518
# ===================
# L = 0.20600000000000016
# rho = 0.3678337790959561
# ===================
# L = 0.20700000000000016
# rho = 0.3678157044707773
# ===================
# L = 0.20800000000000016
# rho = 0.36784878242710556
# ===================
# L = 0.20900000000000016
# rho = 0.3692905329736112
# ===================
# L = 0.21000000000000016
# rho = 0.37408105363434313
# ===================
# L = 0.21100000000000016
# rho = 0.36899629311711735
# ===================
# L = 0.21200000000000016
# rho = 0.3687189359382558
# ===================
# L = 0.21300000000000016
# rho = 0.3684976593180247
# ===================
# L = 0.21400000000000016
# rho = 0.3683347763236101
# ===================
# L = 0.21500000000000016
# rho = 0.36836562129777145
# ===================
# L = 0.21600000000000016
# rho = 0.36895448131510944
# ===================
# L = 0.21700000000000016
# rho = 0.37056899865510723
# ===================
# L = 0.21800000000000017
# rho = 0.3690373404720424
# ===================
# L = 0.21900000000000017
# rho = 0.36875994681098934
# ===================
# L = 0.22000000000000017
# rho = 0.36851651011871234
# ===================
# L = 0.22100000000000017
# rho = 0.36832250111011167
# ===================
# L = 0.22200000000000017
# rho = 0.36816107547676913
# ===================
# L = 0.22300000000000017
# rho = 0.368146515512829
# ===================
# L = 0.22400000000000017
# rho = 0.36895575750784637
# ===================
# L = 0.22500000000000017
# rho = 0.36933922090460064
# ===================
# L = 0.22600000000000017
# rho = 0.3705269713662009
# ===================
# L = 0.22700000000000017
# rho = 0.36949991336009425
# ===================
# L = 0.22800000000000017
# rho = 0.36919249470341925
# ===================
# L = 0.22900000000000018
# rho = 0.3689068030594417
# ===================
# L = 0.23000000000000018
# rho = 0.36868102317756724
# ===================
# L = 0.23100000000000018
# rho = 0.3684436011026348
# ===================
# L = 0.23200000000000018
# rho = 0.36828638065417185
# ===================
# L = 0.23300000000000018
# rho = 0.36812457246262065
# ===================
# L = 0.23400000000000018
# rho = 0.3683668839835389
# ===================
# L = 0.23500000000000018
# rho = 0.3700148126042996
# ===================
# L = 0.23600000000000018
# rho = 0.36855300624318466
# ===================
# L = 0.23700000000000018
# rho = 0.3684533890758566
# ===================
# L = 0.23800000000000018
# rho = 0.3683433907937901
# ===================
# L = 0.23900000000000018
# rho = 0.3686026780767395
# ===================
# L = 0.24000000000000019
# rho = 0.3696279143241168
# ===================
# L = 0.2410000000000002
# rho = 0.3687560239765641
# ===================
# L = 0.2420000000000002
# rho = 0.3684548514129628
# ===================
# L = 0.2430000000000002
# rho = 0.36835624328735245
# ===================
# L = 0.2440000000000002
# rho = 0.3681643726913356
# ===================
# L = 0.2450000000000002
# rho = 0.36858548328204566
# ===================
# L = 0.2460000000000002
# rho = 0.3699544633467373
# ===================
# L = 0.2470000000000002
# rho = 0.36908203484636953
# ===================
# L = 0.2480000000000002
# rho = 0.36873306785635757
# ===================
# L = 0.2490000000000002
# rho = 0.36847044851359045
# ===================
# L = 0.25000000000000017
# rho = 0.36840983219341
# ===================
# L = 0.25100000000000017
# rho = 0.3681721608271965
# ===================
# L = 0.25200000000000017
# rho = 0.3684747208058788
# ===================
# L = 0.25300000000000017
# rho = 0.369189458366643
# ===================
# L = 0.25400000000000017
# rho = 0.3684888846265201
# ===================
# L = 0.25500000000000017
# rho = 0.3682657837259376
# ===================
# L = 0.25600000000000017
# rho = 0.3682066482557353
# ===================
# L = 0.2570000000000002
# rho = 0.36801553196827014
# ===================
# L = 0.2580000000000002
# rho = 0.3687477464451664
# ===================
# L = 0.2590000000000002
# rho = 0.3702863237826501
# ===================
# L = 0.2600000000000002
# rho = 0.36961885763799956
# ===================
# L = 0.2610000000000002
# rho = 0.3694355851609334
# ===================
# L = 0.2620000000000002
# rho = 0.3693484659899652
# ===================
# L = 0.2630000000000002
# rho = 0.3692882449228529
# ===================
# L = 0.2640000000000002
# rho = 0.3692368753137408
# ===================
# L = 0.2650000000000002
# rho = 0.3691885398869746
# ===================
# L = 0.2660000000000002
# rho = 0.36914105508219025
# ===================
# L = 0.2670000000000002
# rho = 0.3690934185269064
# ===================
# L = 0.2680000000000002
# rho = 0.3690449808691688
# ===================
# L = 0.2690000000000002
# rho = 0.3689951220397509
# ===================
# L = 0.2700000000000002
# rho = 0.3689430950237775
# ===================
# L = 0.2710000000000002
# rho = 0.3688879199699058
# ===================
# L = 0.2720000000000002
# rho = 0.3688282849345188
# ===================
# L = 0.2730000000000002
# rho = 0.36876244757686455
# ===================
# L = 0.2740000000000002
# rho = 0.36868818850858287
# ===================
# L = 0.2750000000000002
# rho = 0.368603023399255
# ===================
# L = 0.2760000000000002
# rho = 0.36850532753784354
# ===================
# L = 0.2770000000000002
# rho = 0.36839797336668784
# ===================
# L = 0.2780000000000002
# rho = 0.36829535972881294
# ===================
# L = 0.2790000000000002
# rho = 0.3682164445794247
# ===================
# L = 0.2800000000000002
# rho = 0.3681329747467739
# ===================
# L = 0.2810000000000002
# rho = 0.3680530026759995
# ===================
# L = 0.2820000000000002
# rho = 0.36800292538763507
# ===================
# L = 0.2830000000000002
# rho = 0.3679378734670895
# ===================
# L = 0.2840000000000002
# rho = 0.3680229502936786
# ===================
# L = 0.2850000000000002
# rho = 0.3680447487805674
# ===================
# L = 0.2860000000000002
# rho = 0.3686750340687671
# ===================
# L = 0.2870000000000002
# rho = 0.36944130857436897
# ===================
# L = 0.2880000000000002
# rho = 0.3691842375147378
# ===================
# L = 0.2890000000000002
# rho = 0.3690621612891078
# ===================
# L = 0.2900000000000002
# rho = 0.3689870653607428
# ===================
# L = 0.2910000000000002
# rho = 0.36893122768395664
# ===================
# L = 0.2920000000000002
# rho = 0.3688841326552554
# ===================
# L = 0.2930000000000002
# rho = 0.3688412347096435
# ===================
# L = 0.2940000000000002
# rho = 0.36880036288960616
# ===================
# L = 0.2950000000000002
# rho = 0.3687603918743603
# ===================
# L = 0.2960000000000002
# rho = 0.3687206970975038
# ===================
# L = 0.2970000000000002
# rho = 0.36868091316674295
# ===================
# L = 0.2980000000000002
# rho = 0.36864081972098117
# ===================
# L = 0.2990000000000002
# rho = 0.3686002843192926
# ===================
# L = 0.3000000000000002
# rho = 0.3685592321809209
# ===================
# L = 0.3010000000000002
# rho = 0.3685176291408682
# ===================
# L = 0.3020000000000002
# rho = 0.36847547139769204
# ===================
# L = 0.3030000000000002
# rho = 0.36843277891624476
# ===================
# L = 0.3040000000000002
# rho = 0.36838959089688833
# ===================
# L = 0.3050000000000002
# rho = 0.3683459624721981
# ===================
# L = 0.3060000000000002
# rho = 0.3683019621630095
# ===================
# L = 0.3070000000000002
# rho = 0.36825766981337743
# ===================
# L = 0.3080000000000002
# rho = 0.36821317482210886
# ===================
# L = 0.3090000000000002
# rho = 0.3681685745428164
# ===================
# L = 0.3100000000000002
# rho = 0.3681239727579678
# ===================
# L = 0.3110000000000002
# rho = 0.3680794781570026
# ===================
# L = 0.3120000000000002
# rho = 0.36803520277042845
# ===================
# L = 0.3130000000000002
# rho = 0.3679912603339218
# ===================
# L = 0.3140000000000002
# rho = 0.3679477645798131
# ===================
# L = 0.3150000000000002
# rho = 0.3679048274774084
# ===================
# L = 0.3160000000000002
# rho = 0.3678625574665326
# ===================
# L = 0.3170000000000002
# rho = 0.36782105774772816
# ===================
# L = 0.3180000000000002
# rho = 0.3677804247045589
# ===================
# L = 0.31900000000000023
# rho = 0.3677407465357404
# ===================
# L = 0.32000000000000023
# rho = 0.3677021021658964
# ===================
# L = 0.32100000000000023
# rho = 0.3676645604842192
# ===================
# L = 0.32200000000000023
# rho = 0.3676281799330025
# ===================
# L = 0.32300000000000023
# rho = 0.36759300843756176
# ===================
# L = 0.32400000000000023
# rho = 0.36755908364084966
# ===================
# L = 0.32500000000000023
# rho = 0.3675264333848697
# ===================
# L = 0.32600000000000023
# rho = 0.3674950763697183
# ===================
# L = 0.32700000000000023
# rho = 0.36746502292021366
# ===================
# L = 0.32800000000000024
# rho = 0.36743627579782717
# ===================
# L = 0.32900000000000024
# rho = 0.3674088310088577
# ===================
# L = 0.33000000000000024
# rho = 0.36738267857494306
# ===================
# L = 0.33100000000000024
# rho = 0.3673578032462055
# ===================
# L = 0.33200000000000024
# rho = 0.36733418514877186
# ===================
# L = 0.33300000000000024
# rho = 0.36731180036643074
# ===================
# L = 0.33400000000000024
# rho = 0.36729062146102864
# ===================
# L = 0.33500000000000024
# rho = 0.36727061793855365
# ===================
# L = 0.33600000000000024
# rho = 0.3672517566685252
# ===================
# L = 0.33700000000000024
# rho = 0.36723400226403974
# ===================
# L = 0.33800000000000024
# rho = 0.3672173174290877
# ===================
# L = 0.33900000000000025
# rho = 0.3672016632788996
# ===================
# L = 0.34000000000000025
# rho = 0.36718699963818985
# ===================
# L = 0.34100000000000025
# rho = 0.36717328532133486
# ===================
# L = 0.34200000000000025
# rho = 0.36716047839769694
# ===================
# L = 0.34300000000000025
# rho = 0.3671485364445134
# ===================
# L = 0.34400000000000025
# rho = 0.36713741678897555
# ===================
# L = 0.34500000000000025
# rho = 0.36712707674035483
# ===================
# L = 0.34600000000000025
# rho = 0.36711747381231535
# ===================
# L = 0.34700000000000025
# rho = 0.36710856593491303
# ===================
# L = 0.34800000000000025
# rho = 0.3671003116552565
# ===================
# L = 0.34900000000000025
# rho = 0.3670926703254292
# ===================
# L = 0.35000000000000026
# rho = 0.3670856022760515
# ===================
# L = 0.35100000000000026
# rho = 0.3670790689738128
# ===================
# L = 0.35200000000000026
# rho = 0.36707303316140816
# ===================
# L = 0.35300000000000026
# rho = 0.36706745897856374
# ===================
# L = 0.35400000000000026
# rho = 0.3670623120631869
# ===================
# L = 0.35500000000000026
# rho = 0.3670575596321069
# ===================
# L = 0.35600000000000026
# rho = 0.36705317054133757
# ===================
# L = 0.35700000000000026
# rho = 0.3670491153262646
# ===================
# L = 0.35800000000000026
# rho = 0.36704536622259415
# ===================
# L = 0.35900000000000026
# rho = 0.36704189716929064
# ===================
# L = 0.36000000000000026
# rho = 0.3670386837950416
# ===================
# L = 0.36100000000000027
# rho = 0.3670357033900242
# ===================
# L = 0.36200000000000027
# rho = 0.36703293486489685
# ===================
# L = 0.36300000000000027
# rho = 0.3670303586990103
# ===================
# L = 0.36400000000000027
# rho = 0.36702795687982814
# ===================
# L = 0.36500000000000027
# rho = 0.3670257128354873
# ===================
# L = 0.36600000000000027
# rho = 0.3670236113623075
# ===================
# L = 0.36700000000000027
# rho = 0.3670216385489188
# ===================
# L = 0.36800000000000027
# rho = 0.3670197816984916
# ===================
# L = 0.36900000000000027
# rho = 0.3670180292503762
# ===================
# L = 0.3700000000000003
# rho = 0.3670163707022604
# ===================
# L = 0.3710000000000003
# rho = 0.36701479653377217
# ===================
# L = 0.3720000000000003
# rho = 0.3670132981322746
# ===================
# L = 0.3730000000000003
# rho = 0.36701186772143696
# ===================
# L = 0.3740000000000003
# rho = 0.36701049829302157
# ===================
# L = 0.3750000000000003
# rho = 0.3670091835421934
# ===================
# L = 0.3760000000000003
# rho = 0.3670079178065482
# ===================
# L = 0.3770000000000003
# rho = 0.36700669600896424
# ===================
# L = 0.3780000000000003
# rho = 0.3670055136042987
# ===================
# L = 0.3790000000000003
# rho = 0.3670043665298922
# ===================
# L = 0.3800000000000003
# rho = 0.3670032511597914
# ===================
# L = 0.3810000000000003
# rho = 0.3670021642625636
# ===================
# L = 0.3820000000000003
# rho = 0.3670011029625484
# ===================
# L = 0.3830000000000003
# rho = 0.3670000647043713
# ===================
# L = 0.3840000000000003
# rho = 0.3669990472205327
# ===================
# L = 0.3850000000000003
# rho = 0.36699804850187984
# ===================
# L = 0.3860000000000003
# rho = 0.3669970667707647
# ===================
# L = 0.3870000000000003
# rho = 0.36699610045669506
# ===================
# L = 0.3880000000000003
# rho = 0.3669951481742893
# ===================
# L = 0.3890000000000003
# rho = 0.36699420870335225
# ===================
# L = 0.3900000000000003
# rho = 0.36699328097089745
# ===================
# L = 0.3910000000000003
# rho = 0.3669923640349518
# ===================
# L = 0.3920000000000003
# rho = 0.3669914570699843
# ===================
# L = 0.3930000000000003
# rho = 0.3669905593538172
# ===================
# L = 0.3940000000000003
# rho = 0.36698967025588014
# ===================
# L = 0.3950000000000003
# rho = 0.36698878922668565
# ===================
# L = 0.3960000000000003
# rho = 0.3669879157884078
# ===================
# L = 0.3970000000000003
# rho = 0.3669870495264588
# ===================
# L = 0.3980000000000003
# rho = 0.3669861900819661
# ===================
# L = 0.3990000000000003
# rho = 0.36698533714506093
# ===================
# L = 0.4000000000000003
# rho = 0.3669844904488965
# ===================
# L = 0.4010000000000003
# rho = 0.36698364976432385
# ===================
# L = 0.4020000000000003
# rho = 0.36698281489515555
# ===================
# L = 0.4030000000000003
# rho = 0.36698198567395957
# ===================
# L = 0.4040000000000003
# rho = 0.36698116195832636
# ===================
# L = 0.4050000000000003
# rho = 0.36698034362756016
# ===================
# L = 0.4060000000000003
# rho = 0.3669795305797497
# ===================
# L = 0.4070000000000003
# rho = 0.36697872272917864
# ===================
# L = 0.4080000000000003
# rho = 0.36697792000403834
# ===================
# L = 0.4090000000000003
# rho = 0.3669771223444104
# ===================
# L = 0.4100000000000003
# rho = 0.36697632970049227
# ===================
# L = 0.4110000000000003
# rho = 0.3669755420310346
# ===================
# L = 0.4120000000000003
# rho = 0.3669747593019718
# ===================
# L = 0.4130000000000003
# rho = 0.36697398148522165
# ===================
# L = 0.4140000000000003
# rho = 0.36697320855763627
# ===================
# L = 0.4150000000000003
# rho = 0.3669724405000868
# ===================
# L = 0.4160000000000003
# rho = 0.36697167729666746
# ===================
# L = 0.4170000000000003
# rho = 0.36697091893400446
# ===================
# L = 0.4180000000000003
# rho = 0.3669701654006593
# ===================
# L = 0.4190000000000003
# rho = 0.36696941668661315
# ===================
# L = 0.4200000000000003
# rho = 0.3669686727828255
# ===================
# L = 0.4210000000000003
# rho = 0.36696793368085673
# ===================
# L = 0.4220000000000003
# rho = 0.36696719937254696
# ===================
# L = 0.4230000000000003
# rho = 0.3669664698497452
# ===================
# L = 0.4240000000000003
# rho = 0.366965745104083
# ===================
# L = 0.4250000000000003
# rho = 0.36696502512678514
# ===================
# L = 0.4260000000000003
# rho = 0.36696430990851575
# ===================
# L = 0.4270000000000003
# rho = 0.36696359943925205
# ===================
# L = 0.4280000000000003
# rho = 0.36696289370818586
# ===================
# L = 0.4290000000000003
# rho = 0.366962192703645
# ===================
# L = 0.4300000000000003
# rho = 0.3669614964130371
# ===================
# L = 0.4310000000000003
# rho = 0.36696080482280635
# ===================
# L = 0.43200000000000033
# rho = 0.3669601179184094
# ===================
# L = 0.43300000000000033
# rho = 0.3669594356842981
# ===================
# L = 0.43400000000000033
# rho = 0.36695875810391937
# ===================
# L = 0.43500000000000033
# rho = 0.36695808515971606
# ===================
# L = 0.43600000000000033
# rho = 0.36695741683314503
# ===================
# L = 0.43700000000000033
# rho = 0.3669567531046901
# ===================
# L = 0.43800000000000033
# rho = 0.3669560939538943
# ===================
# L = 0.43900000000000033
# rho = 0.3669554393593791
# ===================
# L = 0.44000000000000034
# rho = 0.3669547892988876
# ===================
# L = 0.44100000000000034
# rho = 0.3669541437493073
# ===================
# L = 0.44200000000000034
# rho = 0.36695350268672117
# ===================
# L = 0.44300000000000034
# rho = 0.36695286608643
# ===================
# L = 0.44400000000000034
# rho = 0.36695223392301135
# ===================
# L = 0.44500000000000034
# rho = 0.36695160617033723
# ===================
# L = 0.44600000000000034
# rho = 0.3669509828016424
# ===================
# L = 0.44700000000000034
# rho = 0.3669503637895324
# ===================
# L = 0.44800000000000034
# rho = 0.36694974910606243
# ===================
# L = 0.44900000000000034
# rho = 0.36694913872273294
# ===================
# L = 0.45000000000000034
# rho = 0.3669485326105819
# ===================
# L = 0.45100000000000035
# rho = 0.36694793074016074
# ===================
# L = 0.45200000000000035
# rho = 0.36694733308164706
# ===================
# L = 0.45300000000000035
# rho = 0.36694673960479257
# ===================
# L = 0.45400000000000035
# rho = 0.36694615027906446
# ===================
# L = 0.45500000000000035
# rho = 0.36694556507355475
# ===================
# L = 0.45600000000000035
# rho = 0.36694498395716285
# ===================
# L = 0.45700000000000035
# rho = 0.36694440689845015
# ===================
# L = 0.45800000000000035
# rho = 0.36694383386588264
# ===================
# L = 0.45900000000000035
# rho = 0.366943264827609
# ===================
# L = 0.46000000000000035
# rho = 0.36694269975178845
# ===================
# L = 0.46100000000000035
# rho = 0.3669421386062613
# ===================
# L = 0.46200000000000035
# rho = 0.3669415813590006
# ===================
# L = 0.46300000000000036
# rho = 0.36694102797762906
# ===================
# L = 0.46400000000000036
# rho = 0.3669404784300483
# ===================
# L = 0.46500000000000036
# rho = 0.3669399326837387
# ===================
# L = 0.46600000000000036
# rho = 0.36693939070664333
# ===================
# L = 0.46700000000000036
# rho = 0.3669388524661576
# ===================
# L = 0.46800000000000036
# rho = 0.366938317930379
# ===================
# L = 0.46900000000000036
# rho = 0.36693778706665575
# ===================
# L = 0.47000000000000036
# rho = 0.3669372598433578
# ===================
# L = 0.47100000000000036
# rho = 0.36693673622779815
# ===================
# L = 0.47200000000000036
# rho = 0.36693621618875016
# ===================
# L = 0.47300000000000036
# rho = 0.36693569969347145
# ===================
# L = 0.47400000000000037
# rho = 0.36693518671129133
# ===================
# L = 0.47500000000000037
# rho = 0.36693467720934947
# ===================
# L = 0.47600000000000037
# rho = 0.36693417115771826
# ===================
# L = 0.47700000000000037
# rho = 0.36693366852330084
# ===================
# L = 0.47800000000000037
# rho = 0.36693316927715347
# ===================
# L = 0.47900000000000037
# rho = 0.3669326733857456
# ===================
# L = 0.48000000000000037
# rho = 0.3669321808214385
# ===================
# L = 0.48100000000000037
# rho = 0.3669316915499622
# ===================
# L = 0.4820000000000004
# rho = 0.36693120554542336
# ===================
# L = 0.4830000000000004
# rho = 0.3669307227723512
# ===================
# L = 0.4840000000000004
# rho = 0.366930243207213
# ===================
# L = 0.4850000000000004
# rho = 0.36692976681265715
# ===================
# L = 0.4860000000000004
# rho = 0.3669292935683798
# ===================
# L = 0.4870000000000004
# rho = 0.3669288234341535
# ===================
# L = 0.4880000000000004
# rho = 0.3669283563941413
# ===================
# L = 0.4890000000000004
# rho = 0.36692789240379364
# ===================
# L = 0.4900000000000004
# rho = 0.3669274314535112
# ===================
# L = 0.4910000000000004
# rho = 0.3669269734923279
# ===================
# L = 0.4920000000000004
# rho = 0.36692651851942554
# ===================
# L = 0.4930000000000004
# rho = 0.3669260664743915
# ===================
# L = 0.4940000000000004
# rho = 0.3669256173688493
# ===================
# L = 0.4950000000000004
# rho = 0.36692517112856154
# ===================
# L = 0.4960000000000004
# rho = 0.3669247277828693
# ===================
# L = 0.4970000000000004
# rho = 0.36692428723738424
# ===================
# L = 0.4980000000000004
# rho = 0.36692384954677765
# ===================
# L = 0.4990000000000004
# rho = 0.36692341458737077
# ===================
# L = 0.5000000000000003
# rho = 0.3669229824501558
# ===================
# L = 0.5010000000000003
# rho = 0.36692255296895593
# ===================
# L = 0.5020000000000003
# rho = 0.366922126286965
# ===================
# L = 0.5030000000000003
# rho = 0.3669217021764165
# ===================
# L = 0.5040000000000003
# rho = 0.36692128085566134
# ===================
# L = 0.5050000000000003
# rho = 0.3669208620077364
# ===================
# L = 0.5060000000000003
# rho = 0.3669204459593493
# ===================
# L = 0.5070000000000003
# rho = 0.3669200322644057
# ===================
# L = 0.5080000000000003
# rho = 0.3669196214060051
# ===================
# L = 0.5090000000000003
# rho = 0.36691921275113204
# ===================
# L = 0.5100000000000003
# rho = 0.36691880700880763
# ===================
# L = 0.5110000000000003
# rho = 0.3669184032754372
# ===================
# L = 0.5120000000000003
# rho = 0.3669180025866447
# ===================
# L = 0.5130000000000003
# rho = 0.36691760364710535
# ===================
# L = 0.5140000000000003
# rho = 0.3669172079648944
# ===================
# L = 0.5150000000000003
# rho = 0.36691681367744944
# ===================
# L = 0.5160000000000003
# rho = 0.3669164229766554
# ===================
# L = 0.5170000000000003
# rho = 0.3669160331783778
# ===================
# L = 0.5180000000000003
# rho = 0.36691564746472416
# ===================
# L = 0.5190000000000003
# rho = 0.36691526196130747
# ===================
# L = 0.5200000000000004
# rho = 0.36691488128485295
# ===================
# L = 0.5210000000000004
# rho = 0.36691449983613994
# ===================
# L = 0.5220000000000004
# rho = 0.36691412431129145
# ===================
# L = 0.5230000000000004
# rho = 0.3669137466109381
# ===================
# L = 0.5240000000000004
# rho = 0.3669133764465415
# ===================
# L = 0.5250000000000004
# rho = 0.36691300209392863
# ===================
# L = 0.5260000000000004
# rho = 0.3669126376391538
# ===================
# L = 0.5270000000000004
# rho = 0.3669122661016828
# ===================
# L = 0.5280000000000004
# rho = 0.36691190791732514
# ===================
# L = 0.5290000000000004
# rho = 0.3669115384822972
# ===================
# L = 0.5300000000000004
# rho = 0.36691118745429213
# ===================
# L = 0.5310000000000004
# rho = 0.3669108191732914
# ===================
# L = 0.5320000000000004
# rho = 0.36691047669890464
# ===================
# L = 0.5330000000000004
# rho = 0.36691010833775595
# ===================
# L = 0.5340000000000004
# rho = 0.3669097766416955
# ===================
# L = 0.5350000000000004
# rho = 0.3669094066739713
# ===================
# L = 0.5360000000000004
# rho = 0.366909089365478
# ===================
# L = 0.5370000000000004
# rho = 0.3669087161055958
# ===================
# L = 0.5380000000000004
# rho = 0.3669084191976008
# ===================
# L = 0.5390000000000004
# rho = 0.36690804130078847
# ===================
# L = 0.5400000000000004
# rho = 0.3669077751398336
# ===================
# L = 0.5410000000000004
# rho = 0.36690739298655145
# ===================
# L = 0.5420000000000004
# rho = 0.36690717601486583
# ===================
# L = 0.5430000000000004
# rho = 0.36690679512690644
# ===================
# L = 0.5440000000000004
# rho = 0.3669066613731435
# ===================
# L = 0.5450000000000004
# rho = 0.3669063003381805
# ===================
# L = 0.5460000000000004
# rho = 0.3669063144916868
# ===================
# L = 0.5470000000000004
# rho = 0.3669060225430171
# ===================
# L = 0.5480000000000004
# rho = 0.36690631012314345
# ===================
# L = 0.5490000000000004
# rho = 0.3669062042835798
# ===================
# L = 0.5500000000000004
# rho = 0.3669070099259814
# ===================
# L = 0.5510000000000004
# rho = 0.3669073473741745
# ===================
# L = 0.5520000000000004
# rho = 0.3669091363262218
# ===================
# L = 0.5530000000000004
# rho = 0.36691043138863577
# ===================
# L = 0.5540000000000004
# rho = 0.3669140170087002
# ===================
# L = 0.5550000000000004
# rho = 0.36691713440766904
# ===================
# L = 0.5560000000000004
# rho = 0.36692364068902433
# ===================
# L = 0.5570000000000004
# rho = 0.3669294968542457
# ===================
# L = 0.5580000000000004
# rho = 0.36693951728789814
# ===================
# L = 0.5590000000000004
# rho = 0.36694760428073503
# ===================
# L = 0.5600000000000004
# rho = 0.36695901947096504
# ===================
# L = 0.5610000000000004
# rho = 0.36696542871836346
# ===================
# L = 0.5620000000000004
# rho = 0.3669728992015637
# ===================
# L = 0.5630000000000004
# rho = 0.3669729512335376
# ===================
# L = 0.5640000000000004
# rho = 0.36697367879012804
# ===================
# L = 0.5650000000000004
# rho = 0.3669681581579678
# ===================
# L = 0.5660000000000004
# rho = 0.3669652499214249
# ===================
# L = 0.5670000000000004
# rho = 0.36695855454741577
# ===================
# L = 0.5680000000000004
# rho = 0.36695586130201163
# ===================
# L = 0.5690000000000004
# rho = 0.36695065873691296
# ===================
# L = 0.5700000000000004
# rho = 0.3669496502956786
# ===================
# L = 0.5710000000000004
# rho = 0.3669463774739776
# ===================
# L = 0.5720000000000004
# rho = 0.3669470102171814
# ===================
# L = 0.5730000000000004
# rho = 0.3669452131856058
# ===================
# L = 0.5740000000000004
# rho = 0.36694698214891996
# ===================
# L = 0.5750000000000004
# rho = 0.3669460359545242
# ===================
# L = 0.5760000000000004
# rho = 0.3669483706331716
# ===================
# L = 0.5770000000000004
# rho = 0.36694769762913804
# ===================
# L = 0.5780000000000004
# rho = 0.366950091484296
# ===================
# L = 0.5790000000000004
# rho = 0.3669492550067288
# ===================
# L = 0.5800000000000004
# rho = 0.3669513599840747
# ===================
# L = 0.5810000000000004
# rho = 0.3669501381233804
# ===================
# L = 0.5820000000000004
# rho = 0.36695182721447245
# ===================
# L = 0.5830000000000004
# rho = 0.366950222516987
# ===================
# L = 0.5840000000000004
# rho = 0.36695156456084377
# ===================
# L = 0.5850000000000004
# rho = 0.3669497246942087
# ===================
# L = 0.5860000000000004
# rho = 0.3669508841630822
# ===================
# L = 0.5870000000000004
# rho = 0.3669489872915955
# ===================
# L = 0.5880000000000004
# rho = 0.36695012101423263
# ===================
# L = 0.5890000000000004
# rho = 0.36694829511190435
# ===================
# L = 0.5900000000000004
# rho = 0.36694949725770126
# ===================
# L = 0.5910000000000004
# rho = 0.36694779577538567
# ===================
# L = 0.5920000000000004
# rho = 0.3669490923552495
# ===================
# L = 0.5930000000000004
# rho = 0.366947508700938
# ===================
# L = 0.5940000000000004
# rho = 0.366948878761747
# ===================
# L = 0.5950000000000004
# rho = 0.36694737470562216
# ===================
# L = 0.5960000000000004
# rho = 0.3669487775927893
# ===================
# L = 0.5970000000000004
# rho = 0.3669473094585622
# ===================
# L = 0.5980000000000004
# rho = 0.36694870670985824
# ===================
# L = 0.5990000000000004
# rho = 0.3669472422339744
# ===================
# L = 0.6000000000000004
# rho = 0.36694860967262743
# ===================
# L = 0.6010000000000004
# rho = 0.3669471341705326
# ===================
# L = 0.6020000000000004
# rho = 0.36694846429128847
# ===================
# L = 0.6030000000000004
# rho = 0.366946978372017
# ===================
# L = 0.6040000000000004
# rho = 0.36694827603617547
# ===================
# L = 0.6050000000000004
# rho = 0.36694678897754845
# ===================
# L = 0.6060000000000004
# rho = 0.3669480645715553
# ===================
# L = 0.6070000000000004
# rho = 0.3669465874194792
# ===================
# L = 0.6080000000000004
# rho = 0.3669478509306748
# ===================
# L = 0.6090000000000004
# rho = 0.36694639187550054
# ===================
# L = 0.6100000000000004
# rho = 0.3669476496014794
# ===================
# L = 0.6110000000000004
# rho = 0.36694621230248586
# ===================
# L = 0.6120000000000004
# rho = 0.36694746623527413
# ===================
# L = 0.6130000000000004
# rho = 0.36694605042407047
# ===================
# L = 0.6140000000000004
# rho = 0.3669472993837264
# ===================
# L = 0.6150000000000004
# rho = 0.36694590256658094
# ===================
# L = 0.6160000000000004
# rho = 0.3669471439493501
# ===================
# L = 0.6170000000000004
# rho = 0.3669457631574385
# ===================
# L = 0.6180000000000004
# rho = 0.3669469944387065
# ===================
# L = 0.6190000000000004
# rho = 0.36694562740692754
# ===================
# L = 0.6200000000000004
# rho = 0.3669468469867883
# ===================
# L = 0.6210000000000004
# rho = 0.3669454925973657
# ===================
# L = 0.6220000000000004
# rho = 0.3669466999737393
# ===================
# L = 0.6230000000000004
# rho = 0.36694535812020035
# ===================
# L = 0.6240000000000004
# rho = 0.36694655361118317
# ===================
# L = 0.6250000000000004
# rho = 0.36694522477212727
# ===================
# L = 0.6260000000000004
# rho = 0.36694640907209486
# ===================
# L = 0.6270000000000004
# rho = 0.36694509386326307
# ===================
# L = 0.6280000000000004
# rho = 0.36694626765581895
# ===================
# L = 0.6290000000000004
# rho = 0.36694496652403863
# ===================
# L = 0.6300000000000004
# rho = 0.36694613026170797
# ===================
# L = 0.6310000000000004
# rho = 0.36694484336657107
# ===================
# L = 0.6320000000000005
# rho = 0.36694599722323984
# ===================
# L = 0.6330000000000005
# rho = 0.36694472446825666
# ===================
# L = 0.6340000000000005
# rho = 0.36694586840810534
# ===================
# L = 0.6350000000000005
# rho = 0.36694460954763375
# ===================
# L = 0.6360000000000005
# rho = 0.3669457434377657
# ===================
# L = 0.6370000000000005
# rho = 0.36694449819095215
# ===================
# L = 0.6380000000000005
# rho = 0.3669456219004746
# ===================
# L = 0.6390000000000005
# rho = 0.36694439002997414
# ===================
# L = 0.6400000000000005
# rho = 0.36694550348703164
# ===================
# L = 0.6410000000000005
# rho = 0.36694428483016434
# ===================
# L = 0.6420000000000005
# rho = 0.3669453880349035
# ===================
# L = 0.6430000000000005
# rho = 0.3669441824964753
# ===================
# L = 0.6440000000000005
# rho = 0.366945275503971
# ===================
# L = 0.6450000000000005
# rho = 0.366944083029313
# ===================
# L = 0.6460000000000005
# rho = 0.3669451659209562
# ===================
# L = 0.6470000000000005
# rho = 0.36694398646675186
# ===================
# L = 0.6480000000000005
# rho = 0.36694505932480903
# ===================
# L = 0.6490000000000005
# rho = 0.3669438928386594
# ===================
# L = 0.6500000000000005
# rho = 0.36694495573143365
# ===================
# L = 0.6510000000000005
# rho = 0.3669438021434942
# ===================
# L = 0.6520000000000005
# rho = 0.3669448551217412
# ===================
# L = 0.6530000000000005
# rho = 0.3669437143462066
# ===================
# L = 0.6540000000000005
# rho = 0.36694475744729743
# ===================
# L = 0.6550000000000005
# rho = 0.36694362938905767
# ===================
# L = 0.6560000000000005
# rho = 0.36694466264418657
# ===================
# L = 0.6570000000000005
# rho = 0.3669435472061647
# ===================
# L = 0.6580000000000005
# rho = 0.36694457064682684
# ===================
# L = 0.6590000000000005
# rho = 0.36694346773516645
# ===================
# L = 0.6600000000000005
# rho = 0.3669444813969715
# ===================
# L = 0.6610000000000005
# rho = 0.3669433909231756
# ===================
# L = 0.6620000000000005
# rho = 0.3669443948467956
# ===================
# L = 0.6630000000000005
# rho = 0.36694331672734676
# ===================
# L = 0.6640000000000005
# rho = 0.36694431095747004
# ===================
# L = 0.6650000000000005
# rho = 0.36694324511210874
# ===================
# ...
# rho = 0.3669441685824738
# ===================
# L = 0.8350000000000006
# rho = 0.36694387364074893
# ===================
# L = 0.8360000000000006
# rho = 0.3669442261893429
# ===================
# L = 0.8370000000000006
# rho = 0.3669439372762001
# ===================
# L = 0.8380000000000006
# rho = 0.36694428479260205
# ===================
# L = 0.8390000000000006
# rho = 0.3669440018395771
# ===================
# L = 0.8400000000000006
# rho = 0.36694434438272977
# ===================
# L = 0.8410000000000006
# rho = 0.3669440673214071
# ===================
# L = 0.8420000000000006
# rho = 0.3669444049503257
# ===================
# L = 0.8430000000000006
# rho = 0.36694413371233764
# ===================
# L = 0.8440000000000006
# rho = 0.3669444664861085
# ===================
# L = 0.8450000000000006
# rho = 0.36694420100313474
# ===================
# L = 0.8460000000000006
# rho = 0.36694452898091445
# ===================
# L = 0.8470000000000006
# rho = 0.3669442691846808
# ===================
# L = 0.8480000000000006
# rho = 0.3669445924256954
# ===================
# L = 0.8490000000000006
# rho = 0.3669443382479737
# ===================
# L = 0.8500000000000006
# rho = 0.36694465681151744
# ===================
# L = 0.8510000000000006
# rho = 0.36694440818412394
# ===================
# L = 0.8520000000000006
# rho = 0.366944722129559
# ===================
# L = 0.8530000000000006
# rho = 0.3669444789843542
# ===================
# L = 0.8540000000000006
# rho = 0.3669447883711089
# ===================
# L = 0.8550000000000006
# rho = 0.36694455063999715
# ===================
# L = 0.8560000000000006
# rho = 0.36694485552756584
# ===================
# L = 0.8570000000000007
# rho = 0.36694462314249365
# ===================
# L = 0.8580000000000007
# rho = 0.36694492359043557
# ===================
# L = 0.8590000000000007
# rho = 0.3669446964833917
# ===================
# L = 0.8600000000000007
# rho = 0.36694499255133006
# ===================
# L = 0.8610000000000007
# rho = 0.3669447706543444
# ===================
# L = 0.8620000000000007
# rho = 0.3669450624019659
# ===================
# L = 0.8630000000000007
# rho = 0.3669448456471089
# ===================
# L = 0.8640000000000007
# rho = 0.36694513313416266
# ===================
# L = 0.8650000000000007
# rho = 0.3669449214535447
# ===================
# L = 0.8660000000000007
# rho = 0.36694520473984127
# ===================
# L = 0.8670000000000007
# rho = 0.3669449980656121
# ===================
# L = 0.8680000000000007
# rho = 0.36694527721102305
# ===================
# L = 0.8690000000000007
# rho = 0.3669450754753708
# ===================
# L = 0.8700000000000007
# rho = 0.36694535053982774
# ===================
# L = 0.8710000000000007
# rho = 0.3669451536749788
# ===================
# L = 0.8720000000000007
# rho = 0.36694542471847263
# ===================
# L = 0.8730000000000007
# rho = 0.3669452326566904
# ===================
# L = 0.8740000000000007
# rho = 0.3669454997392708
# ===================
# L = 0.8750000000000007
# rho = 0.3669453124128554
# ===================
# L = 0.8760000000000007
# rho = 0.36694557559462987
# ===================
# L = 0.8770000000000007
# rho = 0.36694539293591755
# ===================
# L = 0.8780000000000007
# rho = 0.3669456522770507
# ===================
# L = 0.8790000000000007
# rho = 0.36694547421841317
# ===================
# L = 0.8800000000000007
# rho = 0.36694572977912615
# ===================
# L = 0.8810000000000007
# rho = 0.3669455562529698
# ===================
# L = 0.8820000000000007
# rho = 0.3669458080935395
# ===================
# L = 0.8830000000000007
# rho = 0.3669456390323052
# ===================
# L = 0.8840000000000007
# rho = 0.36694588721306354
# ===================
# L = 0.8850000000000007
# rho = 0.36694572254922564
# ===================
# L = 0.8860000000000007
# rho = 0.3669459671305591
# ===================
# L = 0.8870000000000007
# rho = 0.3669458067966251
# ===================
# L = 0.8880000000000007
# rho = 0.3669460478389738
# ===================
# L = 0.8890000000000007
# rho = 0.3669458917674836
# ===================
# L = 0.8900000000000007
# rho = 0.3669461293313408
# ===================
# L = 0.8910000000000007
# rho = 0.3669459774548667
# ===================
# L = 0.8920000000000007
# rho = 0.3669462116007781
# ===================
# L = 0.8930000000000007
# rho = 0.3669460638519233
# ===================
# L = 0.8940000000000007
# rho = 0.36694629464048656
# ===================
# L = 0.8950000000000007
# rho = 0.3669461509518853
# ===================
# L = 0.8960000000000007
# rho = 0.3669463784437495
# ===================
# L = 0.8970000000000007
# rho = 0.3669462387480665
# ===================
# L = 0.8980000000000007
# rho = 0.36694646300393086
# ===================
# L = 0.8990000000000007
# rho = 0.3669463272338604
# ===================
# L = 0.9000000000000007
# rho = 0.3669465483144745
# ===================
# L = 0.9010000000000007
# rho = 0.3669464164027403
# ===================
# L = 0.9020000000000007
# rho = 0.3669466343689032
# ===================
# L = 0.9030000000000007
# rho = 0.36694650624825775
# ===================
# L = 0.9040000000000007
# rho = 0.36694672116081734
# ===================
# L = 0.9050000000000007
# rho = 0.36694659676404134
# ===================
# L = 0.9060000000000007
# rho = 0.3669468086838936
# ===================
# L = 0.9070000000000007
# rho = 0.3669466879437956
# ===================
# L = 0.9080000000000007
# rho = 0.3669468969318846
# ===================
# L = 0.9090000000000007
# rho = 0.36694677978130025
# ===================
# L = 0.9100000000000007
# rho = 0.366946985898617
# ===================
# L = 0.9110000000000007
# rho = 0.36694687227040873
# ===================
# L = 0.9120000000000007
# rho = 0.366947075577991
# ===================
# L = 0.9130000000000007
# rho = 0.3669469654050477
# ===================
# L = 0.9140000000000007
# rho = 0.3669471659639794
# ===================
# L = 0.9150000000000007
# rho = 0.3669470591792157
# ===================
# L = 0.9160000000000007
# rho = 0.3669472570506263
# ===================
# L = 0.9170000000000007
# rho = 0.36694715358698227
# ===================
# L = 0.9180000000000007
# rho = 0.3669473488320461
# ===================
# L = 0.9190000000000007
# rho = 0.3669472486224867
# ===================
# L = 0.9200000000000007
# rho = 0.3669474413024229
# ===================
# L = 0.9210000000000007
# rho = 0.3669473442799376
# ===================
# L = 0.9220000000000007
# rho = 0.36694753445600925
# ===================
# L = 0.9230000000000007
# rho = 0.3669474405536113
# ===================
# L = 0.9240000000000007
# rho = 0.3669476282871251
# ===================
# L = 0.9250000000000007
# rho = 0.36694753743785147
# ===================
# L = 0.9260000000000007
# rho = 0.36694772279015714
# ===================
# L = 0.9270000000000007
# rho = 0.36694763492706806
# ===================
# L = 0.9280000000000007
# rho = 0.3669478179595577
# ===================
# L = 0.9290000000000007
# rho = 0.36694773301573597
# ===================
# L = 0.9300000000000007
# rho = 0.3669479137898441
# ===================
# L = 0.9310000000000007
# rho = 0.3669478316983949
# ===================
# L = 0.9320000000000007
# rho = 0.3669480102755976
# ===================
# L = 0.9330000000000007
# rho = 0.36694793096964784
# ===================
# L = 0.9340000000000007
# rho = 0.36694810741146217
# ===================
# L = 0.9350000000000007
# rho = 0.3669480308241604
# ===================
# L = 0.9360000000000007
# rho = 0.36694820519214427
# ===================
# L = 0.9370000000000007
# rho = 0.36694813125666
# ===================
# L = 0.9380000000000007
# rho = 0.36694830361241154
# ===================
# L = 0.9390000000000007
# rho = 0.3669482322619349
# ===================
# L = 0.9400000000000007
# rho = 0.36694840266709206
# ===================
# L = 0.9410000000000007
# rho = 0.36694833383483355
# ===================
# L = 0.9420000000000007
# rho = 0.36694850235107357
# ===================
# L = 0.9430000000000007
# rho = 0.36694843597026366
# ===================
# L = 0.9440000000000007
# rho = 0.3669486026593029
# ===================
# L = 0.9450000000000007
# rho = 0.3669485386631913
# ===================
# L = 0.9460000000000007
# rho = 0.3669487035867845
# ===================
# L = 0.9470000000000007
# rho = 0.3669486419086404
# ===================
# L = 0.9480000000000007
# rho = 0.3669488051285803
# ===================
# L = 0.9490000000000007
# rho = 0.36694874570169145
# ===================
# L = 0.9500000000000007
# rho = 0.3669489072798088
# ===================
# L = 0.9510000000000007
# rho = 0.36694885003748123
# ===================
# L = 0.9520000000000007
# rho = 0.3669490100356436
# ===================
# L = 0.9530000000000007
# rho = 0.3669489549112016
# ===================
# L = 0.9540000000000007
# rho = 0.36694911339131364
# ===================
# L = 0.9550000000000007
# rho = 0.3669490603180992
# ===================
# L = 0.9560000000000007
# rho = 0.3669492173421022
# ===================
# L = 0.9570000000000007
# rho = 0.3669491662534744
# ===================
# L = 0.9580000000000007
# rho = 0.3669493218833453
# ===================
# L = 0.9590000000000007
# rho = 0.36694927271268046
# ===================
# L = 0.9600000000000007
# rho = 0.3669494270104322
# ===================
# L = 0.9610000000000007
# rho = 0.3669493796911233
# ===================
# L = 0.9620000000000007
# rho = 0.36694953271880376
# ===================
# L = 0.9630000000000007
# rho = 0.36694948718425996
# ===================
# L = 0.9640000000000007
# rho = 0.36694963900395244
# ===================
# L = 0.9650000000000007
# rho = 0.3669495951875989
# ===================
# L = 0.9660000000000007
# rho = 0.3669497458614206
# ===================
# L = 0.9670000000000007
# rho = 0.36694970369669816
# ===================
# L = 0.9680000000000007
# rho = 0.36694985328680096
# ===================
# L = 0.9690000000000007
# rho = 0.36694981270716603
# ===================
# L = 0.9700000000000008
# rho = 0.36694996127573515
# ===================
# L = 0.9710000000000008
# rho = 0.36694992221465894
# ===================
# L = 0.9720000000000008
# rho = 0.36695006982391326
# ===================
# L = 0.9730000000000008
# rho = 0.36695003221488187
# ===================
# L = 0.9740000000000008
# rho = 0.36695017892707316
# ===================
# L = 0.9750000000000008
# rho = 0.36695014270358706
# ===================
# L = 0.9760000000000008
# rho = 0.3669502885809999
# ===================
# L = 0.9770000000000008
# rho = 0.3669502536765736
# ===================
# L = 0.9780000000000008
# rho = 0.366950398781525
# ===================
# L = 0.9790000000000008
# rho = 0.36695036512968693
# ===================
# L = 0.9800000000000008
# rho = 0.3669505095245257
# ===================
# L = 0.9810000000000008
# rho = 0.36695047705881784
# ===================
# L = 0.9820000000000008
# rho = 0.36695062080592444
# ===================
# L = 0.9830000000000008
# rho = 0.3669505894599021
# ===================
# L = 0.9840000000000008
# rho = 0.3669507326216885
# ===================
# L = 0.9850000000000008
# rho = 0.36695070232891974
# ===================
# L = 0.9860000000000008
# rho = 0.36695084496782854
# ===================
# L = 0.9870000000000008
# rho = 0.3669508156618944
# ===================
# L = 0.9880000000000008
# rho = 0.36695095784039905
# ===================
# L = 0.9890000000000008
# rho = 0.3669509294548929
# ===================
# L = 0.9900000000000008
# rho = 0.36695107123549714
# ===================
# L = 0.9910000000000008
# rho = 0.3669510437040244
# ===================
# L = 0.9920000000000008
# rho = 0.3669511851492619
# ===================
# L = 0.9930000000000008
# rho = 0.3669511584054401
# ===================
# L = 0.9940000000000008
# rho = 0.36695129957787415
# ===================
# L = 0.9950000000000008
# rho = 0.36695127355533225
# ===================
# L = 0.9960000000000008
# rho = 0.36695141451755536
# ===================
# L = 0.9970000000000008
# rho = 0.366951389149934
# ===================
# L = 0.9980000000000008
# rho = 0.366951529964568
# ===================
# L = 0.9990000000000008
# rho = 0.36695150518551856
# ===================
# L = 1.0000000000000007
# rho = 0.3669516459152136
# ===================
# ======Section 2======
# rho = 0.3669516216583986
# ===================
# rho = 0.36695100700118594
# ===================
# rho = 0.36695022782307185
# ===================
# rho = 0.3669496138131713
# ===================
# rho = 0.36694883527440325
# ===================
# rho = 0.36694822190975507
# ===================
# rho = 0.3669474440081238
# ===================
# rho = 0.36694683128667566
# ===================
# rho = 0.3669460540199804
# ===================
# rho = 0.3669454419396874
# ===================
# rho = 0.3669446653057363
# ===================
# rho = 0.3669440538645609
# ===================
# rho = 0.36694327786117037
# ===================
# rho = 0.3669426670570825
# ===================
# rho = 0.36694189168207736
# ===================
# rho = 0.3669412815130541
# ===================
# rho = 0.36694050676426765
# ===================
# rho = 0.36693989722829334
# ===================
# rho = 0.36693912310356724
# ===================
# rho = 0.36693851419863316
# ===================
# rho = 0.366937740695817
# ===================
# rho = 0.3669371324199217
# ===================
# rho = 0.36693635953687376
# ===================
# rho = 0.36693575188802235
# ===================
# rho = 0.36693497962260857
# ===================
# rho = 0.36693437259881356
# ===================
# rho = 0.366933600948908
# ===================
# rho = 0.36693299454818834
# ===================
# rho = 0.3669322235116731
# ===================
# rho = 0.36693161773205474
# ===================
# rho = 0.36693084730681996
# ===================
# rho = 0.3669302421463354
# ===================
# rho = 0.36692947233027884
# ===================
# rho = 0.36692886778696715
# ===================
# rho = 0.3669280985779946
# ===================
# rho = 0.36692749464990154
# ===================
# rho = 0.3669267260459262
# ===================
# rho = 0.366926122731104
# ===================
# rho = 0.36692535473004684
# ===================
# rho = 0.3669247520265541
# ===================
# rho = 0.36692398462634385
# ===================
# rho = 0.3669233825322456
# ===================
# rho = 0.36692261573081836
# ===================
# rho = 0.36692201424418586
# ===================
# rho = 0.3669212480394851
# ===================
# rho = 0.3669206471583961
# ===================
# rho = 0.36691988154837296
# ===================
# rho = 0.366919281270911
# ===================
# rho = 0.36691851625352384
# ===================
# rho = 0.3669179165777787
# ===================
# rho = 0.3669171521509933
# ===================
# rho = 0.36691655307506105
# ===================
# rho = 0.36691578923685014
# ===================
# rho = 0.3669151907588326
# ===================
# rho = 0.3669144275071763
# ===================
# rho = 0.36691382962518126
# ===================
# rho = 0.36691306695806686
# ===================
# rho = 0.36691246967020813
# ===================
# rho = 0.36691170758562996
# ===================
# rho = 0.3669111108900269
# ===================
# rho = 0.36691034938598627
# ===================
# rho = 0.36690975328076436
# ===================
# rho = 0.3669089923552694
# ===================
# rho = 0.3669083968385596
# ===================
# rho = 0.36690763648962577
# ===================
# rho = 0.3669070415595646
# ===================
# rho = 0.3669062817852137
# ===================
# rho = 0.3669056874399437
# ===================
# rho = 0.36690492823820453
# ===================
# rho = 0.36690433447587323
# ===================
# rho = 0.36690357584478145
# ===================
# rho = 0.3669029826635422
# ===================
# rho = 0.3669022246011402
# ===================
# rho = 0.36690163199915166
# ===================
# rho = 0.36690087450348813
# ===================
# rho = 0.3669002824789145
# ===================
# rho = 0.36689952554804506
# ===================
# rho = 0.36689893409905555
# ===================
# rho = 0.36689817773104233
# ===================
# rho = 0.3668975868558117
# ===================
# rho = 0.36689683104872306
# ===================
# rho = 0.36689624074543126
# ===================
# rho = 0.36689548549734236
# ===================
# rho = 0.36689489576417433
# ===================
# rho = 0.3668941410731664
# ===================
# rho = 0.3668935519083124
# ===================
# rho = 0.36689279777247336
# ===================
# rho = 0.3668922091741285
# ===================
# rho = 0.3668914555915522
# ===================
# rho = 0.36689086755791683
# ===================
# rho = 0.3668901145267035
# ===================
# rho = 0.36688952705598277
# ===================
# rho = 0.36688877457423885
# ===================
# rho = 0.36688818766464304
# ===================
# rho = 0.3668874357304812
# ===================
# rho = 0.36688684938022514
# ===================
# rho = 0.3668860979917641
# ===================
# rho = 0.3668855121990677
# ===================
# rho = 0.36688476135443227
# ===================
# rho = 0.36688417611751994
# ===================
# ======End======

# %% [markdown]
# **Calculate Result and Residual**

# %%
DMM_U, DMM_Res = Multigrid_circle(inputsize, A1, RightF, Pnew, Rnew, s, wnew, MAX_ITER)
# Out:
# Residual = 13.492004982874134
# Interation = 0
# ===================
# Residual = 1.7613618778600901
# Interation = 1
# ===================
# Residual = 0.5151214771821241
# Interation = 2
# ===================
# Residual = 0.14939393208807264
# Interation = 3
# ===================
# Residual = 0.04222038567892746
# Interation = 4
# ===================
# Residual = 0.011797878179568295
# Interation = 5
# ===================
# Residual = 0.0032836439417642115
# Interation = 6
# ===================
# Residual = 0.0009137066489455473
# Interation = 7
# ===================
# Residual = 0.00025497014373098407
# Interation = 8
# ===================
# Residual = 7.162355802650271e-05
# Interation = 9
# ===================
# Residual = 2.0358743402372078e-05
# Interation = 10
# ===================
# Residual = 5.8933964827517815e-06
# Interation = 11
# ===================
# Residual = 1.748838692776045e-06
# Interation = 12
# ===================
# Residual = 5.344540720406008e-07
# Interation = 13
# ===================
# Residual = 1.6833035615588233e-07
# Interation = 14
# ===================
# Residual = 5.444902534512072e-08
# Interation = 15
# ===================
# Residual = 1.7977984797735857e-08
# Interation = 16
# ===================
# Residual = 6.019801695152168e-09
# Interation = 17
# ===================
# Residual = 2.033018234002302e-09
# Interation = 18
# ===================
# Residual = 6.897840630364969e-10
# Interation = 19
# ===================
# Residual = 2.345261071196234e-10
# Interation = 20
# ===================
# Residual = 7.97891339143936e-11
# Interation = 21
# ===================
# Residual = 2.7134879472399232e-11
# Interation = 22
# ===================
# Residual = 9.223089569011756e-12
# Interation = 23
# ===================
# Residual = 3.1291493237414688e-12
# Interation = 24
# ===================
# Residual = 1.0629197101405565e-12
# Interation = 25
# ===================
# Residual = 3.6344646499936e-13
# Interation = 26
# ===================
# Residual = 1.2888574040508992e-13
# Interation = 27
# ===================
# Residual = 5.456154533297129e-14
# Interation = 28
# ===================
# Residual = 3.429435578020086e-14
# Interation = 29
# ===================
# Residual = 3.1825555120462683e-14
# Interation = 30
# ===================
# Residual = 2.674266926739114e-14
# Interation = 31
# ===================
# Residual = 2.668305565676948e-14
# Interation = 32
# ===================
# Residual = 2.86796343696121e-14
# Interation = 33
# ===================
# Residual = 3.0155162565132974e-14
# Interation = 34
# ===================
# Residual = 3.0098481055582415e-14
# Interation = 35
# ===================
# Residual = 2.931320051472479e-14
# Interation = 36
# ===================
# Residual = 2.8364005994427357e-14
# Interation = 37
# ===================
# Residual = 2.8141092741984906e-14
# Interation = 38
# ===================
# Residual = 2.6557453226041372e-14
# Interation = 39
# ===================
# Residual = 2.9038659851564054e-14
# Interation = 40
# ===================
# Residual = 2.7201424204425657e-14
# Interation = 41
# ===================
# Residual = 2.87242087985553e-14
# Interation = 42
# ===================
# Residual = 2.8349049486644507e-14
# Interation = 43
# ===================
# Residual = 2.923571080461043e-14
# Interation = 44
# ===================
# Residual = 2.737195698365954e-14
# Interation = 45
# ===================
# Residual = 2.7877463867902508e-14
# Interation = 46
# ===================
# Residual = 2.9304951061212745e-14
# Interation = 47
# ===================
# Residual = 2.8306386709609053e-14
# Interation = 48
# ===================
# Residual = 2.9058364479958414e-14
# Interation = 49
# ===================

# %% [markdown]
# **Plot Result**

# %%
plt.imshow(DMM_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# **Plot Residual**

# %%
plt.semilogy(DMM_Res)

# %% [markdown]
# **Calculate Spectral Radius**

# %%
DMM_Radius = Rhonew
print('DMM_Radius = {}'.format(DMM_Radius))
# Out:
# DMM_Radius = 0.36688417611751994

# %% [markdown]
# ## Compare

# %%
print('GMM_Radius = {}'.format(GMM_Radius))
print('DMM_Radius = {}'.format(DMM_Radius))
print("GMM_Radius : DMM_Radius = 1 : %f" %(DMM_Radius/GMM_Radius))
# Out:
# GMM_Radius = 0.4560221701279284
# DMM_Radius = 0.36688417611751994
# GMM_Radius : DMM_Radius = 1 : 0.804531

# %%
plt.semilogy(GMM_Res, label = 'GMM_Res')
plt.semilogy(AMG_Res, label = 'AMG_Res')
plt.semilogy(DMM_Res, label = 'DMM_Res')
plt.legend(loc='upper right')

# %% [markdown]
# ## R, P and  $\omega$ after Optimization

# %%
print('omega after optimization = {}'.format(wnew))
# Out:
# omega after optimization = 0.8014328077359686

# %%
print('P after optimization ')
plt.imshow(np.log10(np.abs(Pnew)))
plt.colorbar()
# Out:
# P after optimization

# %%
print('R after optimization ')
plt.imshow(np.log10(np.abs(Rnew)))
plt.colorbar()
# Out:
# R after optimization

# %%
print("P under log10(abs())")
plt.plot(np.log10(np.abs(Pnew))[round(0.5*inputsize)][:])
# Out:
# P under log10(abs())

# %%
print("R under log10(abs())")
plt.plot(np.log10(np.abs(Rnew))[:][round(0.5*outputsize)])
# Out:
# R under log10(abs())

# %% [markdown]
# # Experiment 2 (with small e1, e2, e3, e4, e5)

# %% [markdown]
# 选取比较小的参数, a函数频率较大

# %%
e1 = 1/2
e2 = 1/2
e3 = 1/2
e4 = 1/2
e5 = 1/2
def u_real(x, y): return np.sin(np.pi*3*x)*np.sin(np.pi*5*y)
def rightf(x, y): return 34*np.pi**2*np.sin(3*np.pi*x)*np.sin(5*np.pi*y)*(np.sin(4*x**2*y**2)/6 + (np.sin((2*np.pi*y)/e2) + 11/10)/(6*(np.cos((2*np.pi*x)/e2) + 11/10)) + (np.cos((2*np.pi*x)/e3) + 11/10)/(6*(np.sin((2*np.pi*y)/e3) + 11/10)) + (np.sin((2*np.pi*y)/e4) + 11/10)/(6*(np.cos((2*np.pi*x)/e4) + 11/10)) + (np.cos((2*np.pi*x)/e5) + 11/10)/(6*(np.sin((2*np.pi*y)/e5) + 11/10)) + (np.sin((2*np.pi*x)/e1) + 11/10)/(6*(np.sin((2*np.pi*y)/e1) + 11/10)) + 1/6) - 3*np.pi*np.cos(3*np.pi*x)*np.sin(5*np.pi*y)*((4*x*y**2*np.cos(4*x**2*y**2))/3 + (np.pi*np.cos((2*np.pi*x)/e1))/(3*e1*(np.sin((2*np.pi*y)/e1) + 11/10)) - (np.pi*np.sin((2*np.pi*x)/e3))/(3*e3*(np.sin((2*np.pi*y)/e3) + 11/10)) - (np.pi*np.sin((2*np.pi*x)/e5))/(3*e5*(np.sin((2*np.pi*y)/e5) + 11/10)) + (np.pi*np.sin((2*np.pi*x)/e2)*(np.sin((2*np.pi*y)/e2) + 11/10))/(3*e2*(np.cos((2*x*np.pi)/e2) + 11/10)**2) + (np.pi*np.sin((2*np.pi*x)/e4)*(np.sin((2*np.pi*y)/e4) + 11/10))/(3*e4*(np.cos((2*x*np.pi)/e4) + 11/10)**2)) - 5*np.pi*np.cos(5*np.pi*y)*np.sin(3*np.pi*x)*((4*x**2*y*np.cos(4*x**2*y**2))/3 + (np.pi*np.cos((2*np.pi*y)/e2))/(3*e2*(np.cos((2*np.pi*x)/e2) + 11/10)) + (np.pi*np.cos((2*np.pi*y)/e4))/(3*e4*(np.cos((2*np.pi*x)/e4) + 11/10)) - (np.pi*np.cos((2*np.pi*y)/e3)*(np.cos((2*np.pi*x)/e3) + 11/10))/(3*e3*(np.sin((2*y*np.pi)/e3) + 11/10)**2) - (np.pi*np.cos((2*np.pi*y)/e5)*(np.cos((2*np.pi*x)/e5) + 11/10))/(3*e5*(np.sin((2*y*np.pi)/e5) + 11/10)**2) - (np.pi*np.cos((2*np.pi*y)/e1)*(np.sin((2*np.pi*x)/e1) + 11/10))/(3*e1*(np.sin((2*y*np.pi)/e1) + 11/10)**2))
def a(x, y): return (1/6)*((1.1+np.sin(2*np.pi*x/e1))/(1.1+np.sin(2*np.pi*y/e1))+(1.1+np.sin(2*np.pi*y/e2))/(1.1+np.cos(2*np.pi*x/e2))+(1.1+np.cos(2*np.pi*x/e3))/(1.1+np.sin(2*np.pi*y/e3))+(1.1+np.sin(2*np.pi*y/e4))/(1.1+np.cos(2*np.pi*x/e4))+(1.1+np.cos(2*np.pi*x/e5))/(1.1+np.sin(2*np.pi*y/e5))+np.sin(4*(x**2)*(y**2))+1)

# %% [markdown]
# **Plot $a(x,y)$**

# %%
[X, Y] = np.meshgrid(np.linspace(0, 1, 1000),np.linspace(0, 1, 1000))
aplot = a(X,Y)
plt.imshow(aplot)
plt.colorbar()

# %%
inputsize = (2**finegridsize-1)**2
inputsize = int(inputsize)
sqrtinputsize = int(np.sqrt(inputsize))
outputsize = int((2**(np.log2(np.sqrt(inputsize)+1)-1)-1)**2)
sqrtoutputsize = int(np.sqrt(outputsize))
h = 1/(sqrtinputsize+1)
A0 = Poisson(inputsize)
A1 = NonlinearPoisson(inputsize)
[X, Y] = np.meshgrid(np.linspace(0, 1, sqrtinputsize),np.linspace(0, 1, sqrtinputsize))
RightF = rightf(X,Y)*h**2
RightF = RightF.reshape(inputsize, 1)
R = Restriction(inputsize)
P = Interpolation(inputsize)

# %% [markdown]
# **Plot A0, A1 **

# %%
plt.imshow(A0)
plt.colorbar()

# %%
plt.imshow(A1)
plt.colorbar()

# %% [markdown]
# ## GMM

# %% [markdown]
# **Calculate Result and Residual**

# %%
GMM_U, GMM_Res = Multigrid_circle(inputsize, A1, RightF, P, R, s, w, MAX_ITER)
# Out:
# Residual = 13.859237184443975
# Interation = 0
# ===================
# Residual = 1.9016460756645286
# Interation = 1
# ===================
# Residual = 0.4550175128652131
# Interation = 2
# ===================
# Residual = 0.13682606562468827
# Interation = 3
# ===================
# Residual = 0.047662810980302846
# Interation = 4
# ===================
# Residual = 0.017888415349008254
# Interation = 5
# ===================
# Residual = 0.006959734305663399
# Interation = 6
# ===================
# Residual = 0.002758674185286888
# Interation = 7
# ===================
# Residual = 0.00110542547706656
# Interation = 8
# ===================
# Residual = 0.0004461815651879037
# Interation = 9
# ===================
# Residual = 0.0001810824126934838
# Interation = 10
# ===================
# Residual = 7.382857859729305e-05
# Interation = 11
# ===================
# Residual = 3.0223060285783613e-05
# Interation = 12
# ===================
# Residual = 1.2419116740154836e-05
# Interation = 13
# ===================
# Residual = 5.121522135553041e-06
# Interation = 14
# ===================
# Residual = 2.1193484379005396e-06
# Interation = 15
# ===================
# Residual = 8.799292688861956e-07
# Interation = 16
# ===================
# Residual = 3.6650817836262394e-07
# Interation = 17
# ===================
# Residual = 1.5312859974086626e-07
# Interation = 18
# ===================
# Residual = 6.416649769094507e-08
# Interation = 19
# ===================
# Residual = 2.6963649206717226e-08
# Interation = 20
# ===================
# Residual = 1.1360647829902568e-08
# Interation = 21
# ===================
# Residual = 4.798609187389651e-09
# Interation = 22
# ===================
# Residual = 2.0316477348032084e-09
# Interation = 23
# ===================
# Residual = 8.620558493870384e-10
# Interation = 24
# ===================
# Residual = 3.6653074297637344e-10
# Interation = 25
# ===================
# Residual = 1.561396587825155e-10
# Interation = 26
# ===================
# Residual = 6.663070398199383e-11
# Interation = 27
# ===================
# Residual = 2.8480745493535776e-11
# Interation = 28
# ===================
# Residual = 1.2192276244591338e-11
# Interation = 29
# ===================
# Residual = 5.227787254357803e-12
# Interation = 30
# ===================
# Residual = 2.2438019967063285e-12
# Interation = 31
# ===================
# Residual = 9.64390079168955e-13
# Interation = 32
# ===================
# Residual = 4.166430234206742e-13
# Interation = 33
# ===================
# Residual = 1.814690623097313e-13
# Interation = 34
# ===================
# Residual = 8.273590138366328e-14
# Interation = 35
# ===================
# Residual = 4.589659017032524e-14
# Interation = 36
# ===================
# Residual = 3.1650740012125236e-14
# Interation = 37
# ===================
# Residual = 3.0282375217288486e-14
# Interation = 38
# ===================
# Residual = 2.8300270065642588e-14
# Interation = 39
# ===================
# Residual = 2.893963398948917e-14
# Interation = 40
# ===================
# Residual = 2.8081754865154892e-14
# Interation = 41
# ===================
# Residual = 2.9659839490590445e-14
# Interation = 42
# ===================
# Residual = 2.799580253693051e-14
# Interation = 43
# ===================
# Residual = 2.85016399082877e-14
# Interation = 44
# ===================
# Residual = 2.7227661238884992e-14
# Interation = 45
# ===================
# Residual = 2.9851755518871815e-14
# Interation = 46
# ===================
# Residual = 2.913224995621065e-14
# Interation = 47
# ===================
# Residual = 2.927625285576028e-14
# Interation = 48
# ===================
# Residual = 2.8443517626579445e-14
# Interation = 49
# ===================

# %% [markdown]
# **Plot Result**

# %%
plt.imshow(GMM_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# **Plot Residual**

# %%
plt.semilogy(GMM_Res)

# %% [markdown]
# **Calculate Spectral Radius**

# %%
GMM_Radius = rho(inputsize,A1,P,R,w,s)
print('GMM_Radius = {}'.format(GMM_Radius))
# Out:
# GMM_Radius = 0.46619808175866373

# %% [markdown]
# ## AMG

# %% [markdown]
# **Define Solver and Solve**

# %%
amg_solver = pyamg.classical.classical.ruge_stuben_solver(A1,max_levels = 2)
pyamg.relaxation.smoothing.change_smoothers(amg_solver,presmoother=("jacobi", {"omega": w, "iterations": s}),postsmoother=("jacobi", {"omega": w, "iterations": s}))
AMG_Res = []
print(amg_solver)
AMG_U= amg_solver.solve(RightF, maxiter = MAX_ITER, tol=0, residuals=AMG_Res)
# Out:
# D:\anaconda\lib\site-packages\pyamg\classical\classical.py:101: SparseEfficiencyWarning: Implicit conversion of A to CSR
#   SparseEfficiencyWarning)
# multilevel_solver
# Number of Levels:     2
# Operator Complexity:  1.872
# Grid Complexity:      1.501
# Coarse Solver:        'pinv2'
#   level   unknowns     nonzeros
#     0          961         4681 [53.42%]
#     1          481         4081 [46.58%]

# %% [markdown]
# **Plot Result**

# %%
plt.imshow(AMG_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# **Plot Residual**

# %%
plt.semilogy(AMG_Res)

# %% [markdown]
# ## DMM

# %% [markdown]
# **Optimize R, P, $\omega$**

# %%
Pnew, Rnew, wnew, Rhoold, Rhonew = homotopy_optimizer_GD(inputsize, A0, A1, Interpolation(inputsize), Restriction(inputsize),  2/3, s, learning_rate = 1e-1,accept_radius = GMM_Radius,step_length = 1e-1)
# Out:
# ======Section 1======
# Decrease the step_length, learning_rate and Restart!!
# step_length = 0.010000000000000002
# learning_rate = 0.010000000000000002
# rhonew = 0.4849435621334588
# ===================
# L = 0.020000000000000004
# rho = 0.44991664009896176
# ===================
# L = 0.030000000000000006
# rho = 0.4445265656151974
# ===================
# L = 0.04000000000000001
# rho = 0.4399758050616917
# ===================
# L = 0.05000000000000001
# rho = 0.4352716068545082
# ===================
# L = 0.06000000000000001
# rho = 0.4308802795805519
# ===================
# L = 0.07
# rho = 0.42640855936695704
# ===================
# L = 0.08000000000000002
# rho = 0.4221168044482985
# ===================
# L = 0.09000000000000002
# rho = 0.41778448415122965
# ===================
# L = 0.10000000000000003
# rho = 0.4135582542976103
# ===================
# L = 0.11000000000000004
# rho = 0.40934628713824894
# ===================
# L = 0.12000000000000005
# rho = 0.4051547355587928
# ===================
# L = 0.13000000000000006
# rho = 0.4010300882796712
# ===================
# L = 0.14000000000000007
# rho = 0.3968075716215336
# ===================
# L = 0.15000000000000008
# rho = 0.39268991154383054
# ===================
# L = 0.1600000000000001
# rho = 0.38844788164951455
# ===================
# L = 0.1700000000000001
# rho = 0.38435825946050084
# ===================
# L = 0.1800000000000001
# rho = 0.38019132778326503
# ===================
# L = 0.1900000000000001
# rho = 0.3761812590857581
# ===================
# L = 0.20000000000000012
# rho = 0.3721602429652475
# ===================
# L = 0.21000000000000013
# rho = 0.369264820418
# ===================
# L = 0.22000000000000014
# rho = 0.3709699363707857
# ===================
# L = 0.23000000000000015
# rho = 0.387005537045935
# ===================
# Decrease the step_length, learning_rate and Restart!!
# step_length = 0.0010000000000000002
# learning_rate = 0.0010000000000000002
# rhonew = 1.2865776577341612
# ===================
# L = 0.0020000000000000005
# rho = 0.4535927540373067
# ===================
# L = 0.003000000000000001
# rho = 0.4531145957045714
# ===================
# L = 0.004000000000000001
# rho = 0.45264190653804415
# ===================
# L = 0.005000000000000001
# rho = 0.45217157119868756
# ===================
# L = 0.006000000000000001
# rho = 0.45170172812304626
# ===================
# L = 0.007000000000000001
# rho = 0.45123131956883283
# ===================
# L = 0.008000000000000002
# rho = 0.4507598067905766
# ===================
# L = 0.009000000000000003
# rho = 0.45028698468696043
# ===================
# L = 0.010000000000000004
# rho = 0.44981285893873396
# ===================
# L = 0.011000000000000005
# rho = 0.44933756372787176
# ===================
# L = 0.012000000000000005
# rho = 0.4488613064636786
# ===================
# L = 0.013000000000000006
# rho = 0.4483843307922001
# ===================
# L = 0.014000000000000007
# rho = 0.44790689212172197
# ===================
# L = 0.015000000000000008
# rho = 0.44742924177044524
# ===================
# L = 0.016000000000000007
# rho = 0.44695161706663705
# ===================
# L = 0.017000000000000008
# rho = 0.44647423555075944
# ===================
# L = 0.01800000000000001
# rho = 0.4459972919871022
# ===================
# L = 0.01900000000000001
# rho = 0.44552095727769125
# ===================
# L = 0.02000000000000001
# rho = 0.4450453786399338
# ===================
# L = 0.02100000000000001
# rho = 0.4445706805983432
# ===================
# L = 0.022000000000000013
# rho = 0.44409696647431257
# ===================
# L = 0.023000000000000013
# rho = 0.44362432015291003
# ===================
# L = 0.024000000000000014
# rho = 0.44315280797348355
# ===================
# L = 0.025000000000000015
# rho = 0.442682480639406
# ===================
# L = 0.026000000000000016
# rho = 0.44221337507708974
# ===================
# L = 0.027000000000000017
# rho = 0.4417455161993394
# ===================
# L = 0.028000000000000018
# rho = 0.44127891854594337
# ===================
# L = 0.02900000000000002
# rho = 0.4408135877870813
# ===================
# L = 0.03000000000000002
# rho = 0.44034952208405104
# ===================
# L = 0.03100000000000002
# rho = 0.43988671330800033
# ===================
# L = 0.03200000000000002
# rho = 0.43942514812152544
# ===================
# L = 0.03300000000000002
# rho = 0.43896480893070555
# ===================
# L = 0.03400000000000002
# rho = 0.4385056747167717
# ===================
# L = 0.035000000000000024
# rho = 0.4380477217574653
# ===================
# L = 0.036000000000000025
# rho = 0.43759092424843293
# ===================
# L = 0.037000000000000026
# rho = 0.4371352548349017
# ===================
# L = 0.03800000000000003
# rho = 0.4366806850635088
# ===================
# L = 0.03900000000000003
# rho = 0.4362271857636067
# ===================
# L = 0.04000000000000003
# rho = 0.4357747273667034
# ===================
# L = 0.04100000000000003
# rho = 0.43532328017198313
# ===================
# L = 0.04200000000000003
# rho = 0.4348728145651102
# ===================
# L = 0.04300000000000003
# rho = 0.4344233011967938
# ===================
# L = 0.04400000000000003
# rho = 0.4339747111268815
# ===================
# L = 0.04500000000000003
# rho = 0.43352701593908766
# ===================
# L = 0.046000000000000034
# rho = 0.43308018783084185
# ===================
# L = 0.047000000000000035
# rho = 0.4326341996821752
# ===================
# L = 0.048000000000000036
# rho = 0.4321890251070438
# ===================
# L = 0.04900000000000004
# rho = 0.4317446384900286
# ===================
# L = 0.05000000000000004
# rho = 0.43130101501093215
# ===================
# L = 0.05100000000000004
# rho = 0.43085813065943007
# ===================
# L = 0.05200000000000004
# rho = 0.4304159622416105
# ===================
# L = 0.05300000000000004
# rho = 0.42997448737995286
# ===================
# L = 0.05400000000000004
# rho = 0.42953368450805346
# ===================
# L = 0.05500000000000004
# rho = 0.42909353286119284
# ===================
# L = 0.05600000000000004
# rho = 0.42865401246365875
# ===================
# L = 0.057000000000000044
# rho = 0.4282151041135791
# ===================
# L = 0.058000000000000045
# rho = 0.427776789365893
# ===================
# L = 0.059000000000000045
# rho = 0.42733905051396814
# ===================
# L = 0.060000000000000046
# rho = 0.4269018705702825
# ===================
# L = 0.06100000000000005
# rho = 0.42646523324650737
# ===================
# L = 0.06200000000000005
# rho = 0.4260291229332602
# ===================
# L = 0.06300000000000004
# rho = 0.42559352467974315
# ===================
# L = 0.06400000000000004
# rho = 0.4251584241734342
# ===================
# L = 0.06500000000000004
# rho = 0.4247238077199627
# ===================
# L = 0.06600000000000004
# rho = 0.42428966222326736
# ===================
# L = 0.06700000000000005
# rho = 0.4238559751661115
# ===================
# L = 0.06800000000000005
# rho = 0.42342273459101
# ===================
# L = 0.06900000000000005
# rho = 0.42298992908160354
# ===================
# L = 0.07000000000000005
# rho = 0.42255754774450754
# ===================
# L = 0.07100000000000005
# rho = 0.4221255801916465
# ===================
# L = 0.07200000000000005
# rho = 0.4216940165230824
# ===================
# L = 0.07300000000000005
# rho = 0.42126284731033714
# ===================
# L = 0.07400000000000005
# rho = 0.42083206358020325
# ===================
# L = 0.07500000000000005
# rho = 0.4204016567990364
# ===================
# L = 0.07600000000000005
# rho = 0.4199716188575185
# ===================
# L = 0.07700000000000005
# rho = 0.41954194205588086
# ===================
# L = 0.07800000000000006
# rho = 0.4191126190895723
# ===================
# L = 0.07900000000000006
# rho = 0.41868364303536193
# ===================
# L = 0.08000000000000006
# rho = 0.41825500733785914
# ===================
# L = 0.08100000000000006
# rho = 0.4178267057964406
# ===================
# L = 0.08200000000000006
# rho = 0.4173987325525693
# ===================
# L = 0.08300000000000006
# rho = 0.4169710820774925
# ===================
# L = 0.08400000000000006
# rho = 0.4165437491603063
# ===================
# L = 0.08500000000000006
# rho = 0.41611672889637646
# ===================
# L = 0.08600000000000006
# rho = 0.4156900166761009
# ===================
# L = 0.08700000000000006
# rho = 0.4152636081740064
# ===================
# L = 0.08800000000000006
# rho = 0.4148374993381679
# ===================
# L = 0.08900000000000007
# rho = 0.41441168637993847
# ===================
# L = 0.09000000000000007
# rho = 0.4139861657639868
# ===================
# L = 0.09100000000000007
# rho = 0.4135609341986258
# ===================
# L = 0.09200000000000007
# rho = 0.41313598862643086
# ===================
# L = 0.09300000000000007
# rho = 0.4127113262151356
# ===================
# L = 0.09400000000000007
# rho = 0.4122869443488
# ===================
# L = 0.09500000000000007
# rho = 0.41186284061924266
# ===================
# L = 0.09600000000000007
# rho = 0.41143901281773104
# ===================
# L = 0.09700000000000007
# rho = 0.4110154589269231
# ===================
# L = 0.09800000000000007
# rho = 0.41059217711305407
# ===================
# L = 0.09900000000000007
# rho = 0.41016916571836176
# ===================
# L = 0.10000000000000007
# rho = 0.40974642325374633
# ===================
# L = 0.10100000000000008
# rho = 0.40932394839165676
# ===================
# L = 0.10200000000000008
# rho = 0.40890173995919976
# ===================
# L = 0.10300000000000008
# rho = 0.4084797969314664
# ===================
# L = 0.10400000000000008
# rho = 0.4080581184250696
# ===================
# L = 0.10500000000000008
# rho = 0.40763670369188904
# ===================
# L = 0.10600000000000008
# rho = 0.40721555211301685
# ===================
# L = 0.10700000000000008
# rho = 0.40679466319290203
# ===================
# L = 0.10800000000000008
# rho = 0.40637403655368504
# ===================
# L = 0.10900000000000008
# rho = 0.4059536719297213
# ===================
# L = 0.11000000000000008
# rho = 0.4055335691622868
# ===================
# L = 0.11100000000000008
# rho = 0.40511372819446245
# ===================
# L = 0.11200000000000009
# rho = 0.40469414906619194
# ===================
# L = 0.11300000000000009
# rho = 0.40427483190950947
# ===================
# L = 0.11400000000000009
# rho = 0.40385577694393215
# ===================
# L = 0.11500000000000009
# rho = 0.4034369844720139
# ===================
# L = 0.11600000000000009
# rho = 0.4030184548750554
# ===================
# L = 0.11700000000000009
# rho = 0.40260018860896696
# ===================
# L = 0.11800000000000009
# rho = 0.40218218620027946
# ===================
# L = 0.11900000000000009
# rho = 0.40176444824230023
# ===================
# L = 0.12000000000000009
# rho = 0.40134697539140923
# ===================
# L = 0.1210000000000001
# rho = 0.40092976836349137
# ===================
# L = 0.1220000000000001
# rho = 0.40051282793050247
# ===================
# L = 0.1230000000000001
# rho = 0.40009615491716355
# ===================
# L = 0.1240000000000001
# rho = 0.39967975019778096
# ===================
# L = 0.12500000000000008
# rho = 0.39926361469318794
# ===================
# L = 0.12600000000000008
# rho = 0.3988477493678045
# ===================
# L = 0.12700000000000009
# rho = 0.39843215522681225
# ===================
# L = 0.12800000000000009
# rho = 0.39801683331344034
# ===================
# L = 0.1290000000000001
# rho = 0.39760178470635965
# ===================
# L = 0.1300000000000001
# rho = 0.3971870105171817
# ===================
# L = 0.1310000000000001
# rho = 0.3967725118880594
# ===================
# L = 0.1320000000000001
# rho = 0.39635828998938555
# ===================
# L = 0.1330000000000001
# rho = 0.3959443460175886
# ===================
# L = 0.1340000000000001
# rho = 0.39553068119301915
# ===================
# L = 0.1350000000000001
# rho = 0.3951172967579278
# ===================
# L = 0.1360000000000001
# rho = 0.39470419397452877
# ===================
# L = 0.1370000000000001
# rho = 0.39429137412314974
# ===================
# L = 0.1380000000000001
# rho = 0.3938788385004614
# ===================
# L = 0.1390000000000001
# rho = 0.3934665884177883
# ===================
# L = 0.1400000000000001
# rho = 0.39305462519949597
# ===================
# L = 0.1410000000000001
# rho = 0.3926429501814532
# ===================
# L = 0.1420000000000001
# rho = 0.3922315647095674
# ===================
# L = 0.1430000000000001
# rho = 0.39182047013839155
# ===================
# L = 0.1440000000000001
# rho = 0.3914096678298002
# ===================
# L = 0.1450000000000001
# rho = 0.3909991591517342
# ===================
# L = 0.1460000000000001
# rho = 0.3905889454770142
# ===================
# L = 0.1470000000000001
# rho = 0.39017902818222083
# ===================
# L = 0.1480000000000001
# rho = 0.3897694086466444
# ===================
# L = 0.1490000000000001
# rho = 0.3893600882513051
# ===================
# L = 0.1500000000000001
# rho = 0.3889510683780479
# ===================
# L = 0.1510000000000001
# rho = 0.38854235040871954
# ===================
# L = 0.1520000000000001
# rho = 0.3881339357244355
# ===================
# L = 0.1530000000000001
# rho = 0.3877258257049541
# ===================
# L = 0.1540000000000001
# rho = 0.3873180217281798
# ===================
# L = 0.1550000000000001
# rho = 0.38691052516982916
# ===================
# L = 0.1560000000000001
# rho = 0.38650333740330733
# ===================
# L = 0.1570000000000001
# rho = 0.3860964597998649
# ===================
# L = 0.1580000000000001
# rho = 0.38568989372913914
# ===================
# L = 0.1590000000000001
# rho = 0.3852836405602212
# ===================
# L = 0.16000000000000011
# rho = 0.38487770166346247
# ===================
# L = 0.16100000000000012
# rho = 0.3844720784133181
# ===================
# L = 0.16200000000000012
# rho = 0.3840667721926583
# ===================
# L = 0.16300000000000012
# rho = 0.38366178439916043
# ===================
# L = 0.16400000000000012
# rho = 0.38325711645465926
# ===================
# L = 0.16500000000000012
# rho = 0.38285276981870325
# ===================
# L = 0.16600000000000012
# rho = 0.38244874600809725
# ===================
# L = 0.16700000000000012
# rho = 0.3820450466249617
# ===================
# L = 0.16800000000000012
# rho = 0.38164167339690436
# ===================
# L = 0.16900000000000012
# rho = 0.3812386282344112
# ===================
# L = 0.17000000000000012
# rho = 0.38083591331269545
# ===================
# L = 0.17100000000000012
# rho = 0.3804335311882649
# ===================
# L = 0.17200000000000013
# rho = 0.3800314849647226
# ===================
# L = 0.17300000000000013
# rho = 0.3796297785283318
# ===================
# L = 0.17400000000000013
# rho = 0.3792284168823307
# ===================
# L = 0.17500000000000013
# rho = 0.3788274066208984
# ===================
# L = 0.17600000000000013
# rho = 0.37842675660039543
# ===================
# L = 0.17700000000000013
# rho = 0.3780264788889609
# ===================
# L = 0.17800000000000013
# rho = 0.37762659010837246
# ===================
# L = 0.17900000000000013
# rho = 0.37722711332787573
# ===================
# L = 0.18000000000000013
# rho = 0.37682808073336116
# ===================
# L = 0.18100000000000013
# rho = 0.3764295373833324
# ===================
# L = 0.18200000000000013
# rho = 0.37603154648404086
# ===================
# L = 0.18300000000000013
# rho = 0.3756341967805089
# ===================
# L = 0.18400000000000014
# rho = 0.3752376128801286
# ===================
# L = 0.18500000000000014
# rho = 0.3748419696131838
# ===================
# L = 0.18600000000000014
# rho = 0.37444751189738057
# ===================
# L = 0.18700000000000014
# rho = 0.3740545820040426
# ===================
# L = 0.18800000000000014
# rho = 0.37366365658099976
# ===================
# L = 0.18900000000000014
# rho = 0.37327539616404576
# ===================
# L = 0.19000000000000014
# rho = 0.3728907099853692
# ===================
# L = 0.19100000000000014
# rho = 0.3725108382833808
# ===================
# L = 0.19200000000000014
# rho = 0.3721374524676993
# ===================
# L = 0.19300000000000014
# rho = 0.37177276960460803
# ===================
# L = 0.19400000000000014
# rho = 0.3714196703571357
# ===================
# L = 0.19500000000000015
# rho = 0.37108179533752333
# ===================
# L = 0.19600000000000015
# rho = 0.370763567852629
# ===================
# L = 0.19700000000000015
# rho = 0.3704700542731725
# ===================
# L = 0.19800000000000015
# rho = 0.37020656680626873
# ===================
# L = 0.19900000000000015
# rho = 0.36997798447810637
# ===================
# L = 0.20000000000000015
# rho = 0.3697878591003961
# ===================
# L = 0.20100000000000015
# rho = 0.36963747045303136
# ===================
# L = 0.20200000000000015
# rho = 0.3695252498168508
# ===================
# L = 0.20300000000000015
# rho = 0.3694469084313134
# ===================
# L = 0.20400000000000015
# rho = 0.3693961845429318
# ===================
# L = 0.20500000000000015
# rho = 0.36936629535094095
# ===================
# L = 0.20600000000000016
# rho = 0.36935019693321425
# ===================
# L = 0.20700000000000016
# rho = 0.3693459008051618
# ===================
# L = 0.20800000000000016
# rho = 0.3693447165278913
# ===================
# L = 0.20900000000000016
# rho = 0.36967451564098397
# ===================
# L = 0.21000000000000016
# rho = 0.37259672258732024
# ===================
# L = 0.21100000000000016
# rho = 0.37017888957444034
# ===================
# L = 0.21200000000000016
# rho = 0.36998573124490375
# ===================
# L = 0.21300000000000016
# rho = 0.369891915789782
# ===================
# L = 0.21400000000000016
# rho = 0.3697348403641033
# ===================
# L = 0.21500000000000016
# rho = 0.36977148162652557
# ===================
# L = 0.21600000000000016
# rho = 0.3698659521968955
# ===================
# L = 0.21700000000000016
# rho = 0.370173710518333
# ===================
# L = 0.21800000000000017
# rho = 0.37022312401117297
# ===================
# L = 0.21900000000000017
# rho = 0.37002197023210026
# ===================
# L = 0.22000000000000017
# rho = 0.36980896805381275
# ===================
# L = 0.22100000000000017
# rho = 0.3697174110650745
# ===================
# L = 0.22200000000000017
# rho = 0.3696016730016659
# ===================
# L = 0.22300000000000017
# rho = 0.3697573631404387
# ===================
# L = 0.22400000000000017
# rho = 0.37010878707715006
# ===================
# L = 0.22500000000000017
# rho = 0.37013484667448826
# ===================
# L = 0.22600000000000017
# rho = 0.37002380683749003
# ===================
# L = 0.22700000000000017
# rho = 0.36989353934112335
# ===================
# L = 0.22800000000000017
# rho = 0.36970357560543843
# ===================
# L = 0.22900000000000018
# rho = 0.36965272028536333
# ===================
# L = 0.23000000000000018
# rho = 0.3695787539888539
# ===================
# L = 0.23100000000000018
# rho = 0.3698376963900026
# ===================
# L = 0.23200000000000018
# rho = 0.37021183486117704
# ===================
# L = 0.23300000000000018
# rho = 0.3699550347510027
# ===================
# L = 0.23400000000000018
# rho = 0.36977456453315694
# ===================
# L = 0.23500000000000018
# rho = 0.36972588197084544
# ===================
# L = 0.23600000000000018
# rho = 0.3696025086683649
# ===================
# L = 0.23700000000000018
# rho = 0.36969471204461957
# ===================
# L = 0.23800000000000018
# rho = 0.36979963381006914
# ===================
# L = 0.23900000000000018
# rho = 0.36992929246557166
# ===================
# L = 0.24000000000000019
# rho = 0.36993021419649835
# ===================
# L = 0.2410000000000002
# rho = 0.3697955999310707
# ===================
# L = 0.2420000000000002
# rho = 0.36962398013829695
# ===================
# L = 0.2430000000000002
# rho = 0.3696089477484274
# ===================
# L = 0.2440000000000002
# rho = 0.3695459915347766
# ===================
# L = 0.2450000000000002
# rho = 0.36974667444917214
# ===================
# L = 0.2460000000000002
# rho = 0.3699682312583094
# ===================
# L = 0.2470000000000002
# rho = 0.36980961620333525
# ===================
# L = 0.2480000000000002
# rho = 0.3696668087572118
# ===================
# L = 0.2490000000000002
# rho = 0.36964472700050227
# ===================
# L = 0.25000000000000017
# rho = 0.3695441637264315
# ===================
# L = 0.25100000000000017
# rho = 0.3696355551405302
# ===================
# L = 0.25200000000000017
# rho = 0.36969974894726476
# ===================
# L = 0.25300000000000017
# rho = 0.3697670735825458
# ===================
# L = 0.25400000000000017
# rho = 0.3697549800713281
# ===================
# L = 0.25500000000000017
# rho = 0.36967494576606247
# ===================
# L = 0.25600000000000017
# rho = 0.3695445339365026
# ===================
# L = 0.2570000000000002
# rho = 0.3695669299871142
# ===================
# L = 0.2580000000000002
# rho = 0.3695300702473253
# ===================
# L = 0.2590000000000002
# rho = 0.3696623067042985
# ===================
# L = 0.2600000000000002
# rho = 0.3697526060967024
# ===================
# L = 0.2610000000000002
# rho = 0.36966963049265006
# ===================
# L = 0.2620000000000002
# rho = 0.3695633418085127
# ===================
# L = 0.2630000000000002
# rho = 0.36956239078936465
# ===================
# L = 0.2640000000000002
# rho = 0.3694911118337733
# ===================
# L = 0.2650000000000002
# rho = 0.3695704892191626
# ===================
# L = 0.2660000000000002
# rho = 0.36960514249061854
# ===================
# L = 0.2670000000000002
# rho = 0.36963039167966016
# ===================
# L = 0.2680000000000002
# rho = 0.3696022667582036
# ===================
# L = 0.2690000000000002
# rho = 0.3695673894006357
# ===================
# L = 0.2700000000000002
# rho = 0.36948018109821645
# ===================
# L = 0.2710000000000002
# rho = 0.3695128660160901
# ===================
# L = 0.2720000000000002
# rho = 0.3694880970508011
# ===================
# L = 0.2730000000000002
# rho = 0.36955789071559175
# ===================
# L = 0.2740000000000002
# rho = 0.36957973312306563
# ===================
# L = 0.2750000000000002
# rho = 0.36955217621717706
# ===================
# L = 0.2760000000000002
# rho = 0.36948748804899684
# ===================
# L = 0.2770000000000002
# rho = 0.36949225548978176
# ===================
# L = 0.2780000000000002
# rho = 0.3694411147674517
# ===================
# L = 0.2790000000000002
# rho = 0.3694895163864216
# ===================
# L = 0.2800000000000002
# rho = 0.36949128670602255
# ===================
# L = 0.2810000000000002
# rho = 0.36951194025948514
# ===================
# L = 0.2820000000000002
# rho = 0.3694917978597877
# ===================
# L = 0.2830000000000002
# rho = 0.3694784342641929
# ===================
# L = 0.2840000000000002
# rho = 0.3694243688816653
# ===================
# L = 0.2850000000000002
# rho = 0.36944556466262035
# ===================
# L = 0.2860000000000002
# rho = 0.36941994170081344
# ===================
# L = 0.2870000000000002
# rho = 0.3694559274894312
# ===================
# L = 0.2880000000000002
# rho = 0.3694529799772453
# ===================
# L = 0.2890000000000002
# rho = 0.36945219477939717
# ===================
# L = 0.2900000000000002
# rho = 0.3694190388132162
# ===================
# L = 0.2910000000000002
# rho = 0.36942066619761277
# ===================
# L = 0.2920000000000002
# rho = 0.3693841198285532
# ===================
# L = 0.2930000000000002
# rho = 0.36940730408676853
# ===================
# L = 0.2940000000000002
# rho = 0.3693933911770007
# ===================
# L = 0.2950000000000002
# rho = 0.3694108982909934
# ===================
# L = 0.2960000000000002
# rho = 0.3693978914311556
# ===================
# L = 0.2970000000000002
# rho = 0.36939607563148785
# ===================
# L = 0.2980000000000002
# rho = 0.3693664161654306
# ===================
# L = 0.2990000000000002
# rho = 0.3693739740329974
# ===================
# L = 0.3000000000000002
# rho = 0.3693501688552177
# ===================
# L = 0.3010000000000002
# rho = 0.3693670414179727
# ===================
# L = 0.3020000000000002
# rho = 0.36935558706601773
# ===================
# L = 0.3030000000000002
# rho = 0.36936270587977654
# ===================
# L = 0.3040000000000002
# rho = 0.369346544307832
# ===================
# L = 0.3050000000000002
# rho = 0.36934682372230776
# ===================
# L = 0.3060000000000002
# rho = 0.3693242647784136
# ===================
# L = 0.3070000000000002
# rho = 0.36933160076737787
# ===================
# L = 0.3080000000000002
# rho = 0.36931513849174
# ===================
# L = 0.3090000000000002
# rho = 0.3693247601502511
# ===================
# L = 0.3100000000000002
# rho = 0.3693137182574289
# ===================
# L = 0.3110000000000002
# rho = 0.36931639591109994
# ===================
# L = 0.3120000000000002
# rho = 0.3693017638592799
# ===================
# L = 0.3130000000000002
# rho = 0.3693024931459288
# ===================
# L = 0.3140000000000002
# rho = 0.3692861264408179
# ===================
# L = 0.3150000000000002
# rho = 0.3692906185929467
# ===================
# L = 0.3160000000000002
# rho = 0.369278386382437
# ===================
# L = 0.3170000000000002
# rho = 0.36928263470465017
# ===================
# L = 0.3180000000000002
# rho = 0.36927276209164106
# ===================
# L = 0.31900000000000023
# rho = 0.3692730570239815
# ===================
# L = 0.32000000000000023
# rho = 0.36926148425046534
# ===================
# L = 0.32100000000000023
# rho = 0.36926112072499834
# ===================
# L = 0.32200000000000023
# rho = 0.3692494294690886
# ===================
# L = 0.32300000000000023
# rho = 0.369250652669942
# ===================
# L = 0.32400000000000023
# rho = 0.3692414227965042
# ===================
# L = 0.32500000000000023
# rho = 0.3692419319408234
# ===================
# L = 0.32600000000000023
# rho = 0.3692339904908568
# ===================
# L = 0.32700000000000023
# rho = 0.36923232756402974
# ===================
# L = 0.32800000000000024
# rho = 0.36922389739756667
# ===================
# L = 0.32900000000000024
# rho = 0.36922174527643403
# ===================
# L = 0.33000000000000024
# rho = 0.3692136352206867
# ===================
# L = 0.33100000000000024
# rho = 0.3692119527358663
# ===================
# L = 0.33200000000000024
# rho = 0.3692053017044756
# ===================
# L = 0.33300000000000024
# rho = 0.3692030024808717
# ===================
# L = 0.33400000000000024
# rho = 0.36919727040547584
# ===================
# L = 0.33500000000000024
# rho = 0.36919371144677254
# ===================
# L = 0.33600000000000024
# rho = 0.3691880909643552
# ===================
# L = 0.33700000000000024
# rho = 0.3691840137778928
# ===================
# L = 0.33800000000000024
# rho = 0.3691788010693438
# ===================
# L = 0.33900000000000025
# rho = 0.3691746840667156
# ===================
# L = 0.34000000000000025
# rho = 0.3691703925765231
# ===================
# L = 0.34100000000000025
# rho = 0.3691658043786512
# ===================
# L = 0.34200000000000025
# rho = 0.3691622530803333
# ===================
# L = 0.34300000000000025
# rho = 0.3691568710882771
# ===================
# L = 0.34400000000000025
# rho = 0.3691536825106355
# ===================
# L = 0.34500000000000025
# rho = 0.3691477856033146
# ===================
# L = 0.34600000000000025
# rho = 0.36914501219500945
# ===================
# L = 0.34700000000000025
# rho = 0.3691388614840313
# ===================
# L = 0.34800000000000025
# rho = 0.36913672527230085
# ===================
# L = 0.34900000000000025
# rho = 0.36913019464305413
# ===================
# L = 0.35000000000000026
# rho = 0.369128666391961
# ===================
# L = 0.35100000000000026
# rho = 0.3691215935897665
# ===================
# L = 0.35200000000000026
# rho = 0.3691205032663911
# ===================
# L = 0.35300000000000026
# rho = 0.36911296698604734
# ===================
# L = 0.35400000000000026
# rho = 0.36911228216202685
# ===================
# L = 0.35500000000000026
# rho = 0.36910441971352487
# ===================
# L = 0.35600000000000026
# rho = 0.3691042188847296
# ===================
# L = 0.35700000000000026
# rho = 0.369096024904626
# ===================
# L = 0.35800000000000026
# rho = 0.36909632089012157
# ===================
# L = 0.35900000000000026
# rho = 0.36908772760927905
# ===================
# L = 0.36000000000000026
# rho = 0.3690884523656952
# ===================
# L = 0.36100000000000027
# rho = 0.3690794684796481
# ===================
# L = 0.36200000000000027
# rho = 0.3690805782698401
# ===================
# L = 0.36300000000000027
# rho = 0.3690712668214383
# ===================
# L = 0.36400000000000027
# rho = 0.3690727734449598
# ===================
# L = 0.36500000000000027
# rho = 0.3690631617172126
# ===================
# L = 0.36600000000000027
# rho = 0.36906507543358885
# ===================
# L = 0.36700000000000027
# rho = 0.3690551484959921
# ===================
# L = 0.36800000000000027
# rho = 0.3690574457601268
# ===================
# L = 0.36900000000000027
# rho = 0.36904719969360794
# ===================
# L = 0.3700000000000003
# rho = 0.36904984945926944
# ===================
# L = 0.3710000000000003
# rho = 0.36903930869138946
# ===================
# L = 0.3720000000000003
# rho = 0.3690422987154083
# ===================
# L = 0.3730000000000003
# rho = 0.3690314884590227
# ===================
# L = 0.3740000000000003
# rho = 0.36903481683949674
# ===================
# L = 0.3750000000000003
# rho = 0.3690237449953408
# ===================
# L = 0.3760000000000003
# rho = 0.3690274020571236
# ===================
# L = 0.3770000000000003
# rho = 0.3690160704328808
# ===================
# L = 0.3780000000000003
# rho = 0.3690200382441098
# ===================
# L = 0.3790000000000003
# rho = 0.3690084567827474
# ===================
# L = 0.3800000000000003
# rho = 0.3690127197007207
# ===================
# L = 0.3810000000000003
# rho = 0.36900090436485905
# ===================
# L = 0.3820000000000003
# rho = 0.36900545280253366
# ===================
# L = 0.3830000000000003
# rho = 0.36899341644388345
# ===================
# L = 0.3840000000000003
# rho = 0.368998241971785
# ===================
# L = 0.3850000000000003
# rho = 0.3689859924247555
# ===================
# L = 0.3860000000000003
# rho = 0.3689910838195361
# ===================
# L = 0.3870000000000003
# rho = 0.3689786285869768
# ===================
# L = 0.3880000000000003
# rho = 0.3689839732192592
# ===================
# L = 0.3890000000000003
# rho = 0.36897132233862684
# ===================
# L = 0.3900000000000003
# rho = 0.3689769089937505
# ===================
# L = 0.3910000000000003
# rho = 0.3689640734098546
# ===================
# L = 0.3920000000000003
# rho = 0.36896989259576574
# ===================
# L = 0.3930000000000003
# rho = 0.36895688184841974
# ===================
# L = 0.3940000000000003
# rho = 0.3689629242897586
# ===================
# L = 0.3950000000000003
# rho = 0.3689497465112123
# ===================
# L = 0.3960000000000003
# rho = 0.3689560023338516
# ===================
# L = 0.3970000000000003
# rho = 0.36894266558874883
# ===================
# L = 0.3980000000000003
# rho = 0.36894912482446884
# ===================
# L = 0.3990000000000003
# rho = 0.3689356377005603
# ===================
# L = 0.4000000000000003
# rho = 0.36894229097307735
# ===================
# L = 0.4010000000000003
# rho = 0.36892866208088276
# ===================
# L = 0.4020000000000003
# rho = 0.3689355006278088
# ===================
# L = 0.4030000000000003
# rho = 0.3689217380357081
# ===================
# L = 0.4040000000000003
# rho = 0.3689287533243174
# ===================
# L = 0.4050000000000003
# rho = 0.36891486458107664
# ===================
# L = 0.4060000000000003
# rho = 0.36892204810547174
# ===================
# L = 0.4070000000000003
# rho = 0.3689080405772509
# ===================
# L = 0.4080000000000003
# rho = 0.3689153839700369
# ===================
# L = 0.4090000000000003
# rho = 0.36890126499980264
# ===================
# L = 0.4100000000000003
# rho = 0.3689087601979752
# ===================
# L = 0.4110000000000003
# rho = 0.3688945370003
# ===================
# L = 0.4120000000000003
# rho = 0.3689021762636832
# ===================
# L = 0.4130000000000003
# rho = 0.3688878557841065
# ===================
# L = 0.4140000000000003
# rho = 0.3688956316074023
# ===================
# L = 0.4150000000000003
# rho = 0.36888122051086925
# ===================
# L = 0.4160000000000003
# rho = 0.368889125560933
# ===================
# L = 0.4170000000000003
# rho = 0.3688746303086909
# ===================
# L = 0.4180000000000003
# rho = 0.36888265743411414
# ===================
# L = 0.4190000000000003
# rho = 0.36886808433716606
# ===================
# L = 0.4200000000000003
# rho = 0.36887622660392416
# ===================
# L = 0.4210000000000003
# rho = 0.3688615818145222
# ===================
# L = 0.4220000000000003
# rho = 0.36886983251665445
# ===================
# L = 0.4230000000000003
# rho = 0.36885512199757997
# ===================
# L = 0.4240000000000003
# rho = 0.36886347463928826
# ===================
# L = 0.4250000000000003
# rho = 0.36884870415436577
# ===================
# L = 0.4260000000000003
# rho = 0.3688571524290284
# ===================
# L = 0.4270000000000003
# rho = 0.36884232755832114
# ===================
# L = 0.4280000000000003
# rho = 0.36885086534126504
# ===================
# L = 0.4290000000000003
# rho = 0.36883599149942975
# ===================
# L = 0.4300000000000003
# rho = 0.36884461285077935
# ===================
# L = 0.4310000000000003
# rho = 0.3688296952938369
# ===================
# L = 0.43200000000000033
# rho = 0.3688383944601754
# ===================
# L = 0.43300000000000033
# rho = 0.3688234382833156
# ===================
# L = 0.43400000000000033
# rho = 0.368832209693198
# ===================
# L = 0.43500000000000033
# rho = 0.36881721982917287
# ===================
# L = 0.43600000000000033
# rho = 0.36882605808539376
# ===================
# L = 0.43700000000000033
# rho = 0.3688110393081157
# ===================
# L = 0.43800000000000033
# rho = 0.3688199391812259
# ===================
# L = 0.43900000000000033
# rho = 0.3688048961124043
# ===================
# L = 0.44000000000000034
# rho = 0.36881385253684806
# ===================
# L = 0.44100000000000034
# rho = 0.36879878965179314
# ===================
# L = 0.44200000000000034
# rho = 0.3688077977231862
# ===================
# L = 0.44300000000000034
# rho = 0.3687927193543615
# ===================
# L = 0.44400000000000034
# rho = 0.3688017743261982
# ===================
# L = 0.44500000000000034
# rho = 0.36878668466563863
# ===================
# L = 0.44600000000000034
# rho = 0.3687957819450488
# ===================
# L = 0.44700000000000034
# rho = 0.3687806850471484
# ===================
# L = 0.44800000000000034
# rho = 0.3687898201903493
# ===================
# L = 0.44900000000000034
# rho = 0.36877471997547223
# ===================
# L = 0.45000000000000034
# rho = 0.3687838886835634
# ===================
# L = 0.45100000000000035
# rho = 0.36876878894199544
# ===================
# L = 0.45200000000000035
# rho = 0.36877798705721887
# ===================
# L = 0.45300000000000035
# rho = 0.36876289145288
# ===================
# L = 0.45400000000000035
# rho = 0.3687721149550937
# ===================
# L = 0.45500000000000035
# rho = 0.3687570270288431
# ===================
# L = 0.45600000000000035
# rho = 0.3687662720319619
# ===================
# L = 0.45700000000000035
# rho = 0.36875119520468136
# ===================
# L = 0.45800000000000035
# rho = 0.3687604579530361
# ===================
# L = 0.45900000000000035
# rho = 0.36874539552871266
# ===================
# L = 0.46000000000000035
# rho = 0.36875467239341836
# ===================
# L = 0.46100000000000035
# rho = 0.36873962756229856
# ===================
# L = 0.46200000000000035
# rho = 0.3687489150377282
# ===================
# L = 0.46300000000000036
# rho = 0.3687338908794787
# ===================
# L = 0.46400000000000036
# rho = 0.3687431855798654
# ===================
# L = 0.46500000000000036
# rho = 0.368728185066656
# ===================
# L = 0.46600000000000036
# rho = 0.3687374837227957
# ===================
# L = 0.46700000000000036
# rho = 0.3687225097222714
# ===================
# L = 0.46800000000000036
# rho = 0.36873180917828735
# ===================
# L = 0.46900000000000036
# rho = 0.3687168644564461
# ===================
# L = 0.47000000000000036
# rho = 0.36872616166660455
# ===================
# L = 0.47100000000000036
# rho = 0.3687112488906153
# ===================
# L = 0.47200000000000036
# rho = 0.3687205409161975
# ===================
# L = 0.47300000000000036
# rho = 0.3687056626571725
# ===================
# L = 0.47400000000000037
# rho = 0.3687149466634162
# ===================
# L = 0.47500000000000037
# rho = 0.36870010539913645
# ===================
# L = 0.47600000000000037
# rho = 0.3687093786522547
# ===================
# L = 0.47700000000000037
# rho = 0.3686945767698373
# ===================
# L = 0.47800000000000037
# rho = 0.36870383663411077
# ===================
# L = 0.47900000000000037
# rho = 0.3686890764326101
# ===================
# L = 0.48000000000000037
# rho = 0.36869832036754796
# ===================
# L = 0.48100000000000037
# rho = 0.368683604060493
# ===================
# L = 0.4820000000000004
# rho = 0.3686928296180602
# ===================
# L = 0.4830000000000004
# rho = 0.3686781593359297
# ===================
# L = 0.4840000000000004
# rho = 0.36868736415783687
# ===================
# L = 0.4850000000000004
# rho = 0.3686727419504779
# ===================
# L = 0.4860000000000004
# rho = 0.3686819237655366
# ===================
# L = 0.4870000000000004
# rho = 0.36866735160452735
# ===================
# L = 0.4880000000000004
# rho = 0.3686765082260685
# ===================
# L = 0.4890000000000004
# rho = 0.36866198800702604
# ===================
# L = 0.4900000000000004
# rho = 0.36867111733038427
# ===================
# L = 0.4910000000000004
# rho = 0.36865665087521576
# ===================
# L = 0.4920000000000004
# rho = 0.36866575087527653
# ===================
# L = 0.4930000000000004
# rho = 0.36865133993437427
# ===================
# L = 0.4940000000000004
# rho = 0.3686604086631815
# ===================
# L = 0.4950000000000004
# rho = 0.368646054917564
# ===================
# L = 0.4960000000000004
# rho = 0.36865509050198964
# ===================
# L = 0.4970000000000004
# rho = 0.36864079556538853
# ===================
# L = 0.4980000000000004
# rho = 0.36864979620486016
# ===================
# L = 0.4990000000000004
# rho = 0.36863556162575417
# ===================
# L = 0.5000000000000003
# rho = 0.3686445255900424
# ===================
# L = 0.5010000000000003
# rho = 0.3686303528536398
# ===================
# L = 0.5020000000000003
# rho = 0.3686392784807017
# ===================
# L = 0.5030000000000003
# rho = 0.3686251690108725
# ===================
# L = 0.5040000000000003
# rho = 0.36863405470475236
# ===================
# L = 0.5050000000000003
# rho = 0.3686200098659098
# ===================
# L = 0.5060000000000003
# rho = 0.36862885409469587
# ===================
# L = 0.5070000000000003
# rho = 0.368614875193629
# ===================
# L = 0.5080000000000003
# rho = 0.3686236764874632
# ===================
# L = 0.5090000000000003
# rho = 0.36860976477512114
# ===================
# L = 0.5100000000000003
# rho = 0.36861852172426385
# ===================
# L = 0.5110000000000003
# rho = 0.36860467839749234
# ===================
# L = 0.5120000000000003
# rho = 0.36861338965043783
# ===================
# L = 0.5130000000000003
# rho = 0.3685996158536699
# ===================
# L = 0.5140000000000003
# rho = 0.3686082801153141
# ===================
# L = 0.5150000000000003
# rho = 0.3685945769422149
# ===================
# L = 0.5160000000000003
# rho = 0.36860319297207256
# ===================
# L = 0.5170000000000003
# rho = 0.3685895614671392
# ===================
# L = 0.5180000000000003
# rho = 0.36859812807761094
# ===================
# L = 0.5190000000000003
# rho = 0.3685845692377292
# ===================
# L = 0.5200000000000004
# rho = 0.3685930852924166
# ===================
# L = 0.5210000000000004
# rho = 0.36857960006837437
# ===================
# L = 0.5220000000000004
# rho = 0.368588064480441
# ===================
# L = 0.5230000000000004
# rho = 0.36857465377839954
# ===================
# L = 0.5240000000000004
# rho = 0.36858306550898
# ===================
# L = 0.5250000000000004
# rho = 0.3685697301919047
# ===================
# L = 0.5260000000000004
# rho = 0.3685780882485573
# ===================
# L = 0.5270000000000004
# rho = 0.3685648291376078
# ===================
# L = 0.5280000000000004
# rho = 0.36857313257281205
# ===================
# L = 0.5290000000000004
# rho = 0.3685599504486925
# ===================
# L = 0.5300000000000004
# rho = 0.3685681983583891
# ===================
# L = 0.5310000000000004
# rho = 0.36855509396266145
# ===================
# L = 0.5320000000000004
# rho = 0.3685632854848355
# ===================
# L = 0.5330000000000004
# rho = 0.3685502595211929
# ===================
# L = 0.5340000000000004
# rho = 0.36855839383449746
# ===================
# L = 0.5350000000000004
# rho = 0.3685454469700024
# ===================
# L = 0.5360000000000004
# rho = 0.36855352329242225
# ===================
# L = 0.5370000000000004
# rho = 0.3685406561587083
# ===================
# L = 0.5380000000000004
# rho = 0.36854867374626393
# ===================
# L = 0.5390000000000004
# rho = 0.3685358869407021
# ===================
# L = 0.5400000000000004
# rho = 0.3685438450861911
# ===================
# L = 0.5410000000000004
# rho = 0.368531139173022
# ===================
# L = 0.5420000000000004
# rho = 0.3685390372047987
# ===================
# L = 0.5430000000000004
# rho = 0.3685264127162304
# ===================
# L = 0.5440000000000004
# rho = 0.3685342499970223
# ===================
# L = 0.5450000000000004
# rho = 0.36852170743429613
# ===================
# L = 0.5460000000000004
# rho = 0.3685294833600553
# ===================
# L = 0.5470000000000004
# rho = 0.3685170231944795
# ===================
# L = 0.5480000000000004
# rho = 0.3685247371932694
# ===================
# L = 0.5490000000000004
# rho = 0.36851235986722075
# ===================
# L = 0.5500000000000004
# rho = 0.36852001139813717
# ===================
# L = 0.5510000000000004
# rho = 0.3685077173260328
# ===================
# L = 0.5520000000000004
# rho = 0.3685153058781585
# ===================
# L = 0.5530000000000004
# rho = 0.3685030954473971
# ===================
# L = 0.5540000000000004
# rho = 0.3685106205387881
# ===================
# L = 0.5550000000000004
# rho = 0.3684984941106627
# ===================
# L = 0.5560000000000004
# rho = 0.3685059552873662
# ===================
# L = 0.5570000000000004
# rho = 0.3684939131979481
# ===================
# L = 0.5580000000000004
# rho = 0.3685013100330521
# ===================
# L = 0.5590000000000004
# rho = 0.36848935259404725
# ===================
# L = 0.5600000000000004
# rho = 0.3684966846867599
# ===================
# L = 0.5610000000000004
# rho = 0.3684848121863376
# ===================
# L = 0.5620000000000004
# rho = 0.3684920791610957
# ===================
# L = 0.5630000000000004
# rho = 0.3684802918646919
# ===================
# L = 0.5640000000000004
# rho = 0.3684874933702976
# ===================
# L = 0.5650000000000004
# rho = 0.36847579152139176
# ===================
# L = 0.5660000000000004
# rho = 0.36848292723017906
# ===================
# L = 0.5670000000000004
# rho = 0.3684713110510458
# ===================
# L = 0.5680000000000004
# rho = 0.3684783806580714
# ===================
# L = 0.5690000000000004
# rho = 0.36846685035050863
# ===================
# L = 0.5700000000000004
# rho = 0.36847385357277157
# ===================
# L = 0.5710000000000004
# rho = 0.36846240931880353
# ===================
# L = 0.5720000000000004
# rho = 0.36846934589448965
# ===================
# L = 0.5730000000000004
# rho = 0.3684579878570473
# ===================
# L = 0.5740000000000004
# rho = 0.36846485754479924
# ===================
# L = 0.5750000000000004
# rho = 0.36845358586837834
# ===================
# L = 0.5760000000000004
# rho = 0.3684603884465891
# ===================
# L = 0.5770000000000004
# rho = 0.3684492032578859
# ===================
# L = 0.5780000000000004
# rho = 0.36845593852401753
# ===================
# L = 0.5790000000000004
# rho = 0.3684448399325426
# ===================
# L = 0.5800000000000004
# rho = 0.36845150770246765
# ===================
# L = 0.5810000000000004
# rho = 0.36844049580113947
# ===================
# L = 0.5820000000000004
# rho = 0.3684470959085041
# ===================
# L = 0.5830000000000004
# rho = 0.36843617077422197
# ===================
# L = 0.5840000000000004
# rho = 0.3684427030698324
# ===================
# L = 0.5850000000000004
# rho = 0.36843186476402984
# ===================
# L = 0.5860000000000004
# rho = 0.3684383291152593
# ===================
# L = 0.5870000000000004
# rho = 0.3684275776844374
# ===================
# L = 0.5880000000000004
# rho = 0.3684339739746549
# ===================
# L = 0.5890000000000004
# rho = 0.3684233094508976
# ===================
# L = 0.5900000000000004
# rho = 0.3684296375789153
# ===================
# L = 0.5910000000000004
# rho = 0.3684190599803864
# ===================
# L = 0.5920000000000004
# rho = 0.36842531985992855
# ===================
# L = 0.5930000000000004
# rho = 0.36841482919135055
# ===================
# L = 0.5940000000000004
# rho = 0.3684210207505402
# ===================
# L = 0.5950000000000004
# rho = 0.3684106170036561
# ===================
# L = 0.5960000000000004
# rho = 0.36841674018452125
# ===================
# L = 0.5970000000000004
# rho = 0.36840642333853973
# ===================
# L = 0.5980000000000004
# rho = 0.368412478096537
# ===================
# L = 0.5990000000000004
# rho = 0.36840224811856087
# ===================
# L = 0.6000000000000004
# rho = 0.3684082344221175
# ===================
# L = 0.6010000000000004
# rho = 0.36839809126755685
# ===================
# L = 0.6020000000000004
# rho = 0.3684040090976293
# ===================
# L = 0.6030000000000004
# rho = 0.36839395271059844
# ===================
# L = 0.6040000000000004
# rho = 0.3683998020602475
# ===================
# L = 0.6050000000000004
# rho = 0.36838983237394773
# ===================
# L = 0.6060000000000004
# rho = 0.36839561324793024
# ===================
# L = 0.6070000000000004
# rho = 0.36838573018501775
# ===================
# L = 0.6080000000000004
# rho = 0.3683914425993941
# ===================
# L = 0.6090000000000004
# rho = 0.3683816460723333
# ===================
# L = 0.6100000000000004
# rho = 0.36838729005408943
# ===================
# L = 0.6110000000000004
# rho = 0.36837757996549353
# ===================
# L = 0.6120000000000004
# rho = 0.3683831555521787
# ===================
# L = 0.6130000000000004
# rho = 0.3683735317951357
# ===================
# L = 0.6140000000000004
# rho = 0.3683790390345139
# ===================
# L = 0.6150000000000004
# rho = 0.3683695014929012
# ===================
# L = 0.6160000000000004
# rho = 0.3683749404426166
# ===================
# L = 0.6170000000000004
# rho = 0.3683654889914015
# ===================
# L = 0.6180000000000004
# rho = 0.36837085971865835
# ===================
# L = 0.6190000000000004
# rho = 0.36836149422418757
# ===================
# L = 0.6200000000000004
# rho = 0.3683667968054421
# ===================
# L = 0.6210000000000004
# rho = 0.36835751712571885
# ===================
# L = 0.6220000000000004
# rho = 0.3683627516463846
# ===================
# L = 0.6230000000000004
# rho = 0.3683535576313339
# ===================
# L = 0.6240000000000004
# rho = 0.3683587241854994
# ===================
# L = 0.6250000000000004
# rho = 0.36834961567722374
# ===================
# L = 0.6260000000000004
# rho = 0.3683547143673816
# ===================
# L = 0.6270000000000004
# rho = 0.3683456912004039
# ===================
# L = 0.6280000000000004
# rho = 0.3683507221371931
# ===================
# L = 0.6290000000000004
# rho = 0.3683417841386903
# ===================
# L = 0.6300000000000004
# rho = 0.3683467474406481
# ===================
# L = 0.6310000000000004
# rho = 0.3683378944306749
# ===================
# L = 0.6320000000000005
# rho = 0.3683427902240007
# ===================
# L = 0.6330000000000005
# rho = 0.36833402201570264
# ===================
# L = 0.6340000000000005
# rho = 0.3683388504340319
# ===================
# L = 0.6350000000000005
# rho = 0.3683301668338497
# ===================
# L = 0.6360000000000005
# rho = 0.36833492801803935
# ===================
# L = 0.6370000000000005
# rho = 0.3683263288259032
# ===================
# L = 0.6380000000000005
# rho = 0.36833102292382586
# ===================
# L = 0.6390000000000005
# rho = 0.3683225079333414
# ===================
# L = 0.6400000000000005
# rho = 0.36832713509968945
# ===================
# L = 0.6410000000000005
# rho = 0.3683187040983153
# ===================
# L = 0.6420000000000005
# rho = 0.3683232644944158
# ===================
# L = 0.6430000000000005
# rho = 0.3683149172636316
# ===================
# L = 0.6440000000000005
# rho = 0.36831941105726834
# ===================
# L = 0.6450000000000005
# rho = 0.3683111473727363
# ===================
# L = 0.6460000000000005
# rho = 0.368315574737982
# ===================
# L = 0.6470000000000005
# rho = 0.36830739436969884
# ===================
# L = 0.6480000000000005
# rho = 0.3683117554867564
# ===================
# L = 0.6490000000000005
# rho = 0.36830365819919886
# ===================
# L = 0.6500000000000005
# rho = 0.3683079532542491
# ===================
# L = 0.6510000000000005
# rho = 0.3682999388065119
# ===================
# L = 0.6520000000000005
# rho = 0.3683041679915719
# ===================
# L = 0.6530000000000005
# rho = 0.36829623613749796
# ===================
# L = 0.6540000000000005
# rho = 0.3683003996502851
# ===================
# L = 0.6550000000000005
# rho = 0.3682925501385891
# ===================
# L = 0.6560000000000005
# rho = 0.3682966481823943
# ===================
# L = 0.6570000000000005
# rho = 0.3682888807567803
# ===================
# L = 0.6580000000000005
# rho = 0.368292913540348
# ===================
# L = 0.6590000000000005
# rho = 0.36828522793961876
# ===================
# L = 0.6600000000000005
# rho = 0.368289195677034
# ===================
# L = 0.6610000000000005
# rho = 0.36828159163519597
# ===================
# L = 0.6620000000000005
# rho = 0.368285494545779
# ===================
# L = 0.6630000000000005
# rho = 0.36827797179213995
# ===================
# L = 0.6640000000000005
# rho = 0.3682818101003475
# ===================
# L = 0.6650000000000005
# rho = 0.3682743683596084
# ===================
# L = 0.6660000000000005
# rho = 0.3682781422949411
# ===================
# L = 0.6670000000000005
# rho = 0.3682707812872826
# ===================
# L = 0.6680000000000005
# rho = 0.36827449108419996
# ===================
# L = 0.6690000000000005
# rho = 0.3682672105253625
# ===================
# L = 0.6700000000000005
# rho = 0.3682708564232031
# ===================
# L = 0.6710000000000005
# ...
# L = 0.8340000000000006
# rho = 0.36802604362892805
# ===================
# L = 0.8350000000000006
# rho = 0.3680240270927505
# ===================
# L = 0.8360000000000006
# rho = 0.3680236861342315
# ===================
# L = 0.8370000000000006
# rho = 0.36802170968284104
# ===================
# L = 0.8380000000000006
# rho = 0.3680213434039245
# ===================
# L = 0.8390000000000006
# rho = 0.36801940629079843
# ===================
# L = 0.8400000000000006
# rho = 0.36801901539614584
# ===================
# L = 0.8410000000000006
# rho = 0.36801711686843513
# ===================
# L = 0.8420000000000006
# rho = 0.3680167020647613
# ===================
# L = 0.8430000000000006
# rho = 0.36801484136363455
# ===================
# L = 0.8440000000000006
# rho = 0.3680144033592125
# ===================
# L = 0.8450000000000006
# rho = 0.36801257972024215
# ===================
# L = 0.8460000000000006
# rho = 0.36801211922438926
# ===================
# L = 0.8470000000000006
# rho = 0.3680103318779792
# ===================
# L = 0.8480000000000006
# rho = 0.36800984960052446
# ===================
# L = 0.8490000000000006
# rho = 0.3680080977723819
# ===================
# L = 0.8500000000000006
# rho = 0.3680075944231174
# ===================
# L = 0.8510000000000006
# rho = 0.36800587733476836
# ===================
# L = 0.8520000000000006
# rho = 0.3680053536228842
# ===================
# L = 0.8530000000000006
# rho = 0.3680036704922342
# ===================
# L = 0.8540000000000006
# rho = 0.3680031271257399
# ===================
# L = 0.8550000000000006
# rho = 0.3680014771676784
# ===================
# L = 0.8560000000000006
# rho = 0.3680009148528117
# ===================
# L = 0.8570000000000007
# rho = 0.3679992972798614
# ===================
# L = 0.8580000000000007
# rho = 0.3679987167204867
# ===================
# L = 0.8590000000000007
# rho = 0.36799713074349516
# ===================
# L = 0.8600000000000007
# rho = 0.3679965326404918
# ===================
# L = 0.8610000000000007
# rho = 0.36799497746936544
# ===================
# L = 0.8620000000000007
# rho = 0.3679943625200098
# ===================
# L = 0.8630000000000007
# rho = 0.36799283736448735
# ===================
# L = 0.8640000000000007
# rho = 0.3679922062618282
# ===================
# L = 0.8650000000000007
# rho = 0.3679907103322915
# ===================
# L = 0.8660000000000007
# rho = 0.36799006376452253
# ===================
# L = 0.8670000000000007
# rho = 0.36798859627284225
# ===================
# L = 0.8680000000000007
# rho = 0.3679879349226716
# ===================
# L = 0.8690000000000007
# rho = 0.36798649508308334
# ===================
# L = 0.8700000000000007
# rho = 0.36798581962710436
# ===================
# L = 0.8710000000000007
# rho = 0.36798440665711235
# ===================
# L = 0.8720000000000007
# rho = 0.36798371776517447
# ===================
# L = 0.8730000000000007
# rho = 0.36798233088647775
# ===================
# L = 0.8740000000000007
# rho = 0.36798162922106303
# ===================
# L = 0.8750000000000007
# rho = 0.36798026766049863
# ===================
# L = 0.8760000000000007
# rho = 0.3679795538761034
# ===================
# L = 0.8770000000000007
# rho = 0.36797821686660237
# ===================
# L = 0.8780000000000007
# rho = 0.3679774916091266
# ===================
# L = 0.8790000000000007
# rho = 0.3679761783906773
# ===================
# L = 0.8800000000000007
# rho = 0.36797544229682333
# ===================
# L = 0.8810000000000007
# rho = 0.367974152117435
# ===================
# L = 0.8820000000000007
# rho = 0.36797340581412025
# ===================
# L = 0.8830000000000007
# rho = 0.36797213793078043
# ===================
# L = 0.8840000000000007
# rho = 0.36797138203456226
# ===================
# L = 0.8850000000000007
# rho = 0.3679701357141838
# ===================
# L = 0.8860000000000007
# rho = 0.3679693708307024
# ===================
# L = 0.8870000000000007
# rho = 0.3679681453510516
# ===================
# L = 0.8880000000000007
# rho = 0.3679673720744905
# ===================
# L = 0.8890000000000007
# rho = 0.3679661667250913
# ===================
# L = 0.8900000000000007
# rho = 0.36796538563765896
# ===================
# L = 0.8910000000000007
# rho = 0.3679641997206663
# ===================
# L = 0.8920000000000007
# rho = 0.36796341139210154
# ===================
# L = 0.8930000000000007
# rho = 0.367962244223138
# ===================
# L = 0.8940000000000007
# rho = 0.36796144921023943
# ===================
# L = 0.8950000000000007
# rho = 0.36796030011919
# ===================
# L = 0.8960000000000007
# rho = 0.3679594989653744
# ===================
# L = 0.8970000000000007
# rho = 0.36795836729713366
# ===================
# L = 0.8980000000000007
# rho = 0.3679575605320227
# ===================
# L = 0.8990000000000007
# rho = 0.3679564456471884
# ===================
# L = 0.9000000000000007
# rho = 0.36795563378622836
# ===================
# L = 0.9010000000000007
# rho = 0.3679545350617394
# ===================
# L = 0.9020000000000007
# rho = 0.3679537186058535
# ===================
# L = 0.9030000000000007
# rho = 0.3679526354355665
# ===================
# L = 0.9040000000000007
# rho = 0.36795181487084316
# ===================
# L = 0.9050000000000007
# rho = 0.36795074666604527
# ===================
# L = 0.9060000000000007
# rho = 0.3679499224634633
# ===================
# L = 0.9070000000000007
# rho = 0.3679488686533178
# ===================
# L = 0.9080000000000007
# rho = 0.3679480412685111
# ===================
# L = 0.9090000000000007
# rho = 0.3679470013004355
# ===================
# L = 0.9100000000000007
# rho = 0.3679461711734963
# ===================
# L = 0.9110000000000007
# rho = 0.3679451445134698
# ===================
# L = 0.9120000000000007
# rho = 0.3679443120687938
# ===================
# L = 0.9130000000000007
# rho = 0.3679432982015953
# ===================
# L = 0.9140000000000007
# rho = 0.367942463847768
# ===================
# L = 0.9150000000000007
# rho = 0.3679414622771434
# ===================
# L = 0.9160000000000007
# rho = 0.3679406264068689
# ===================
# L = 0.9170000000000007
# rho = 0.36793963665562884
# ===================
# L = 0.9180000000000007
# rho = 0.36793879964570075
# ===================
# L = 0.9190000000000007
# rho = 0.3679378212557506
# ===================
# L = 0.9200000000000007
# rho = 0.3679369834670654
# ===================
# L = 0.9210000000000007
# rho = 0.36793601599936865
# ===================
# L = 0.9220000000000007
# rho = 0.36793517777698076
# ===================
# L = 0.9230000000000007
# rho = 0.3679342208114593
# ===================
# L = 0.9240000000000007
# rho = 0.3679333824846771
# ===================
# L = 0.9250000000000007
# rho = 0.3679324356200501
# ===================
# L = 0.9260000000000007
# rho = 0.3679315975025721
# ===================
# L = 0.9270000000000007
# rho = 0.3679306603561371
# ===================
# L = 0.9280000000000007
# rho = 0.367929822746227
# ===================
# L = 0.9290000000000007
# rho = 0.3679288949535875
# ===================
# L = 0.9300000000000007
# rho = 0.36792805813428653
# ===================
# L = 0.9310000000000007
# rho = 0.36792713934902954
# ===================
# L = 0.9320000000000007
# rho = 0.3679263035884037
# ===================
# L = 0.9330000000000007
# rho = 0.36792539348173103
# ===================
# L = 0.9340000000000007
# rho = 0.36792455903315213
# ===================
# L = 0.9350000000000007
# rho = 0.36792365729347026
# ===================
# L = 0.9360000000000007
# rho = 0.36792282439592733
# ===================
# L = 0.9370000000000007
# rho = 0.36792193072840057
# ===================
# L = 0.9380000000000007
# rho = 0.3679210996068406
# ===================
# L = 0.9390000000000007
# rho = 0.3679202137329111
# ===================
# L = 0.9400000000000007
# rho = 0.36791938459860496
# ===================
# L = 0.9410000000000007
# rho = 0.3679185062554843
# ===================
# L = 0.9420000000000007
# rho = 0.36791767930641656
# ===================
# L = 0.9430000000000007
# rho = 0.36791680824655415
# ===================
# L = 0.9440000000000007
# rho = 0.36791598366783357
# ===================
# L = 0.9450000000000007
# rho = 0.36791511965836476
# ===================
# L = 0.9460000000000007
# rho = 0.36791429762265176
# ===================
# L = 0.9470000000000007
# rho = 0.36791344044483143
# ===================
# L = 0.9480000000000007
# rho = 0.36791262111278056
# ===================
# L = 0.9490000000000007
# rho = 0.36791177056140456
# ===================
# L = 0.9500000000000007
# rho = 0.36791095408211977
# ===================
# L = 0.9510000000000007
# rho = 0.36791010996493967
# ===================
# L = 0.9520000000000007
# rho = 0.36790929647643833
# ===================
# L = 0.9530000000000007
# rho = 0.3679084586135706
# ===================
# L = 0.9540000000000007
# rho = 0.3679076482432541
# ===================
# L = 0.9550000000000007
# rho = 0.36790681646659107
# ===================
# L = 0.9560000000000007
# rho = 0.3679060093317194
# ===================
# L = 0.9570000000000007
# rho = 0.36790518348434054
# ===================
# L = 0.9580000000000007
# rho = 0.367904379692509
# ===================
# L = 0.9590000000000007
# rho = 0.3679035596280984
# ===================
# L = 0.9600000000000007
# rho = 0.36790275927771243
# ===================
# L = 0.9610000000000007
# rho = 0.36790194485998484
# ===================
# L = 0.9620000000000007
# rho = 0.3679011480407321
# ===================
# L = 0.9630000000000007
# rho = 0.36790033914286796
# ===================
# L = 0.9640000000000007
# rho = 0.3678995459361862
# ===================
# L = 0.9650000000000007
# rho = 0.36789874244027976
# ===================
# L = 0.9660000000000007
# rho = 0.36789795291981653
# ===================
# L = 0.9670000000000007
# rho = 0.3678971547163381
# ===================
# L = 0.9680000000000007
# rho = 0.3678963689484018
# ===================
# L = 0.9690000000000007
# rho = 0.3678955759356751
# ===================
# L = 0.9700000000000008
# rho = 0.3678947939796767
# ===================
# L = 0.9710000000000008
# rho = 0.36789400606337375
# ===================
# L = 0.9720000000000008
# rho = 0.3678932279722562
# ===================
# L = 0.9730000000000008
# rho = 0.3678924450649098
# ===================
# L = 0.9740000000000008
# rho = 0.36789167088556457
# ===================
# L = 0.9750000000000008
# rho = 0.36789089290609966
# ===================
# L = 0.9760000000000008
# rho = 0.36789012267976934
# ===================
# L = 0.9770000000000008
# rho = 0.36788934955305486
# ===================
# L = 0.9780000000000008
# rho = 0.36788858331572205
# ===================
# L = 0.9790000000000008
# rho = 0.3678878149721413
# ===================
# L = 0.9800000000000008
# rho = 0.3678870527549011
# ===================
# L = 0.9810000000000008
# rho = 0.36788628912994353
# ===================
# L = 0.9820000000000008
# rho = 0.3678855309593605
# ===================
# L = 0.9830000000000008
# rho = 0.3678847719932336
# ===================
# L = 0.9840000000000008
# rho = 0.3678840178916831
# ===================
# L = 0.9850000000000008
# rho = 0.36788326352894474
# ===================
# L = 0.9860000000000008
# rho = 0.36788251351493695
# ===================
# L = 0.9870000000000008
# rho = 0.36788176370414793
# ===================
# L = 0.9880000000000008
# rho = 0.3678810177926357
# ===================
# L = 0.9890000000000008
# rho = 0.3678802724860328
# ===================
# L = 0.9900000000000008
# rho = 0.3678795306887031
# ===================
# L = 0.9910000000000008
# rho = 0.36787878984189093
# ===================
# L = 0.9920000000000008
# rho = 0.3678780521674394
# ===================
# L = 0.9930000000000008
# rho = 0.3678773157391027
# ===================
# L = 0.9940000000000008
# rho = 0.36787658219349295
# ===================
# L = 0.9950000000000008
# rho = 0.367875850145126
# ===================
# L = 0.9960000000000008
# rho = 0.3678751207318317
# ===================
# L = 0.9970000000000008
# rho = 0.3678743930274881
# ===================
# L = 0.9980000000000008
# rho = 0.36787366774772007
# ===================
# L = 0.9990000000000008
# rho = 0.36787294435377726
# ===================
# L = 1.0000000000000007
# rho = 0.36787222320669616
# ===================
# ======Section 2======
# rho = 0.3678715040916394
# ===================
# rho = 0.3678695461676947
# ===================
# rho = 0.36786758872638126
# ===================
# rho = 0.36786563176553905
# ===================
# rho = 0.36786367528300135
# ===================
# rho = 0.36786171927662165
# ===================
# rho = 0.3678597637442538
# ===================
# rho = 0.3678578086837642
# ===================
# rho = 0.3678558540930259
# ===================
# rho = 0.36785389996991863
# ===================
# rho = 0.367851946312332
# ===================
# rho = 0.3678499931181591
# ===================
# rho = 0.3678480403853053
# ===================
# rho = 0.36784608811167646
# ===================
# rho = 0.36784413629519225
# ===================
# rho = 0.3678421849337714
# ===================
# rho = 0.367840234025347
# ===================
# rho = 0.36783828356785037
# ===================
# rho = 0.3678363335592269
# ===================
# rho = 0.3678343839974205
# ===================
# rho = 0.3678324348803886
# ===================
# rho = 0.3678304862060867
# ===================
# rho = 0.36782853797248405
# ===================
# rho = 0.3678265901775477
# ===================
# rho = 0.3678246428192579
# ===================
# rho = 0.3678226958955934
# ===================
# rho = 0.3678207494045448
# ===================
# rho = 0.3678188033441022
# ===================
# rho = 0.3678168577122668
# ===================
# rho = 0.3678149125070393
# ===================
# rho = 0.3678129677264312
# ===================
# rho = 0.36781102336845395
# ===================
# rho = 0.367809079431129
# ===================
# rho = 0.36780713591247827
# ===================
# rho = 0.36780519281053314
# ===================
# rho = 0.3678032501233256
# ===================
# rho = 0.367801307848897
# ===================
# rho = 0.36779936598528906
# ===================
# rho = 0.3677974245305527
# ===================
# rho = 0.36779548348273977
# ===================
# rho = 0.36779354283991056
# ===================
# rho = 0.3677916026001268
# ===================
# rho = 0.3677896627614578
# ===================
# rho = 0.36778772332197496
# ===================
# rho = 0.36778578427975694
# ===================
# rho = 0.3677838456328846
# ===================
# rho = 0.36778190737944566
# ===================
# rho = 0.36777996951753017
# ===================
# rho = 0.3677780320452351
# ===================
# rho = 0.36777609496065994
# ===================
# rho = 0.36777415826191023
# ===================
# rho = 0.36777222194709447
# ===================
# rho = 0.36777028601432726
# ===================
# rho = 0.36776835046172635
# ===================
# rho = 0.3677664152874149
# ===================
# rho = 0.36776448048951943
# ===================
# rho = 0.367762546066172
# ===================
# rho = 0.3677606120155078
# ===================
# rho = 0.3677586783356677
# ===================
# rho = 0.3677567450247956
# ===================
# rho = 0.3677548120810409
# ===================
# rho = 0.367752879502556
# ===================
# rho = 0.3677509472874987
# ===================
# rho = 0.36774901543403027
# ===================
# rho = 0.3677470839403169
# ===================
# rho = 0.367745152804528
# ===================
# rho = 0.36774322202483833
# ===================
# rho = 0.36774129159942576
# ===================
# rho = 0.36773936152647324
# ===================
# rho = 0.36773743180416685
# ===================
# rho = 0.3677355024306979
# ===================
# rho = 0.3677335734042606
# ===================
# rho = 0.3677316447230543
# ===================
# rho = 0.3677297163852817
# ===================
# rho = 0.36772778838915005
# ===================
# rho = 0.36772586073286984
# ===================
# rho = 0.36772393341465653
# ===================
# rho = 0.3677220064327289
# ===================
# rho = 0.36772007978531
# ===================
# rho = 0.3677181534706266
# ===================
# rho = 0.36771622748690974
# ===================
# rho = 0.367714301832394
# ===================
# rho = 0.3677123765053182
# ===================
# rho = 0.36771045150392473
# ===================
# rho = 0.36770852682646
# ===================
# rho = 0.36770660247117437
# ===================
# rho = 0.3677046784363217
# ===================
# rho = 0.36770275472016023
# ===================
# rho = 0.3677008313209514
# ===================
# rho = 0.3676989082369609
# ===================
# rho = 0.3676969854664577
# ===================
# rho = 0.36769506300771504
# ===================
# rho = 0.3676931408590096
# ===================
# rho = 0.3676912190186219
# ===================
# rho = 0.3676892974848359
# ===================
# rho = 0.3676873762559397
# ===================
# rho = 0.36768545533022473
# ===================
# rho = 0.3676835347059861
# ===================
# rho = 0.36768161438152264
# ===================
# rho = 0.36767969435513687
# ===================
# ======End======

# %% [markdown]
# **Calculate Result and Residual**

# %%
DMM_U, DMM_Res = Multigrid_circle(inputsize, A1, RightF, Pnew, Rnew, s, wnew, MAX_ITER)
# Out:
# Residual = 13.247752472029722
# Interation = 0
# ===================
# Residual = 1.3398903409813667
# Interation = 1
# ===================
# Residual = 0.2496512591711532
# Interation = 2
# ===================
# Residual = 0.06382576003721094
# Interation = 3
# ===================
# Residual = 0.018795475006626133
# Interation = 4
# ===================
# Residual = 0.005870683436347229
# Interation = 5
# ===================
# Residual = 0.001885444218521754
# Interation = 6
# ===================
# Residual = 0.0006156811310919586
# Interation = 7
# ===================
# Residual = 0.00020341730840364313
# Interation = 8
# ===================
# Residual = 6.782670121652068e-05
# Interation = 9
# ===================
# Residual = 2.2787837799454548e-05
# Interation = 10
# ===================
# Residual = 7.70549908067017e-06
# Interation = 11
# ===================
# Residual = 2.6200291987359333e-06
# Interation = 12
# ===================
# Residual = 8.951560961808123e-07
# Interation = 13
# ===================
# Residual = 3.0711895552092863e-07
# Interation = 14
# ===================
# Residual = 1.0575382749567282e-07
# Interation = 15
# ===================
# Residual = 3.653138868203592e-08
# Interation = 16
# ===================
# Residual = 1.2654473137281597e-08
# Interation = 17
# ===================
# Residual = 4.394218757373365e-09
# Interation = 18
# ===================
# Residual = 1.529156753603246e-09
# Interation = 19
# ===================
# Residual = 5.331477935993894e-10
# Interation = 20
# ===================
# Residual = 1.8619797732365303e-10
# Interation = 21
# ===================
# Residual = 6.512451949480924e-11
# Interation = 22
# ===================
# Residual = 2.280579007017137e-11
# Interation = 23
# ===================
# Residual = 7.99682389868946e-12
# Interation = 24
# ===================
# Residual = 2.807010781861633e-12
# Interation = 25
# ===================
# Residual = 9.828002307824846e-13
# Interation = 26
# ===================
# Residual = 3.4782139671319847e-13
# Interation = 27
# ===================
# Residual = 1.2678406893888404e-13
# Interation = 28
# ===================
# Residual = 5.2430877443996436e-14
# Interation = 29
# ===================
# Residual = 3.239085350598975e-14
# Interation = 30
# ===================
# Residual = 2.80953700359284e-14
# Interation = 31
# ===================
# Residual = 2.2953825340351367e-14
# Interation = 32
# ===================
# Residual = 2.653451681541981e-14
# Interation = 33
# ===================
# Residual = 2.7028431865498743e-14
# Interation = 34
# ===================
# Residual = 2.494365042317507e-14
# Interation = 35
# ===================
# Residual = 2.2588434827158606e-14
# Interation = 36
# ===================
# Residual = 2.59847323191815e-14
# Interation = 37
# ===================
# Residual = 2.434309852231675e-14
# Interation = 38
# ===================
# Residual = 2.79643368485821e-14
# Interation = 39
# ===================
# Residual = 2.6609997470890638e-14
# Interation = 40
# ===================
# Residual = 2.3933433495052986e-14
# Interation = 41
# ===================
# Residual = 2.4419377231504858e-14
# Interation = 42
# ===================
# Residual = 2.397010597978426e-14
# Interation = 43
# ===================
# Residual = 2.5061944603323502e-14
# Interation = 44
# ===================
# Residual = 2.444785035125089e-14
# Interation = 45
# ===================
# Residual = 2.4114097224134914e-14
# Interation = 46
# ===================
# Residual = 2.3191413385341262e-14
# Interation = 47
# ===================
# Residual = 2.5368186891106096e-14
# Interation = 48
# ===================
# Residual = 2.361801040596919e-14
# Interation = 49
# ===================

# %% [markdown]
# **Plot Result**

# %%
plt.imshow(DMM_U.reshape(sqrtinputsize,sqrtinputsize))
plt.colorbar()

# %% [markdown]
# **Plot Residual**

# %%
plt.semilogy(DMM_Res)

# %% [markdown]
# **Calculate Spectral Radius**

# %%
DMM_Radius = Rhonew
print('DMM_Radius = {}'.format(DMM_Radius))
# Out:
# DMM_Radius = 0.36767969435513687

# %% [markdown]
# ## Compare

# %%
print('GMM_Radius = {}'.format(GMM_Radius))
print('DMM_Radius = {}'.format(DMM_Radius))
print("GMM_Radius : DMM_Radius = 1 : %f" %(DMM_Radius/GMM_Radius))
# Out:
# GMM_Radius = 0.46619808175866373
# DMM_Radius = 0.36767969435513687
# GMM_Radius : DMM_Radius = 1 : 0.788677

# %%
plt.semilogy(GMM_Res, label = 'GMM_Res')
plt.semilogy(AMG_Res, label = 'AMG_Res')
plt.semilogy(DMM_Res, label = 'DMM_Res')
plt.legend(loc='upper right')

# %% [markdown]
# ## R, P and  $\omega$ after Optimization

# %%
print('omega after optimization = {}'.format(wnew))
# Out:
# omega after optimization = 0.8000409797000307

# %%
print('P after optimization ')
plt.imshow(np.log10(np.abs(Pnew)))
plt.colorbar()
# Out:
# P after optimization

# %%
print('R after optimization ')
plt.imshow(np.log10(np.abs(Rnew)))
plt.colorbar()
# Out:
# R after optimization

# %%
print("P under log10(abs())")
plt.plot(np.log10(np.abs(Pnew))[round(0.5*inputsize)][:])
# Out:
# P under log10(abs())

# %%
print("R under log10(abs())")
plt.plot(np.log10(np.abs(Rnew))[:][round(0.5*outputsize)])
# Out:
# R under log10(abs())

# %%
import win32com.client
import winsound
speak = win32com.client.Dispatch('SAPI.SPVOICE')
speak.Speak('The program has finished, please check the result')
# Out:
# 1
